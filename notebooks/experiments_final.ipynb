# %% [markdown]
# ---
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import time
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from deep_translator import GoogleTranslator

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from tqdm import tqdm
from lime.lime_text import LimeTextExplainer
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath('../src'))
import utils
import spacy 
from transformers import AutoTokenizer, AutoModelWithLMHead
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

from IPython.display import display, HTML

# %%
# !pip install emoji
# !pip install lime
# Out:
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/bin/pip: line 2: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/.venv/bin/python3.13: No such file or directory
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/bin/pip: line 2: exec: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/.venv/bin/python3.13: cannot execute: No such file or directory
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/bin/pip: line 2: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/.venv/bin/python3.13: No such file or directory
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/bin/pip: line 2: exec: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/.venv/bin/python3.13: cannot execute: No such file or directory

# %% [markdown]
# **Directory Paths**

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path(os.getcwd()).parent 

DATA_PATH = PROJECT_ROOT / "data"
RAW_DATA_PATH = DATA_PATH / "raw"
PROCESSED_DATA_PATH = DATA_PATH / "processed"
AUGMENTED_DATA_PATH = DATA_PATH / "augmented"

OUTPUT_PATH = PROJECT_ROOT / "output"
FIGURES_PATH = OUTPUT_PATH / "figures"
METRICS_PATH = OUTPUT_PATH / "metrics"

print(f"Reading data from: {DATA_PATH}")
print(f"Saving outputs in {OUTPUT_PATH}")
# Out:
# Reading data from: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/data
# Saving outputs in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/output

# %% [markdown]
# ---
# ## Upload the data

# %%
df = pd.read_csv(RAW_DATA_PATH / 'fakeWhatsApp.BR_2018.csv')
df
# Out:
# /var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/ipykernel_1056/1281561040.py:1: DtypeWarning: Columns (4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(RAW_DATA_PATH / 'fakeWhatsApp.BR_2018.csv')
#                          id      date   hour            timestamp ddi country  \
# 0       3631133147603888180  01/08/18  13:13  2018-08-01 13:13:00  55  BRASIL
# 1       3631133147603888180  01/08/18  13:24  2018-08-01 13:24:00  55  BRASIL
# 2       3631133147603888180  01/08/18  13:24  2018-08-01 13:24:00  55  BRASIL
# 3      -4391661641377612003  01/08/18  13:28  2018-08-01 13:28:00  55  BRASIL
# 4      -4391661641377612003  09/08/18  14:46  2018-08-09 14:46:00  55  BRASIL
# ...                     ...       ...    ...                  ...  ..     ...
# 282596 -3459365403520904542  28/10/18  21:48  2018-10-28 21:48:00   ?       ?
# 282597 -3459365403520904542  28/10/18  22:06  2018-10-28 22:06:00   ?       ?
# 282598 -3459365403520904542  28/10/18  22:08  2018-10-28 22:08:00   ?       ?
# 282599 -3459365403520904542  28/10/18  22:12  2018-10-28 22:12:00   ?       ?
# 282600 -3459365403520904542  28/10/18  23:12  2018-10-28 23:12:00   ?       ?
#
#        country_iso3 ddd      state    group  midia  url  characters  words  \
# 0               BRA  17  São Paulo   2018_1      1    0          25      4
# 1               BRA  17  São Paulo   2018_1      0    0          58      9
# 2               BRA  17  São Paulo   2018_1      1    0          25      4
# 3               BRA  13  São Paulo   2018_1      0    0           5      1
# 4               BRA  13  São Paulo   2018_1      1    0          25      4
# ...             ...  ..        ...      ...    ...  ...         ...    ...
# 282596            ?   ?          ?  2018_59      1    0          25      4
# 282597            ?   ?          ?  2018_59      1    0          25      4
# 282598            ?   ?          ?  2018_59      1    0          25      4
# 282599            ?   ?          ?  2018_59      1    0          25      4
# 282600            ?   ?          ?  2018_59      1    0          25      4
#
#         types  viral  shares  \
# 0           4      0       1
# 1           9      1       2
# 2           4      0       1
# 3           1      0       1
# 4           4      0       1
# ...       ...    ...     ...
# 282596      4      0       1
# 282597      4      0       1
# 282598      4      0       1
# 282599      4      0       1
# 282600      4      0       1
#
#                                                      text  misinformation
# 0                               <Arquivo de mídia oculto>              -1
# 1       O Bolsonaro tem que estar preparado pra respon...              -1
# 2                               <Arquivo de mídia oculto>              -1
# 3                                                   Boaaa              -1
# 4                               <Arquivo de mídia oculto>              -1
# ...                                                   ...             ...
# 282596                          <Arquivo de mídia oculto>              -1
# 282597                          <Arquivo de mídia oculto>              -1
# 282598                          <Arquivo de mídia oculto>              -1
# 282599                          <Arquivo de mídia oculto>              -1
# 282600                          <Arquivo de mídia oculto>              -1
#
# [282601 rows x 19 columns]

# %% [markdown]
# - Only viral menssages from non midiatic sources

# %%
df = df[df['viral'] == 1]
df = df[df['midia'] == 0]

# %% [markdown]
# - We came from 282601 rows to 20872

# %%
df.head()
# Out:
#                       id      date   hour            timestamp ddi country  \
# 1    3631133147603888180  01/08/18  13:24  2018-08-01 13:24:00  55  BRASIL
# 15   3631133147603888180  10/08/18  14:31  2018-08-10 14:31:00  55  BRASIL
# 26  -4391661641377612003  11/08/18  19:28  2018-08-11 19:28:00  55  BRASIL
# 43   3631133147603888180  15/08/18  19:23  2018-08-15 19:23:00  55  BRASIL
# 103 -4391661641377612003  22/08/18  22:11  2018-08-22 22:11:00  55  BRASIL
#
#     country_iso3 ddd      state   group  midia  url  characters  words  types  \
# 1            BRA  17  São Paulo  2018_1      0    0          58      9      9
# 15           BRA  17  São Paulo  2018_1      0    0          99     18     18
# 26           BRA  13  São Paulo  2018_1      0    0         114     17     17
# 43           BRA  17  São Paulo  2018_1      0    1         330     47     40
# 103          BRA  13  São Paulo  2018_1      0    0         226     39     34
#
#      viral  shares                                               text  \
# 1        1       2  O Bolsonaro tem que estar preparado pra respon...
# 15       1       2  No dia 07 de Outubro, quando for votar, não es...
# 26       1       6  Devido a aborrecimentos nas varias redes socia...
# 43       1       7  EU GOSTARIA DE PEDIR A TODOS DO GRUPOS ENTREM ...
# 103      1       8  Como são as coisas.\nChefe do jacaré aparece n...
#
#      misinformation
# 1                -1
# 15                1
# 26                0
# 43                0
# 103               1

# %% [markdown]
# - Elimination of data there was classified with misinformation = -1

# %%
df = df[df["misinformation"] != -1]

# %% [markdown]
# - Looking the data

# %% [markdown]
# - Misinformation

# %%
i = 0
for message in df[df['misinformation'] == 1]['text'].sample(5):
    print(f"Mensagem: {i}\n")
    print(message)
    print("\n")
    i+=1
# Out:
# Mensagem: 0
#
# O golpe da esquerda é o seguinte: a viagem do Ciro Gomes à Europa foi proposital!
# Um teatro p/ colocar a seguinte narrativa em prática: ele sai de cena, ou seja, teoricamente não está apoiando Haddad, de repente ele volta (e de fato, de acordo c/ o Estadão ele está chegando hoje) qdo não terá mais nenhuma pesquisa a ser divulgada, para q não se “comprove”, se de fato aconteceria, a escalada q Haddad  “terá” de milhões de votos em 2 dias. Enfim, o fato novo, que a imprensa já avisadamente, a todo tempo publicou, que seria a única coisa p/ virada nos votos!
# Ou seja, tudo articulado, para acontecer exatamente como no 1° turno, onde o apoio do Lula fez o poste crescer em poucos dias 20 ptos percentuais, vão tentar vender a ideia que o apoio do Ciro de última hora, fez reverter ao Haddad todos os votos que ele teve, justificando o golpe nas urnas!
# Precisamos divulgar isto em massa, numa velocidade recorde, para minar o efeito, antes mesmo de ocorrer!
# Joyce H, Bia k,  Janaína P, família Bolsonaro, tds os brasileiros, nas redes!
#
#
# Mensagem: 1
#
# *_O meu Voto será de acordo com a Palavra de Deus._*
#
# O número do Bolsonaro é 17 certo?
#
# Então veja sobre o número 17 na Bíblia.
# *Isso é de arrepiar!*
#
# _Você Sabia?_
#
# *17 Livros da Bíblia tem Capítulo 17 e versículo 17.*
#
# *1)* _É na hora da Angústia que nasce um irmão._ *Provérbios 17:17*.
#
# *2)* _Deus sempre prepara um Refúgio nos dias em que a maldade está prevalecendo._ *Jeremias 17:17*.
#
# *3)* _Para um povo grande e forte, coisas boas sempre acontecerão._ *Josué 17:17*.
#
# *4)* _Mesmo que o inimigo venha com um numeroso exército e com tranqueiras para destruir vidas, a sua força será anulada e não farão coisa alguma._ *Ezequiel 17:17*.
#
# *5)* _O dia de trazer a vida, para um estado de morte que era irreversível._ *I Reis 17:17*.
#
# *6)* _Não posso expor meus filhos a maldade, pq isso é mal aos olhos do Senhor._ *II Reis 17:17*.
#
# *7)* _O Rei não Pode ser depravado e não pode ser corrupto._ *Deuteronômio 17:17*.
#
# *8)* _Estava a caminho o homem que  iria derrubar o gigante que afrontava a nação._ *I Samuel 17:17*.
#
# *9)* _Davi é avisado sobre uma cilada que estava preparada, e escapou a tempo._ *II Samuel 17:17*.
#
# *10)* _Deus exalta aquele que ninguém imaginava que seria exaltado._ *I Crônicas 17:17*.
#
# *11)* _Eliada (Deus conhece),o Varão Valente, de Benjamim (O filho da minha direita)._ *II Crônicas 17:17*.
#
# *12)* _O que parecia ser impossível mudar, Deus mudou._ *Gênesis 17:17*.
#
# *13)* _Tempo de uma geração incrédula e perversa, mas o negócio ia mudar._ *Mateus 17:17*.
#
# *14)* _Só um estava disposto a glorificar a Deus._ *Lucas 17:17*.
#
# *15)* _Se nos aproximarmos da Palavra de Deus, seremos santificados por ela, porque a Palavra é a Verdade._ *João 17:17*.
#
# *16)* _Gálio (procônsul), viu um homem ser atacado e ferido na frente do seu tribunal, e não se incomodou com o que viu._ *Atos 17:17*.
#
# *17)* _Quando desprezamos a Deus, Ele mesmo permite que o governante seja de acordo com os intentos dos homens que O desprezaram. Até que a Sua Palavra se cumpra._ *Apocalipse 17:17*.
#
# *_#Compartilhe_*
#
#
# Mensagem: 2
#
# *📣📢📣📢🚨🚨*GOLPE EM ANDAMENTO!!!❗ ............. Campanhas de HADDAD e CIRO GOMES preparam ação no TSE para tirar BOLSONARO do segundo turno, com base na denuncia FAKE da fOLHA DE SAO PAULO!!!                Vamos ficar em estado de ALERTA TOTAL**
#
#
# Mensagem: 3
#
# Ouça a narrativa do apresentador padre Cléber do Programa Aparecida Sertaneja da TV Aparecida, e tire a sua conclusão.
# Se vale a pena repassar para mais gente ouvir. 👇👇👇
#
#
# Mensagem: 4
#
# https://youtu.be/X_PrbQhcohs
#
# Estadual: Professor Edison 1⃣7⃣7⃣0⃣0⃣
#
# Realizamos no dia 21/09/2018 a útltima reunião dos Bolsonaristas antes da eleição do dia 07/10.
#
# Resoluções do grupo:
#
# 1. Postar os candidatos que passaram pelo crivo do grupo: Farlei senador, Patrícia Federal, Edisom estadual e Lucas estadual.
#
# 2. Trabalhar os grupos de cada cidade em especial das 22 maiores. E observar e pedir ajuda as lideranças que podem criar novos grupos em todas as cidades do Tocantins.
#
# 3. Enviar os links desses grupos para que as pessoas possam migrar para os grupos das cidades onde o trabalho será intensificado com foco.
#
# 4. O foco estratégico é compartilhar a página de referência no Tocantins: Direita Palmas e Amor pelo Brasil. Somos 50 Bolsonaristas em Palmas se todos compartilherem chegaremos aos potenciais eleitores.
#
# 5. Foco nas postagem no WhastApp evitar envios redundantes sem foco eleitoral. Queremos ganhar queremos voto, precisamos massificar o nome e número dos candidatos da chapa do Bolsonaro.
#
# 6. Postar os vídeos do Farlei, Patrícia, Edisom e Lucas nos nossos grupos e redes sociais.
#
# Vamos ajudar o Capitão! Conte conosco!
#
#
# ✨✨  Marcha para o interior do Tocantins ✨✨
#
# Projeto: Bolsonaro 2018, Vencer no 1° Turno no Tocantins
#
# 20 cidades onde Bolsonaro precisa vencer no 1° Turno no Tocantins
#
# 🤷♀ Como posso ajudar?
#
# 👉 Resposta: Você, eu e todos nós podemos ajudar a crescer os grupos direcionando os contatos para as respectivas localidade de suas residências, onde você pode ajudar a organizar os apoiadores de Jair Bolsonaro, em todos os municípios do Tocantins. Pela ordem vamos começar nos maiores colégios eleitorais, ok?
# 👉 Note: estamos na reta final, agora o mais importante é chegar ao maior número de potenciais eleitores do Mito.
# 👉 Conteúdo: nossa páginas do facebook lhe darão o conteúdo de apoio. A ordem é crescer os grupos e eliminar os cabos eleitorais dos adversários do projeto Bolsonaro 2018.
#
# 1. Palmas
#
# ✅ https://chat.whatsapp.com/2IdCUfeJoeQBA0K5OX1cWg
#
#                  1.1 Luzimangues
#
#                  ✅ https://chat.whatsapp.com/6mCy9S9vcNVAX3jlzXyZJa
#
#                  1.2 Taquaralto.
#
#                   ✅ https://chat.whatsapp.com/APPPZATMZ5V5WH00aWoZyO
#
#                  1.3 Aureny III
#
#                  ✅ https://chat.whatsapp.com/4ULz3DTIjg8GdVJvddR7al
#
# 2. Araguaína
#
# ✅ https://chat.whatsapp.com/5eKvlBO4o1d1rcCPRAJB2W
#
# 3. Gurupi
#
# ✅ https://chat.whatsapp.com/Hn6hyxjhfMd4GFWYNB45te
#
# 4. Porto Nacional
#
# ✅ https://chat.whatsapp.com/7gLWnHBwZ5OFUvMQYpHEhq
#
# 5. Paraíso do Tocantins
#
# ✅ https://chat.whatsapp.com/ABojVsdKjAx1jMgtmttXCq
#
# 6. Colinas do Tocantins
#
# ✅ https://chat.whatsapp.com/3PjH2KIuEi853GK6rszLrK
#
# 7. Araguatins
#
# ✅ https://chat.whatsapp.com/1dQhSEGRQbL7oLeQTxwk97
#
# 8. Guaraí
#
# ✅ https://chat.whatsapp.com/8LEiEsMosxr6PApw3daThA
#
# 9. Tocantinópolis
#
# ✅ https://chat.whatsapp.com/3lgBraACZhZ8gKzIsZx5iY
#
# 10. Miracema do Tocantins
#
# ✅ https://chat.whatsapp.com/16VKMkHXic7GOVcUCwNaqN
#
# 11. Formoso do Araguaia
#
# ✅ https://chat.whatsapp.com/Ah71fDx9RlFDSdrCvzjljX
#
# 12. Dianópolis
#
# ✅ https://chat.whatsapp.com/4tmfSOEn8kj62KkZ0FJQzq
#
# 13. Augustinópolis
#
# ✅ https://chat.whatsapp.com/0P3ELe77vbNB1n57fvSZdb
#
# 14. Taguatinga
#
# ✅ https://chat.whatsapp.com/8smHNwtHw1d3uwawjh7ZT5
#
# 15. Miranorte
#
# ✅ https://chat.whatsapp.com/5WRWgKacx3iDDJZLYpYosJ
#
# 16. Pedro Afonso
#
# ✅ https://chat.whatsapp.com/2DmEfxwO4hQBD6tlGVdC3a
#
# 17. Xambioá
#
# ✅ https://chat.whatsapp.com/2HjtpRGsbEf0A4LxWC68Aj
#
# 18. Axixá do Tocantins
#
# ✅ https://chat.whatsapp.com/IgssgURUT9HB6dMVfjOrrX
#
# 19. Lagoa da Confusão
#
# ✅ https://chat.whatsapp.com/JmWJAInsjE8EJ2AbdB0Sjq
#
# 20. Arraias
#
# ✅ https://chat.whatsapp.com/8Uc37BHILAl2CDBDUi4Dqq
#
# Estatuto
#
# 1. Objetivo único apoio a Bolsonaro.
#
# 2. Organizar nova etapa de inauguração de grupo.
#
# 3. Orientar as iniciativas nas demais redes sociais como: facebook, you tube...
#
# 4. Estabelecer meta
#
# 5. Monitorar
#
# 6. Avaliar
#
# 7. Buscar informação precisa e dizer a verdade
#
# 8. Elogiar, urbanidade
#
# 9. Zelar pela integridade dos grupos
#
# 10. Proliferar
#
# Eis o Estatuto da Rede Bolsonarista - TO
#
# 🔰 *Grupo WhatsApp Central* 🔰: https://chat.whatsapp.com/KGDkFevX2IZGDboME188fj
#
# ➡ Facebook: https://www.facebook.com/DireitaPalmas
#
# ➡ Blog: https://bolsonarista.wordpress.com
#
# ➡ Canal YouTube: https://www.youtube.com/channel/UC3uaVEAIvmCEXbRgeL7Vvmw
#
# Loja Camisetas 😎:
#
# ✅ https://chat.whatsapp.com/L3I1537RNKLFOYyuRccM2Z
#
# Presidente: Bolsonaro 1⃣7⃣
# Senador: Farlei 1⃣7⃣0⃣
# Federal: Patrícia 1⃣7⃣7⃣7⃣
# Estadual: Professor Edison 1⃣7⃣7⃣0⃣0⃣

# %% [markdown]
# - Non misinformation

# %%
i = 0
for message in df[df['misinformation'] == 0]['text'].sample(5):
    print(f"Mensagem: {i}\n")
    print(message)
    print("\n")
    i+=1
# Out:
# Mensagem: 0
#
# *GRANDE ENCONTRO* de patriotas e movimentos de direita para a *APURAÇÃO DE VOTOS* no comitê central de Bolsonaro em Fortaleza-CE!  _você é nosso convidado especial_ para essa festa Onde comemoraremos a vitória do Brasil! O comitê fica na *AV. Antônio Sales, 855*  o evento será a partir das 17:00Hrs.
#
# *PRESENÇAS CONFIRMADAS: KAROL ÉLLER, ANDRÉ FERNANDES E HEITOR FREIRE!*
#
# *EVENTO NO FACEBOOK:* https://www.facebook.com/events/532882347173300/
#
#
# Mensagem: 1
#
# Atualizando
#
# Sgt Augusto
# Sgt Cavalcante
# Ten César
#
# 03 PMs baleados na Vila Manoel Satiro, segundo informações  todos em óbito.
#
# -----'-'-  ----''-
# Informações de 03 policiais baleados agora no bairro Vila Pery em Fortaleza-CE.
#
# Aguardando mais informações
#
#
# Mensagem: 2
#
# Quem mora em Recife da equipe de Bolsonaro tem que ficar esperto para filmar tudo e entregar as autoridades...urgente!!!
#
#
# Mensagem: 3
#
# Vamos fazer campanha inteligente e garantir a vitória!?
# - Não compartilhem nada ofensivo ao Nordeste!!! 2014 internet bombou de ofensas e a Dilma cresceu absurdamente la no segundo turno!
# - Compartilhe mensagens positivas dele e da mudança!
# - Guarde pra VC o medo, transmita confiança para cativar votos!
# - Respeite a opinião alheia!
# - Cheque a Notícia, Fake News joga contra!
# Eleição tem dois turnos essa é a regra do jogo! AGORA É A HORA!
#
#
# Mensagem: 4
#
# https://youtu.be/hEucRA_B180
#
# Bolsonaro venceu em Bernardo Sayão veja porquê!
#
# Em Bernardo Sayão os Bolsonaristas se organizaram! É isso! Esse é o caminho!

# %% [markdown]
# - Corpus statistics

# %%
df.describe()[['characters','words','shares']]
# Out:
#          characters         words        shares
# count  18951.000000  18951.000000  18951.000000
# mean     574.501293     87.253390     11.885230
# std      929.443834    142.718198     16.573243
# min       38.000000     10.000000      2.000000
# 25%      132.000000     19.000000      2.000000
# 50%      222.000000     33.000000      5.000000
# 75%      551.000000     85.000000     13.000000
# max    15683.000000   2664.000000     91.000000

# %% [markdown]
# - Removing duplicates

# %%
df = df.drop_duplicates(subset=['text'])

# %% [markdown]
# - Definition of X and y

# %%
texts = df[df['midia'] == 0]['text']
y = df[df['midia'] == 0]['misinformation']

# %%
print('data after remove duplicates')
pos_mask = y == 1
pos = y[pos_mask]
neg_mask = y == 0
neg = y[neg_mask]
values = [pos.shape[0],neg.shape[0]]
keys = ['misinformation', 'non-misinformation']
g = sns.barplot(x = keys, y = values)
for p in g.patches:
    g.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2.,
                                               p.get_height()), ha = 'center',
               va = 'center', xytext = (0, 5), textcoords = 'offset points')
# Out:
# data after remove duplicates

# %% [markdown]
# - Lenght of the data used

# %%
print(len(texts))
print(len(y))
# Out:
# 4588
# 4588

# %% [markdown]
# - Misinformation column statistics

# %%
df.columns
# Out:
# Index(['id', 'date', 'hour', 'timestamp', 'ddi', 'country', 'country_iso3',
#        'ddd', 'state', 'group', 'midia', 'url', 'characters', 'words', 'types',
#        'viral', 'shares', 'text', 'misinformation'],
#       dtype='object')

# %%
df['types'] = [len(set(t.split())) for t in df['text']]

df['types/token ratio'] = df['types']/df['words']
df['char/word ratio'] = df['characters']/df['words']

df['average chars by word'] = [utils.avgSizeWords(t) for t in df['text']]

# %%
mis = df[df['misinformation']==1][['words','types','types/token ratio' ,'characters', 'char/word ratio', 'average chars by word','shares']].mean().to_frame().rename(columns={0: "misinformation"})
non_mis = df[df['misinformation']==0][['words','types','types/token ratio' ,'characters', 'char/word ratio', 'average chars by word','shares']].mean().to_frame().rename(columns={0: "non-misinformation"})
mis.join(non_mis, lsuffix='_misinformation', rsuffix='_non-misinformation')
# Out:
#                        misinformation  non-misinformation
# words                      113.870652           60.044366
# types                       78.719255           44.574401
# types/token ratio            0.845943            0.899166
# characters                 719.406663          408.918728
# char/word ratio              6.590809            7.231410
# average chars by word        5.529126            6.174667
# shares                       4.974032            3.454653

# %% [markdown]
# ---
# ## Pre-processing

# %%
import sys
sys.path.append(os.path.abspath('../src'))
import utils

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.8.0/pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 35.7 MB/s  0:00:00eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
nlp = spacy.load('pt_core_news_sm') 

texts = df['pre_processed_text'] = [utils.preprocess(t, nlp, sentence=True) for t in texts]

# %%
texts_train, texts_test, y_train, y_test = train_test_split(texts, y, test_size=0.2, stratify=y, random_state=42)

# %%
texts = df['pre_processed_text'] = [utils.preprocess(t, sentence = True) for t in texts]

# %% [markdown]
# - **Train and Test Split**

# %%
texts_train,texts_test,y_train,y_test = train_test_split(texts,y,test_size=0.2,stratify=y,random_state=42)

# %% [markdown]
# - Only retain one hundred words for each text (100 words are the limit)

# %%
texts = [utils.trucateText(t) for t in texts]

# %% [markdown]
# - Vectorization

# %%
vectorization = ['tfidf-']
ngrams = ['unigram_bigram_trigram']
processed = ['-pre_processed']
max_features = ['']#,'-max_features']
balancing = ['-oversampling']
experiments = []

for vec in vectorization:
    for ng in ngrams:
        for p in processed:
            for m in max_features:
                exp = vec+ng+p+m
                experiments.append(exp)

print(len(experiments))
experiments
# Out:
# 1
# ['tfidf-unigram_bigram_trigram-pre_processed']

# %%
vectorizer = utils.defineVectorizing(experiments[0])
X_train, X_test = utils.vectorizing(vectorizer, texts_train, texts_test)
# Out:
# Train: (3670, 1225)
# Test: (918, 1225)

# %% [markdown]
# ---
# ## Models

# %%
models = ['lr','nb','lsvm','sgd', 'svm', 'knn', 'rf', 'gb', 'mlp']
print(len(models))
models
# Out:
# 9
# ['lr', 'nb', 'lsvm', 'sgd', 'svm', 'knn', 'rf', 'gb', 'mlp']

# %%
lr = utils.model_eval('lr', X_train, y_train, X_test, y_test)
nb = utils.model_eval('nb', X_train, y_train, X_test, y_test, experiments)
lsvm = utils.model_eval('lsvm', X_train, y_train, X_test, y_test)
sgd = utils.model_eval('sgd', X_train, y_train, X_test, y_test)
svm = utils.model_eval('svm', X_train, y_train, X_test, y_test)
knn = utils.model_eval('knn', X_train, y_train, X_test, y_test)
rf = utils.model_eval('rf', X_train, y_train, X_test, y_test)
gb = utils.model_eval('gb', X_train, y_train, X_test, y_test)
mlp = utils.model_eval('mlp', X_train, y_train, X_test, y_test)

models_results = {
    'Logistic\nRegression': lr,
    'Naive\nBayes': nb,
    'Linear\nSVM': lsvm,
    'SGD': sgd,
    'SVM\nRBF': svm,
    'KNN': knn,
    'Random\nForest': rf,
    'Gradient\nBoosting': gb,
    'MLP': mlp
}

with open(METRICS_PATH / 'all_classifications_reports.txt', 'w', encoding='utf-8') as f:
    f.write("CLASSIFICATION REPORTS\n============================\n\n")
    
    for model_name, (model, metrics) in models_results.items():
        # No seu utils.py, o classification_report é o último item da lista de métricas
        report_str = metrics[-1] 
        
        f.write(f"MODELO: {model_name.replace(chr(10), ' ')}\n") # Remove quebras de linha do nome
        f.write(report_str)
        f.write("\n" + "-"*60 + "\n\n")

print("File 'all_classifications_reports.txt' saved with success!")

fig, ax, df_metrics = utils.plot_models_metrics(models_results, FIGURES_PATH / 'model_comparison.png')
# Out:
# === Logistic Regression ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.654
# Precision (W): 0.651
# Recall (W): 0.654
# F1 (W): 0.652
# AUC: 0.696
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.66      0.76      0.71       510
#            1       0.64      0.51      0.57       408
#
#     accuracy                           0.65       918
#    macro avg       0.65      0.64      0.64       918
# weighted avg       0.65      0.65      0.65       918
#
# === Complement Naive-Bayes ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.639
# Precision (W): 0.641
# Recall (W): 0.639
# F1 (W): 0.640
# AUC: 0.700
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67       510
#            1       0.59      0.61      0.60       408
#
#     accuracy                           0.64       918
#    macro avg       0.64      0.64      0.64       918
# weighted avg       0.64      0.64      0.64       918
#
# === Linear Support Vector Machine ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.651
# Precision (W): 0.649
# Recall (W): 0.651
# F1 (W): 0.650
# AUC: nan
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70       510
#            1       0.62      0.55      0.58       408
#
#     accuracy                           0.65       918
#    macro avg       0.65      0.64      0.64       918
# weighted avg       0.65      0.65      0.65       918
#
# === Linear SVM with SGD training ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.644
# Precision (W): 0.641
# Recall (W): 0.644
# F1 (W): 0.642
# AUC: nan
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.66      0.75      0.70       510
#            1       0.62      0.52      0.56       408
#
#     accuracy                           0.64       918
#    macro avg       0.64      0.63      0.63       918
# weighted avg       0.64      0.64      0.64       918
#
# === SVM with RBF kernel ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.669
# Precision (W): 0.669
# Recall (W): 0.669
# F1 (W): 0.669
# AUC: 0.713
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73       510
#            1       0.67      0.51      0.58       408
#
#     accuracy                           0.67       918
#    macro avg       0.67      0.65      0.65       918
# weighted avg       0.67      0.67      0.66       918
#
# === KNN ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.630
# Precision (W): 0.626
# Recall (W): 0.630
# F1 (W): 0.628
# AUC: 0.670
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.65      0.72      0.68       510
#            1       0.60      0.52      0.55       408
#
#     accuracy                           0.63       918
#    macro avg       0.62      0.62      0.62       918
# weighted avg       0.63      0.63      0.63       918
#
# === Random Forest ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.672
# Precision (W): 0.671
# Recall (W): 0.672
# F1 (W): 0.672
# AUC: 0.728
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73       510
#            1       0.66      0.53      0.59       408
#
#     accuracy                           0.67       918
#    macro avg       0.67      0.66      0.66       918
# weighted avg       0.67      0.67      0.67       918
#
# === Gradient Boosting ===
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.631
# Precision (W): 0.640
# Recall (W): 0.631
# F1 (W): 0.635
# AUC: 0.673
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.62      0.86      0.72       510
#            1       0.66      0.34      0.45       408
#
#     accuracy                           0.63       918
#    macro avg       0.64      0.60      0.59       918
# weighted avg       0.64      0.63      0.60       918
#
# === Multilayer Perceptron ===
# Iteration 1, loss = 0.67686036
# Validation score: 0.574932
# Iteration 2, loss = 0.63365244
# Validation score: 0.648501
# Iteration 3, loss = 0.57417494
# Validation score: 0.648501
# Iteration 4, loss = 0.51650805
# Validation score: 0.651226
# Iteration 5, loss = 0.47163021
# Validation score: 0.651226
# Iteration 6, loss = 0.43726954
# Validation score: 0.637602
# Iteration 7, loss = 0.41065377
# Validation score: 0.653951
# Iteration 8, loss = 0.38657851
# Validation score: 0.651226
# Iteration 9, loss = 0.36680212
# Validation score: 0.645777
# Iteration 10, loss = 0.34889476
# Validation score: 0.648501
# Iteration 11, loss = 0.33280840
# Validation score: 0.656676
# Iteration 12, loss = 0.31761333
# Validation score: 0.651226
# Iteration 13, loss = 0.30467224
# Validation score: 0.651226
# Iteration 14, loss = 0.29151131
# Validation score: 0.645777
# Iteration 15, loss = 0.28013204
# Validation score: 0.648501
# Iteration 16, loss = 0.26914509
# Validation score: 0.645777
# Iteration 17, loss = 0.25864079
# Validation score: 0.643052
# Validation score did not improve more than tol=0.001000 for 5 consecutive epochs. Stopping.
# ## 📊 Métricas de Desempenho (Weighted) ##
# Accuracy: 0.653
# Precision (W): 0.650
# Recall (W): 0.653
# F1 (W): 0.651
# AUC: 0.695
#
# ---
# ## 📋 Classification Report ##
#               precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70       510
#            1       0.63      0.54      0.58       408
#
#     accuracy                           0.65       918
#    macro avg       0.65      0.64      0.64       918
# weighted avg       0.65      0.65      0.65       918
#
# File 'all_classifications_reports.txt' saved with success!
# Plot saved as '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/output/figures/model_comparison.png'
# Metrics table:
#                Model  Accuracy  Precision   Recall  F1-Score
# Logistic\nRegression  0.653595   0.651309 0.653595  0.652450
#         Naive\nBayes  0.639434   0.640901 0.639434  0.640166
#          Linear\nSVM  0.651416   0.648905 0.651416  0.650158
#                  SGD  0.643791   0.640885 0.643791  0.642335
#             SVM\nRBF  0.668845   0.668500 0.668845  0.668673
#                  KNN  0.629630   0.626472 0.629630  0.628047
#       Random\nForest  0.672113   0.671064 0.672113  0.671588
#   Gradient\nBoosting  0.630719   0.639855 0.630719  0.635254
#                  MLP  0.652505   0.649931 0.652505  0.651216

# %%
from utils import plot_bias_analysis

# %%
df_gap = plot_bias_analysis(models_results, X_test, y_test, class_labels=['Real', 'Fake'])

# %%
trained_models = {
    "LogisticRegression": lr,
    "MultinomialNB": nb,
    "LinearSVC": lsvm,
    "SGDClassifier": sgd,
    "SVM": svm,
    "KNN": knn,
    "RandomForest": rf,
    "GradientBoosting": gb,
    "MLP": mlp
}

# %%
print(lr[0])
print(lr[1])
# Out:
# LogisticRegression()
# (0.6535947712418301, 0.6513090084518657, nan, 0.6535947712418301, nan, 0.6524498378942124, nan, 0.6957852748942714, '              precision    recall  f1-score   support\n\n           0       0.66      0.76      0.71       510\n           1       0.64      0.51      0.57       408\n\n    accuracy                           0.65       918\n   macro avg       0.65      0.64      0.64       918\nweighted avg       0.65      0.65      0.65       918\n')

# %% [markdown]
# ---
# ## Experiences

# %% [markdown]
# ### Experience 1 - Generating LIME explanations for each model predictions and compared the words that appear the most

# %% [markdown]
# LIME object stores: weights, class probabilities, raw scores, and links back to the original text.

# %% [markdown]
# - With the test set

# %%
def explain_with_lime(model, vectorizer, texts, idx, model_name="Model"):
    explainer = LimeTextExplainer(class_names=["real", "fake"])

    if hasattr(texts, "iloc"):
        text_instance = texts.iloc[idx]
    else:
        text_instance = texts[idx]

    def predict_proba(texts_list):
        X = vectorizer.transform(texts_list)
        if hasattr(model, "predict_proba"):
            return model.predict_proba(X)
        else:
            scores = model.decision_function(X)
            if scores.ndim == 1:
                scores = np.vstack([-scores, scores]).T
            # Converte para pseudo-probabilidades (usando softmax em scores)
            probs = np.exp(scores) / np.exp(scores).sum(axis=1, keepdims=True)  
            return probs

    print(f"\nText: {text_instance}")
    predicted_class = model.predict(vectorizer.transform([text_instance]))[0]
    print("Predicted Class:", predicted_class)
    
    exp = explainer.explain_instance(text_instance, predict_proba, num_features=10)
    
    # exp.show_in_notebook(text=True) 
    return exp

idx = 125 

for name, model_tuple in trained_models.items():
    print(f"\nModel: {name}")
    try:
        model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple
        
        exp = explain_with_lime(model, vectorizer, texts_test, idx, model_name=name) 
        
    except Exception as e:
        print(f"Error with {name}: {e}")
# Out:
# Model: LogisticRegression
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: MultinomialNB
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: LinearSVC
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: SGDClassifier
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: SVM
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: KNN
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 0
#
# Model: RandomForest
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: GradientBoosting
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Model: MLP
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1

# %% [markdown]
# - With the train set

# %%
'''def explain_with_lime(model,vectorizer,texts,idx):
    explainer = LimeTextExplainer(class_names=["real","fake"])

    if hasattr(texts,"iloc"):
      text_instance = texts.iloc[idx]
    else:
      text_instance = texts[idx]

    def predict_proba(texts_list):
        X = vectorizer.transform(texts_list)
        if hasattr(model, "predict_proba"):
            return model.predict_proba(X)
        else:
            scores = model.decision_function(X)
            if scores.ndim == 1:
                scores = np.vstack([-scores, scores]).T
            probs = np.exp(scores) / np.exp(scores).sum(axis=1, keepdims=True)  # converts into pseudo-prob.
            return probs

    print(f"\nText: {text_instance}")
    print("Predicted Class:", model.predict(vectorizer.transform([text_instance]))[0])
    exp = explainer.explain_instance(text_instance, predict_proba, num_features=10)
    exp.show_in_notebook(text=True)
    return exp


trained_models = {
    "LogisticRegression": lr,
    "MultinomialNB": nb,
    "LinearSVC": lsvm,
    "SGDClassifier": sgd,
    "KNN": knn,
    "RandomForest": rf,
    "GradientBoosting": gb,
    "MLP": mlp
}

idx = 76
for name, model_tuple in trained_models.items():
    print(f"\nModel: {name}")
    try:
        model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple
        exp = explain_with_lime(model,vectorizer,texts_train,idx)
    except Exception as e:
        print(f"Error with {name}: {e}")
'''
# Out:
# 'def explain_with_lime(model,vectorizer,texts,idx):\n    explainer = LimeTextExplainer(class_names=["real","fake"])\n\n    if hasattr(texts,"iloc"):\n      text_instance = texts.iloc[idx]\n    else:\n      text_instance = texts[idx]\n\n    def predict_proba(texts_list):\n        X = vectorizer.transform(texts_list)\n        if hasattr(model, "predict_proba"):\n            return model.predict_proba(X)\n        else:\n            scores = model.decision_function(X)\n            if scores.ndim == 1:\n                scores = np.vstack([-scores, scores]).T\n            probs = np.exp(scores) / np.exp(scores).sum(axis=1, keepdims=True)  # converts into pseudo-prob.\n            return probs\n\n    print(f"\nText: {text_instance}")\n    print("Predicted Class:", model.predict(vectorizer.transform([text_instance]))[0])\n    exp = explainer.explain_instance(text_instance, predict_proba, num_features=10)\n    exp.show_in_notebook(text=True)\n    return exp\n\n\ntrained_models = {\n    "LogisticRegression": lr,\n    "MultinomialNB": nb,\n    "LinearSVC": lsvm,\n    "SGDClassifier": sgd,\n    "KNN": knn,\n    "RandomForest": rf,\n    "GradientBoosting": gb,\n    "MLP": mlp\n}\n\nidx = 76\nfor name, model_tuple in trained_models.items():\n    print(f"\nModel: {name}")\n    try:\n        model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple\n        exp = explain_with_lime(model,vectorizer,texts_train,idx)\n    except Exception as e:\n        print(f"Error with {name}: {e}")\n'

# %%
trained_models.items()
# Out:
# dict_items([('LogisticRegression', (LogisticRegression(), (0.6535947712418301, 0.6513090084518657, nan, 0.6535947712418301, nan, 0.6524498378942124, nan, 0.6957852748942714, '              precision    recall  f1-score   support\n\n           0       0.66      0.76      0.71       510\n           1       0.64      0.51      0.57       408\n\n    accuracy                           0.65       918\n   macro avg       0.65      0.64      0.64       918\nweighted avg       0.65      0.65      0.65       918\n'))), ('MultinomialNB', (ComplementNB(), (0.6394335511982571, 0.6409007330993147, nan, 0.6394335511982571, nan, 0.6401662515001447, nan, 0.699543444828912, '              precision    recall  f1-score   support\n\n           0       0.68      0.66      0.67       510\n           1       0.59      0.61      0.60       408\n\n    accuracy                           0.64       918\n   macro avg       0.64      0.64      0.64       918\nweighted avg       0.64      0.64      0.64       918\n'))), ('LinearSVC', (LinearSVC(dual=False), (0.6514161220043573, 0.648904818797292, nan, 0.6514161220043573, nan, 0.6501579953674713, nan, nan, '              precision    recall  f1-score   support\n\n           0       0.67      0.73      0.70       510\n           1       0.62      0.55      0.58       408\n\n    accuracy                           0.65       918\n   macro avg       0.65      0.64      0.64       918\nweighted avg       0.65      0.65      0.65       918\n'))), ('SGDClassifier', (SGDClassifier(), (0.6470588235294118, 0.6442906574394464, nan, 0.6470588235294118, nan, 0.6456717235327977, nan, nan, '              precision    recall  f1-score   support\n\n           0       0.66      0.75      0.70       510\n           1       0.62      0.52      0.57       408\n\n    accuracy                           0.65       918\n   macro avg       0.64      0.63      0.63       918\nweighted avg       0.64      0.65      0.64       918\n'))), ('SVM', (SVC(probability=True), (0.6688453159041394, 0.6685001833516685, nan, 0.6688453159041394, nan, 0.6686726550932419, nan, 0.7130358515955402, '              precision    recall  f1-score   support\n\n           0       0.67      0.80      0.73       510\n           1       0.67      0.51      0.58       408\n\n    accuracy                           0.67       918\n   macro avg       0.67      0.65      0.65       918\nweighted avg       0.67      0.67      0.66       918\n'))), ('KNN', (KNeighborsClassifier(n_jobs=-1, weights='distance'), (0.6296296296296297, 0.6264722477685811, nan, 0.6296296296296297, nan, 0.6280469204463737, nan, 0.6697592272203, '              precision    recall  f1-score   support\n\n           0       0.65      0.72      0.68       510\n           1       0.60      0.52      0.55       408\n\n    accuracy                           0.63       918\n   macro avg       0.62      0.62      0.62       918\nweighted avg       0.63      0.63      0.63       918\n'))), ('RandomForest', (RandomForestClassifier(n_jobs=-1), (0.6699346405228758, 0.6687594586414148, nan, 0.6699346405228758, nan, 0.6693464837614129, nan, 0.7223904267589389, '              precision    recall  f1-score   support\n\n           0       0.67      0.78      0.73       510\n           1       0.66      0.53      0.59       408\n\n    accuracy                           0.67       918\n   macro avg       0.67      0.66      0.66       918\nweighted avg       0.67      0.67      0.66       918\n'))), ('GradientBoosting', (GradientBoostingClassifier(n_estimators=200), (0.6187363834422658, 0.6229819563152896, nan, 0.6187363834422658, nan, 0.6208518618368444, nan, 0.6699058054594387, '              precision    recall  f1-score   support\n\n           0       0.61      0.85      0.71       510\n           1       0.63      0.34      0.44       408\n\n    accuracy                           0.62       918\n   macro avg       0.62      0.59      0.58       918\nweighted avg       0.62      0.62      0.59       918\n')) ...
#               verbose=True), (0.6230936819172114, 0.6338020118884317, nan, 0.6230936819172114, nan, 0.6284021812156151, nan, 0.691142829680892, '              precision    recall  f1-score   support\n\n           0       0.69      0.58      0.63       510\n           1       0.56      0.67      0.61       408\n\n    accuracy                           0.62       918\n   macro avg       0.63      0.63      0.62       918\nweighted avg       0.63      0.62      0.62       918\n')))])

# %%
# return the common words between models and show the word weight
def compare_lime_words(trained_models,vectorizer,texts,idx):

    words_by_model = {} # {word1:[(model1],"fake",weight1),(model2,"fake",weight2)}

    for name, model_tuple in trained_models.items():
        try:
            if isinstance(model_tuple,tuple):
              model = model_tuple[0]
            else:
              model = model_tuple
            exp = explain_with_lime(model,vectorizer,texts,idx)
            words = exp.as_list() # return a [(word1,weight1),(word2,weight2),...]

            for w,weight in words:
              # fake is 1 and real is 0
              if weight > 0:
                assign = "fake"
              else:
                assign = "real"
              if w not in words_by_model:
                words_by_model[w] = []
              words_by_model[w].append((name,assign,abs(weight)))

        except Exception:
            pass

    # to keep only the words that are on multiple models
    shared_words = {}
    for w,info in words_by_model.items():
      if len(info) > 1:
        shared_words[w] = info

    if not shared_words:
        return pd.DataFrame(columns=["word","avg_weight"])

    rows = []
    for word,infos in shared_words.items():
        avg_weight = np.mean([x[2] for x in infos])
        directions = {x[0]: x[1] for x in infos}  # builds the direction of the word (fake or real)
        rows.append({"word":word, "avg_weight":avg_weight, **directions})

    df = pd.DataFrame(rows).sort_values("avg_weight", ascending=False).fillna("-")
    return df


idx = 125  # sentence that will be analyzed
df_common = compare_lime_words(trained_models,vectorizer,texts_test,idx)
df_common
# Out:
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 0
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#
# Text: quando alguém rua apresentar receita pedir trocadinho comprar remédio , passagem ônibus criançar colo pedir comprar leite , reflitar bem valer pena
# Predicted Class: 1
#           word  avg_weight LogisticRegression MultinomialNB LinearSVC  \
# 0        valer    0.128418               fake          fake      fake
# 1         pena    0.125838               fake          fake      fake
# 2      comprar    0.089641               fake          fake      fake
# 3       quando    0.066396               real          real      real
# 5        pedir    0.047738               fake          real      fake
# 6   apresentar    0.032148               real          real      real
# 4          bem    0.028838               real          real      real
# 7          rua    0.021280               real          real      real
# 9       alguém    0.009419               fake          real         -
# 8      receita    0.004656               real             -         -
# 10        colo    0.002517                  -             -      fake
#
#    SGDClassifier   SVM   KNN RandomForest GradientBoosting   MLP
# 0           fake  fake  fake         fake             fake  fake
# 1           fake  fake  fake         fake             fake  fake
# 2           fake  fake  real         fake             fake  fake
# 3           real  real     -         real             real  real
# 5           fake  fake  real         fake             real  fake
# 6           real  real  real         fake             real  fake
# 4           real  real  real         real             real  real
# 7           real  real  real         real             real  fake
# 9           fake     -  real         fake             real  real
# 8              -  real  fake         fake             real     -
# 10             -  fake     -            -                -  real

# %% [markdown]
# ### Experience 2 - Global Approach

# %% [markdown]
# Iterate over 300 examples, so i can check the number of ocurrences the models have in common and verify if they are learning important features (words)

# %% [markdown]
# - with test set

# %%
def explain_with_lime(model,vectorizer,texts,idx):
    explainer = LimeTextExplainer(class_names=["real","fake"])

    # checking if texts is a pandas series or a python list
    if hasattr(texts,"iloc"):
      text_instance = texts.iloc[idx]
    else:
      text_instance = texts[idx]

    def predict_proba(texts_list):
        X = vectorizer.transform(texts_list)  # for the texts_test
        if hasattr(model,"predict_proba"):  # checking if the model has "predict_proba" attribute
            return model.predict_proba(X)
        else:
            scores = model.decision_function(X)
            if scores.ndim == 1:
                scores = np.vstack([-scores, scores]).T
            probs = np.exp(scores) / np.exp(scores).sum(axis=1, keepdims=True)
            return probs

    exp = explainer.explain_instance(text_instance, predict_proba, num_features=10)
    return exp.as_list()  # return the list [(word,weight)]



def generate_lime_explanations(trained_models,vectorizer,texts,n_samples=300):
    results = []

    for name, model_tuple in trained_models.items():
        if isinstance(model_tuple,tuple):
          model = model_tuple[0]
        else:
          model = model_tuple

        if not hasattr(model,"predict_proba") and not hasattr(model,"decision_function"):
            print(f"{name} doesn´t support LIME (no probability or decision_function).")
            continue

        print(f"\nGenerating LIME explanations for: {name}")
        for i in tqdm(range(min(n_samples, len(texts)))):
            try:
                exp = explain_with_lime(model,vectorizer,texts,i)
                # {'model':'model_name','word':'word1','weight':weight1,'sample_idx':index,'dominant_class':'class (fake or real)'}
                for word,weight in exp:
                    results.append({
                        "model": name,
                        "word": word,
                        "weight": weight,
                        "sample_idx": i,
                        "dominant_class": "fake" if weight > 0 else "real"
                    })
            except Exception as e:
                print(f"Error on {name} in sample {i}: {e}")

    return pd.DataFrame(results)



def aggregate_word_influence(df):
    agg = (
        df.groupby(["model","word","dominant_class"])
          .agg(avg_weight=("weight","mean"),
               avg_abs_weight=("weight",lambda x: np.mean(np.abs(x))),
               n_occurrences=("weight","count"))
          .reset_index()
    )
    return agg



def plot_weight_distribution(agg_df,model_name):
    subset = agg_df[agg_df["model"] == model_name]
    plt.figure(figsize=(8,5))
    sns.histplot(data=subset, x="avg_weight", hue="dominant_class", bins=30, kde=True)
    plt.title(f"LIME - weigths distribution - {model_name}")
    plt.xlabel("Average weight (LIME)")
    plt.ylabel("Frequency")
    plt.show()


def show_top_words(agg_df,model_name,top_n=10):
    subset = agg_df[agg_df["model"] == model_name]
    top_fake = subset[subset["dominant_class"] == "fake"].nlargest(top_n, "avg_abs_weight")
    top_real = subset[subset["dominant_class"] == "real"].nlargest(top_n, "avg_abs_weight")

    print(f"\nTop {top_n} most explicative words for Fake ({model_name})")
    display(top_fake[["word", "avg_abs_weight", "avg_weight", "n_occurrences"]])

    print(f"\nTop {top_n} most explicative words for REAL ({model_name})")
    display(top_real[["word", "avg_abs_weight", "avg_weight", "n_occurrences"]])


lime_df = generate_lime_explanations(trained_models,vectorizer,texts_test,n_samples=300)
agg_df = aggregate_word_influence(lime_df)

agg_df.to_csv(METRICS_PATH / "lime_global_results.csv",index=False)
print("\nLIME results saved.")

for model_name in agg_df["model"].unique():
    plot_weight_distribution(agg_df,model_name)
    show_top_words(agg_df,model_name,top_n=10)
# Out:
# Generating LIME explanations for: LogisticRegression
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on LogisticRegression in sample 0: low >= high
#   6%|▋         | 19/300 [00:00<00:09, 30.63it/s]
# Error on LogisticRegression in sample 15: low >= high
#  12%|█▏        | 35/300 [00:01<00:08, 30.96it/s]
# Error on LogisticRegression in sample 31: low >= high
#  19%|█▉        | 58/300 [00:01<00:07, 30.43it/s]
# Error on LogisticRegression in sample 52: low >= high
#  24%|██▍       | 72/300 [00:02<00:06, 33.08it/s]
# Error on LogisticRegression in sample 65: low >= high
# Error on LogisticRegression in sample 66: low >= high
#  32%|███▏      | 97/300 [00:03<00:06, 30.32it/s]
# Error on LogisticRegression in sample 92: low >= high
# Error on LogisticRegression in sample 98: low >= high
#  44%|████▍     | 132/300 [00:04<00:05, 29.90it/s]
# Error on LogisticRegression in sample 124: low >= high
# Error on LogisticRegression in sample 130: low >= high
#  50%|█████     | 151/300 [00:05<00:04, 31.59it/s]
# Error on LogisticRegression in sample 145: low >= high
# Error on LogisticRegression in sample 147: low >= high
# Error on LogisticRegression in sample 152: low >= high
#  56%|█████▌    | 167/300 [00:05<00:04, 29.04it/s]
# Error on LogisticRegression in sample 162: low >= high
#  59%|█████▊    | 176/300 [00:06<00:03, 33.69it/s]
# Error on LogisticRegression in sample 170: low >= high
# Error on LogisticRegression in sample 171: low >= high
#  67%|██████▋   | 200/300 [00:06<00:03, 32.46it/s]
# Error on LogisticRegression in sample 195: low >= high
# Error on LogisticRegression in sample 196: low >= high
# Error on LogisticRegression in sample 201: low >= high
#  73%|███████▎  | 218/300 [00:07<00:02, 32.94it/s]
# Error on LogisticRegression in sample 214: low >= high
#  75%|███████▌  | 226/300 [00:07<00:02, 31.83it/s]
# Error on LogisticRegression in sample 220: low >= high
# Error on LogisticRegression in sample 221: low >= high
#  79%|███████▉  | 238/300 [00:07<00:02, 30.93it/s]
# Error on LogisticRegression in sample 231: low >= high
#  84%|████████▍ | 253/300 [00:08<00:01, 27.68it/s]
# Error on LogisticRegression in sample 249: low >= high
#  91%|█████████ | 273/300 [00:09<00:00, 28.23it/s]
# Error on LogisticRegression in sample 269: low >= high
# Error on LogisticRegression in sample 274: low >= high
# Error on LogisticRegression in sample 276: low >= high
#  95%|█████████▍| 284/300 [00:09<00:00, 36.67it/s]
# Error on LogisticRegression in sample 279: low >= high
# Error on LogisticRegression in sample 280: low >= high
# Error on LogisticRegression in sample 286: low >= high
# 100%|██████████| 300/300 [00:10<00:00, 29.70it/s]
# Error on LogisticRegression in sample 296: low >= high
#
# Generating LIME explanations for: MultinomialNB
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on MultinomialNB in sample 0: low >= high
#   7%|▋         | 22/300 [00:00<00:09, 30.51it/s]
# Error on MultinomialNB in sample 15: low >= high
#  11%|█▏        | 34/300 [00:01<00:08, 31.11it/s]
# Error on MultinomialNB in sample 31: low >= high
#  19%|█▊        | 56/300 [00:01<00:07, 31.60it/s]
# Error on MultinomialNB in sample 52: low >= high
#  23%|██▎       | 70/300 [00:02<00:06, 33.53it/s]
# Error on MultinomialNB in sample 65: low >= high
# Error on MultinomialNB in sample 66: low >= high
#  33%|███▎      | 98/300 [00:03<00:06, 30.20it/s]
# Error on MultinomialNB in sample 92: low >= high
# Error on MultinomialNB in sample 98: low >= high
#  43%|████▎     | 129/300 [00:04<00:06, 26.27it/s]
# Error on MultinomialNB in sample 124: low >= high
#  44%|████▍     | 133/300 [00:04<00:05, 29.54it/s]
# Error on MultinomialNB in sample 130: low >= high
#  50%|█████     | 150/300 [00:05<00:04, 32.44it/s]
# Error on MultinomialNB in sample 145: low >= high
# Error on MultinomialNB in sample 147: low >= high
# Error on MultinomialNB in sample 152: low >= high
#  55%|█████▌    | 166/300 [00:05<00:04, 30.16it/s]
# Error on MultinomialNB in sample 162: low >= high
#  60%|█████▉    | 179/300 [00:06<00:03, 33.65it/s]
# Error on MultinomialNB in sample 170: low >= high
# Error on MultinomialNB in sample 171: low >= high
#  68%|██████▊   | 204/300 [00:06<00:02, 34.54it/s]
# Error on MultinomialNB in sample 195: low >= high
# Error on MultinomialNB in sample 196: low >= high
# Error on MultinomialNB in sample 201: low >= high
#  72%|███████▏  | 216/300 [00:07<00:02, 32.55it/s]
# Error on MultinomialNB in sample 214: low >= high
#  75%|███████▌  | 225/300 [00:07<00:02, 33.51it/s]
# Error on MultinomialNB in sample 220: low >= high
# Error on MultinomialNB in sample 221: low >= high
#  79%|███████▉  | 237/300 [00:08<00:02, 30.68it/s]
# Error on MultinomialNB in sample 231: low >= high
#  84%|████████▍ | 253/300 [00:08<00:01, 27.00it/s]
# Error on MultinomialNB in sample 249: low >= high
#  91%|█████████ | 273/300 [00:09<00:00, 27.97it/s]
# Error on MultinomialNB in sample 269: low >= high
# Error on MultinomialNB in sample 274: low >= high
# Error on MultinomialNB in sample 276: low >= high
#  95%|█████████▍| 284/300 [00:09<00:00, 36.87it/s]
# Error on MultinomialNB in sample 279: low >= high
# Error on MultinomialNB in sample 280: low >= high
# Error on MultinomialNB in sample 286: low >= high
# 100%|██████████| 300/300 [00:10<00:00, 29.51it/s]
# Error on MultinomialNB in sample 296: low >= high
#
# Generating LIME explanations for: LinearSVC
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on LinearSVC in sample 0: low >= high
#   7%|▋         | 22/300 [00:00<00:09, 30.52it/s]
# Error on LinearSVC in sample 15: low >= high
#  11%|█▏        | 34/300 [00:01<00:08, 31.09it/s]
# Error on LinearSVC in sample 31: low >= high
#  18%|█▊        | 55/300 [00:01<00:08, 30.58it/s]
# Error on LinearSVC in sample 52: low >= high
#  24%|██▍       | 72/300 [00:02<00:06, 32.89it/s]
# Error on LinearSVC in sample 65: low >= high
# Error on LinearSVC in sample 66: low >= high
#  33%|███▎      | 100/300 [00:03<00:06, 31.30it/s]
# Error on LinearSVC in sample 92: low >= high
# Error on LinearSVC in sample 98: low >= high
#  43%|████▎     | 130/300 [00:04<00:06, 26.78it/s]
# Error on LinearSVC in sample 124: low >= high
# Error on LinearSVC in sample 130: low >= high
#  50%|█████     | 150/300 [00:05<00:04, 32.74it/s]
# Error on LinearSVC in sample 145: low >= high
# Error on LinearSVC in sample 147: low >= high
# Error on LinearSVC in sample 152: low >= high
#  55%|█████▌    | 166/300 [00:05<00:04, 30.05it/s]
# Error on LinearSVC in sample 162: low >= high
#  59%|█████▊    | 176/300 [00:06<00:03, 33.76it/s]
# Error on LinearSVC in sample 170: low >= high
# Error on LinearSVC in sample 171: low >= high
#  68%|██████▊   | 205/300 [00:06<00:02, 35.08it/s]
# Error on LinearSVC in sample 195: low >= high
# Error on LinearSVC in sample 196: low >= high
# Error on LinearSVC in sample 201: low >= high
#  73%|███████▎  | 218/300 [00:07<00:02, 33.19it/s]
# Error on LinearSVC in sample 214: low >= high
#  75%|███████▌  | 226/300 [00:07<00:02, 31.72it/s]
# Error on LinearSVC in sample 220: low >= high
# Error on LinearSVC in sample 221: low >= high
#  79%|███████▉  | 238/300 [00:08<00:02, 30.83it/s]
# Error on LinearSVC in sample 231: low >= high
#  84%|████████▍ | 253/300 [00:08<00:01, 27.59it/s]
# Error on LinearSVC in sample 249: low >= high
#  92%|█████████▏| 276/300 [00:09<00:00, 30.24it/s]
# Error on LinearSVC in sample 269: low >= high
# Error on LinearSVC in sample 274: low >= high
# Error on LinearSVC in sample 276: low >= high
#  95%|█████████▌| 286/300 [00:09<00:00, 34.44it/s]
# Error on LinearSVC in sample 279: low >= high
# Error on LinearSVC in sample 280: low >= high
# Error on LinearSVC in sample 286: low >= high
# 100%|██████████| 300/300 [00:10<00:00, 29.47it/s]
# Error on LinearSVC in sample 296: low >= high
#
# Generating LIME explanations for: SGDClassifier
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on SGDClassifier in sample 0: low >= high
#   7%|▋         | 22/300 [00:00<00:08, 31.17it/s]
# Error on SGDClassifier in sample 15: low >= high
#  11%|█▏        | 34/300 [00:01<00:08, 31.33it/s]
# Error on SGDClassifier in sample 31: low >= high
#  19%|█▉        | 57/300 [00:01<00:07, 31.83it/s]
# Error on SGDClassifier in sample 52: low >= high
#  23%|██▎       | 70/300 [00:02<00:06, 34.78it/s]
# Error on SGDClassifier in sample 65: low >= high
# Error on SGDClassifier in sample 66: low >= high
#  33%|███▎      | 100/300 [00:03<00:06, 32.02it/s]
# Error on SGDClassifier in sample 92: low >= high
# Error on SGDClassifier in sample 98: low >= high
#  44%|████▍     | 132/300 [00:04<00:05, 29.66it/s]
# Error on SGDClassifier in sample 124: low >= high
# Error on SGDClassifier in sample 130: low >= high
#  50%|█████     | 151/300 [00:05<00:04, 31.43it/s]
# Error on SGDClassifier in sample 145: low >= high
# Error on SGDClassifier in sample 147: low >= high
# Error on SGDClassifier in sample 152: low >= high
#  56%|█████▌    | 167/300 [00:05<00:04, 29.13it/s]
# Error on SGDClassifier in sample 162: low >= high
#  59%|█████▊    | 176/300 [00:06<00:03, 33.03it/s]
# Error on SGDClassifier in sample 170: low >= high
# Error on SGDClassifier in sample 171: low >= high
#  68%|██████▊   | 205/300 [00:06<00:02, 34.73it/s]
# Error on SGDClassifier in sample 195: low >= high
# Error on SGDClassifier in sample 196: low >= high
# Error on SGDClassifier in sample 201: low >= high
#  73%|███████▎  | 218/300 [00:07<00:02, 32.84it/s]
# Error on SGDClassifier in sample 214: low >= high
#  75%|███████▌  | 226/300 [00:07<00:02, 31.56it/s]
# Error on SGDClassifier in sample 220: low >= high
# Error on SGDClassifier in sample 221: low >= high
#  79%|███████▉  | 238/300 [00:08<00:02, 30.31it/s]
# Error on SGDClassifier in sample 231: low >= high
#  85%|████████▌ | 255/300 [00:08<00:01, 26.75it/s]
# Error on SGDClassifier in sample 249: low >= high
#  92%|█████████▏| 276/300 [00:09<00:00, 30.59it/s]
# Error on SGDClassifier in sample 269: low >= high
# Error on SGDClassifier in sample 274: low >= high
# Error on SGDClassifier in sample 276: low >= high
#  95%|█████████▌| 286/300 [00:09<00:00, 34.38it/s]
# Error on SGDClassifier in sample 279: low >= high
# Error on SGDClassifier in sample 280: low >= high
# Error on SGDClassifier in sample 286: low >= high
# 100%|██████████| 300/300 [00:10<00:00, 29.52it/s]
# Error on SGDClassifier in sample 296: low >= high
#
# Generating LIME explanations for: SVM
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on SVM in sample 0: low >= high
#   6%|▌         | 17/300 [00:03<00:37,  7.64it/s]
# Error on SVM in sample 15: low >= high
#  11%|█         | 33/300 [00:06<00:41,  6.36it/s]
# Error on SVM in sample 31: low >= high
#  17%|█▋        | 52/300 [00:10<00:38,  6.40it/s]
# Error on SVM in sample 52: low >= high
#  23%|██▎       | 68/300 [00:13<00:28,  8.17it/s]
# Error on SVM in sample 65: low >= high
# Error on SVM in sample 66: low >= high
#  31%|███▏      | 94/300 [00:20<00:37,  5.54it/s]
# Error on SVM in sample 92: low >= high
#  33%|███▎      | 98/300 [00:20<00:39,  5.06it/s]
# Error on SVM in sample 98: low >= high
#  41%|████▏     | 124/300 [00:27<00:34,  5.06it/s]
# Error on SVM in sample 124: low >= high
#  44%|████▍     | 132/300 [00:28<00:26,  6.30it/s]
# Error on SVM in sample 130: low >= high
#  48%|████▊     | 145/300 [00:31<00:27,  5.57it/s]
# Error on SVM in sample 145: low >= high
#  50%|████▉     | 149/300 [00:32<00:19,  7.85it/s]
# Error on SVM in sample 147: low >= high
#  51%|█████▏    | 154/300 [00:33<00:24,  6.01it/s]
# Error on SVM in sample 152: low >= high
#  55%|█████▍    | 164/300 [00:35<00:21,  6.21it/s]
# Error on SVM in sample 162: low >= high
#  58%|█████▊    | 173/300 [00:37<00:16,  7.72it/s]
# Error on SVM in sample 170: low >= high
# Error on SVM in sample 171: low >= high
#  65%|██████▌   | 195/300 [00:42<00:29,  3.58it/s]
# Error on SVM in sample 195: low >= high
# Error on SVM in sample 196: low >= high
#  67%|██████▋   | 201/300 [00:43<00:18,  5.40it/s]
# Error on SVM in sample 201: low >= high
#  71%|███████▏  | 214/300 [00:45<00:18,  4.71it/s]
# Error on SVM in sample 214: low >= high
#  74%|███████▍  | 223/300 [00:47<00:12,  6.02it/s]
# Error on SVM in sample 220: low >= high
# Error on SVM in sample 221: low >= high
#  77%|███████▋  | 231/300 [00:49<00:19,  3.60it/s]
# Error on SVM in sample 231: low >= high
#  84%|████████▎ | 251/300 [00:53<00:07,  6.30it/s]
# Error on SVM in sample 249: low >= high
#  90%|████████▉ | 269/300 [00:58<00:09,  3.34it/s]
# Error on SVM in sample 269: low >= high
#  91%|█████████▏| 274/300 [00:59<00:05,  4.74it/s]
# Error on SVM in sample 274: low >= high
#  93%|█████████▎| 278/300 [01:00<00:03,  6.94it/s]
# Error on SVM in sample 276: low >= high
#  93%|█████████▎| 279/300 [01:00<00:04,  4.96it/s]
# Error on SVM in sample 279: low >= high
# Error on SVM in sample 280: low >= high
#  95%|█████████▌| 286/300 [01:01<00:02,  6.16it/s]
# Error on SVM in sample 286: low >= high
#  99%|█████████▊| 296/300 [01:03<00:00,  4.32it/s]
# Error on SVM in sample 296: low >= high
# 100%|██████████| 300/300 [01:04<00:00,  4.63it/s]
# Generating LIME explanations for: KNN
#   1%|          | 2/300 [00:00<00:16, 18.24it/s]
# Error on KNN in sample 0: low >= high
#   6%|▌         | 17/300 [00:01<00:23, 12.29it/s]
# Error on KNN in sample 15: low >= high
#  11%|█▏        | 34/300 [00:03<00:23, 11.35it/s]
# Error on KNN in sample 31: low >= high
#  18%|█▊        | 55/300 [00:05<00:21, 11.49it/s]
# Error on KNN in sample 52: low >= high
#  23%|██▎       | 69/300 [00:06<00:16, 13.64it/s]
# Error on KNN in sample 65: low >= high
# Error on KNN in sample 66: low >= high
#  32%|███▏      | 95/300 [00:09<00:17, 11.62it/s]
# Error on KNN in sample 92: low >= high
#  33%|███▎      | 99/300 [00:09<00:15, 13.15it/s]
# Error on KNN in sample 98: low >= high
#  42%|████▏     | 126/300 [00:12<00:16, 10.65it/s]
# Error on KNN in sample 124: low >= high
#  44%|████▍     | 133/300 [00:13<00:14, 11.89it/s]
# Error on KNN in sample 130: low >= high
#  49%|████▉     | 147/300 [00:14<00:13, 11.76it/s]
# Error on KNN in sample 145: low >= high
# Error on KNN in sample 147: low >= high
#  52%|█████▏    | 155/300 [00:15<00:12, 11.88it/s]
# Error on KNN in sample 152: low >= high
#  54%|█████▍    | 163/300 [00:15<00:11, 11.43it/s]
# Error on KNN in sample 162: low >= high
#  58%|█████▊    | 173/300 [00:16<00:09, 12.86it/s]
# Error on KNN in sample 170: low >= high
# Error on KNN in sample 171: low >= high
#  66%|██████▌   | 198/300 [00:19<00:07, 12.99it/s]
# Error on KNN in sample 195: low >= high
# Error on KNN in sample 196: low >= high
#  68%|██████▊   | 203/300 [00:19<00:07, 13.33it/s]
# Error on KNN in sample 201: low >= high
#  72%|███████▏  | 216/300 [00:20<00:07, 11.50it/s]
# Error on KNN in sample 214: low >= high
#  75%|███████▍  | 224/300 [00:21<00:06, 12.42it/s]
# Error on KNN in sample 220: low >= high
# Error on KNN in sample 221: low >= high
#  78%|███████▊  | 234/300 [00:22<00:06, 10.74it/s]
# Error on KNN in sample 231: low >= high
#  84%|████████▎ | 251/300 [00:24<00:04, 10.54it/s]
# Error on KNN in sample 249: low >= high
#  90%|█████████ | 271/300 [00:26<00:02, 10.42it/s]
# Error on KNN in sample 269: low >= high
#  92%|█████████▏| 276/300 [00:26<00:02, 11.92it/s]
# Error on KNN in sample 274: low >= high
# Error on KNN in sample 276: low >= high
#  94%|█████████▍| 282/300 [00:27<00:01, 14.70it/s]
# Error on KNN in sample 279: low >= high
# Error on KNN in sample 280: low >= high
#  96%|█████████▌| 288/300 [00:27<00:00, 13.51it/s]
# Error on KNN in sample 286: low >= high
#  99%|█████████▉| 298/300 [00:28<00:00, 12.17it/s]
# Error on KNN in sample 296: low >= high
# 100%|██████████| 300/300 [00:28<00:00, 10.36it/s]
# Generating LIME explanations for: RandomForest
#   1%|          | 3/300 [00:00<00:15, 19.43it/s]
# Error on RandomForest in sample 0: low >= high
#   6%|▌         | 18/300 [00:01<00:17, 15.75it/s]
# Error on RandomForest in sample 15: low >= high
#  11%|█         | 33/300 [00:02<00:17, 15.59it/s]
# Error on RandomForest in sample 31: low >= high
#  18%|█▊        | 54/300 [00:03<00:16, 14.71it/s]
# Error on RandomForest in sample 52: low >= high
#  23%|██▎       | 68/300 [00:04<00:13, 17.81it/s]
# Error on RandomForest in sample 65: low >= high
# Error on RandomForest in sample 66: low >= high
#  32%|███▏      | 95/300 [00:06<00:13, 15.39it/s]
# Error on RandomForest in sample 92: low >= high
#  33%|███▎      | 100/300 [00:06<00:11, 16.81it/s]
# Error on RandomForest in sample 98: low >= high
#  42%|████▏     | 127/300 [00:08<00:11, 14.82it/s]
# Error on RandomForest in sample 124: low >= high
#  44%|████▍     | 132/300 [00:09<00:10, 15.73it/s]
# Error on RandomForest in sample 130: low >= high
#  49%|████▉     | 147/300 [00:10<00:10, 15.08it/s]
# Error on RandomForest in sample 145: low >= high
# Error on RandomForest in sample 147: low >= high
#  52%|█████▏    | 155/300 [00:10<00:08, 16.68it/s]
# Error on RandomForest in sample 152: low >= high
#  55%|█████▍    | 164/300 [00:11<00:08, 15.53it/s]
# Error on RandomForest in sample 162: low >= high
#  58%|█████▊    | 174/300 [00:12<00:07, 17.65it/s]
# Error on RandomForest in sample 170: low >= high
# Error on RandomForest in sample 171: low >= high
#  66%|██████▌   | 198/300 [00:13<00:05, 18.35it/s]
# Error on RandomForest in sample 195: low >= high
# Error on RandomForest in sample 196: low >= high
#  68%|██████▊   | 203/300 [00:13<00:05, 17.48it/s]
# Error on RandomForest in sample 201: low >= high
#  72%|███████▏  | 216/300 [00:14<00:05, 16.50it/s]
# Error on RandomForest in sample 214: low >= high
#  75%|███████▍  | 224/300 [00:15<00:04, 17.50it/s]
# Error on RandomForest in sample 220: low >= high
# Error on RandomForest in sample 221: low >= high
#  78%|███████▊  | 233/300 [00:15<00:04, 15.90it/s]
# Error on RandomForest in sample 231: low >= high
#  84%|████████▍ | 253/300 [00:17<00:03, 13.52it/s]
# Error on RandomForest in sample 249: low >= high
#  91%|█████████ | 272/300 [00:18<00:01, 15.52it/s]
# Error on RandomForest in sample 269: low >= high
#  93%|█████████▎| 278/300 [00:19<00:01, 18.94it/s]
# Error on RandomForest in sample 274: low >= high
# Error on RandomForest in sample 276: low >= high
# Error on RandomForest in sample 279: low >= high
# Error on RandomForest in sample 280: low >= high
#  96%|█████████▌| 288/300 [00:19<00:00, 18.93it/s]
# Error on RandomForest in sample 286: low >= high
# 100%|██████████| 300/300 [00:20<00:00, 14.70it/s]
# Error on RandomForest in sample 296: low >= high
#
# Generating LIME explanations for: GradientBoosting
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on GradientBoosting in sample 0: low >= high
#   7%|▋         | 21/300 [00:00<00:10, 26.55it/s]
# Error on GradientBoosting in sample 15: low >= high
#  11%|█▏        | 34/300 [00:01<00:09, 27.00it/s]
# Error on GradientBoosting in sample 31: low >= high
#  19%|█▊        | 56/300 [00:02<00:09, 26.94it/s]
# Error on GradientBoosting in sample 52: low >= high
#  23%|██▎       | 70/300 [00:02<00:07, 30.41it/s]
# Error on GradientBoosting in sample 65: low >= high
# Error on GradientBoosting in sample 66: low >= high
#  32%|███▏      | 96/300 [00:03<00:07, 26.48it/s]
# Error on GradientBoosting in sample 92: low >= high
# Error on GradientBoosting in sample 98: low >= high
#  43%|████▎     | 130/300 [00:05<00:07, 23.57it/s]
# Error on GradientBoosting in sample 124: low >= high
# Error on GradientBoosting in sample 130: low >= high
#  50%|█████     | 151/300 [00:05<00:05, 27.92it/s]
# Error on GradientBoosting in sample 145: low >= high
# Error on GradientBoosting in sample 147: low >= high
#  53%|█████▎    | 158/300 [00:06<00:05, 27.41it/s]
# Error on GradientBoosting in sample 152: low >= high
#  55%|█████▌    | 165/300 [00:06<00:05, 26.73it/s]
# Error on GradientBoosting in sample 162: low >= high
#  59%|█████▊    | 176/300 [00:06<00:04, 28.74it/s]
# Error on GradientBoosting in sample 170: low >= high
# Error on GradientBoosting in sample 171: low >= high
#  68%|██████▊   | 203/300 [00:07<00:03, 30.62it/s]
# Error on GradientBoosting in sample 195: low >= high
# Error on GradientBoosting in sample 196: low >= high
# Error on GradientBoosting in sample 201: low >= high
#  72%|███████▏  | 217/300 [00:08<00:02, 29.52it/s]
# Error on GradientBoosting in sample 214: low >= high
#  75%|███████▌  | 225/300 [00:08<00:02, 30.00it/s]
# Error on GradientBoosting in sample 220: low >= high
# Error on GradientBoosting in sample 221: low >= high
#  79%|███████▊  | 236/300 [00:09<00:02, 26.97it/s]
# Error on GradientBoosting in sample 231: low >= high
#  84%|████████▎ | 251/300 [00:09<00:02, 22.47it/s]
# Error on GradientBoosting in sample 249: low >= high
#  93%|█████████▎| 278/300 [00:10<00:00, 30.57it/s]
# Error on GradientBoosting in sample 269: low >= high
# Error on GradientBoosting in sample 274: low >= high
# Error on GradientBoosting in sample 276: low >= high
#  95%|█████████▌| 286/300 [00:11<00:00, 30.87it/s]
# Error on GradientBoosting in sample 279: low >= high
# Error on GradientBoosting in sample 280: low >= high
# Error on GradientBoosting in sample 286: low >= high
# 100%|██████████| 300/300 [00:11<00:00, 25.94it/s]
# Error on GradientBoosting in sample 296: low >= high
#
# Generating LIME explanations for: MLP
#   0%|          | 0/300 [00:00<?, ?it/s]
# Error on MLP in sample 0: low >= high
#   7%|▋         | 22/300 [00:00<00:09, 29.17it/s]
# Error on MLP in sample 15: low >= high
#  12%|█▏        | 37/300 [00:01<00:09, 28.21it/s]
# Error on MLP in sample 31: low >= high
#  19%|█▉        | 58/300 [00:02<00:08, 28.51it/s]
# Error on MLP in sample 52: low >= high
#  23%|██▎       | 70/300 [00:02<00:07, 32.36it/s]
# Error on MLP in sample 65: low >= high
# Error on MLP in sample 66: low >= high
#  33%|███▎      | 98/300 [00:03<00:07, 28.65it/s]
# Error on MLP in sample 92: low >= high
# Error on MLP in sample 98: low >= high
#  43%|████▎     | 129/300 [00:04<00:06, 24.86it/s]
# Error on MLP in sample 124: low >= high
#  44%|████▍     | 133/300 [00:04<00:05, 28.26it/s]
# Error on MLP in sample 130: low >= high
#  50%|█████     | 151/300 [00:05<00:05, 29.64it/s]
# Error on MLP in sample 145: low >= high
# Error on MLP in sample 147: low >= high
#  52%|█████▏    | 155/300 [00:05<00:04, 30.77it/s]
# Error on MLP in sample 152: low >= high
#  56%|█████▌    | 167/300 [00:06<00:04, 28.13it/s]
# Error on MLP in sample 162: low >= high
#  58%|█████▊    | 175/300 [00:06<00:03, 32.69it/s]
# Error on MLP in sample 170: low >= high
# Error on MLP in sample 171: low >= high
#  68%|██████▊   | 203/300 [00:07<00:02, 32.83it/s]
# Error on MLP in sample 195: low >= high
# Error on MLP in sample 196: low >= high
# Error on MLP in sample 201: low >= high
#  73%|███████▎  | 219/300 [00:07<00:02, 29.52it/s]
# Error on MLP in sample 214: low >= high
#  75%|███████▍  | 224/300 [00:07<00:02, 32.28it/s]
# Error on MLP in sample 220: low >= high
# Error on MLP in sample 221: low >= high
#  80%|███████▉  | 239/300 [00:08<00:02, 29.37it/s]
# Error on MLP in sample 231: low >= high
#  85%|████████▌ | 255/300 [00:09<00:01, 25.46it/s]
# Error on MLP in sample 249: low >= high
#  91%|█████████▏| 274/300 [00:09<00:00, 26.78it/s]
# Error on MLP in sample 269: low >= high
# Error on MLP in sample 274: low >= high
# Error on MLP in sample 276: low >= high
#  95%|█████████▍| 284/300 [00:10<00:00, 35.58it/s]
# Error on MLP in sample 279: low >= high
# Error on MLP in sample 280: low >= high
# Error on MLP in sample 286: low >= high
# 100%|██████████| 300/300 [00:10<00:00, 28.11it/s]
# Error on MLP in sample 296: low >= high
#
# LIME results saved.
# Top 10 most explicative words for Fake (GradientBoosting)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 692       padre        0.202786    0.202786              1
# 831     quebrar        0.171676    0.171676              1
# 1036      áudio        0.168476    0.168476              1
# 681       olher        0.152204    0.152204              1
# 148      apenas        0.150760    0.150760              1
# 381   eleitoral        0.148579    0.148579              1
# 938          só        0.148208    0.148208              1
# 310        dado        0.147805    0.147805              1
# 377      eleger        0.146624    0.146624              1
# 989     urgente        0.145464    0.145464              7
# Top 10 most explicative words for REAL (GradientBoosting)
#          word  avg_abs_weight  avg_weight  n_occurrences
# 579     linkr        0.250940   -0.250940              4
# 954  tocantim        0.212531   -0.212531              2
# 457     feira        0.160909   -0.160909              2
# 151     apoio        0.140666   -0.140666              4
# 26         30        0.132092   -0.132092              1
# 935    sábado        0.121786   -0.121786              1
# 165     assim        0.114045   -0.114045              1
# 229  carreato        0.109022   -0.109022              1
# 219  campanha        0.108486   -0.108486              6
# 480   galerar        0.106175   -0.106175              1
# Top 10 most explicative words for Fake (KNN)
#           word  avg_abs_weight  avg_weight  n_occurrences
# 1397     dever        0.598767    0.598767              1
# 1156     agora        0.496470    0.496470              1
# 1097     Filho        0.467055    0.467055              1
# 2025        só        0.439202    0.439202              1
# 1634     juíza        0.400763    0.400763              1
# 1475  esquerda        0.396762    0.396762              2
# 1137   absurdo        0.392393    0.392393              2
# 1051        15        0.360801    0.360801              2
# 1902  publicar        0.350198    0.350198              3
# 1253       bor        0.347278    0.347278              1
# Top 10 most explicative words for REAL (KNN)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 1338  continuar        0.536435   -0.536435              1
# 1915        que        0.444711   -0.444711              1
# 1587   histório        0.398237   -0.398237              1
# 1228       ação        0.398205   -0.398205              1
# 1092     Carlos        0.362746   -0.362746              1
# 1858        pra        0.340644   -0.340644              1
# 2062       tudo        0.316437   -0.316437              1
# 1991        ser        0.315654   -0.315654              1
# 1046         08        0.284361   -0.284361              1
# 1637        kkk        0.283718   -0.283718              1
# Top 10 most explicative words for Fake (LinearSVC)
#             word  avg_abs_weight  avg_weight  n_occurrences
# 2290      atacar        0.404989    0.404989              1
# 2713     mentira        0.396727    0.396727              1
# 2429        dado        0.372488    0.372488              1
# 2893    publicar        0.354844    0.354844              3
# 2771       olher        0.340583    0.340583              1
# 2383  comentário        0.337373    0.337373              1
# 2906     quebrar        0.326140    0.326140              1
# 2146          21        0.322636    0.322636              1
# 2871   pretender        0.319365    0.319365              1
# 2944     rouanet        0.313739    0.313739              1
# Top 10 most explicative words for REAL (LinearSVC)
#           word  avg_abs_weight  avg_weight  n_occurrences
# 2203   Supremo        0.435409   -0.435409              2
# 3040        tô        0.426927   -0.426927              1
# 2667      lado        0.377031   -0.377031              3
# 2568     forma        0.365490   -0.365490              1
# 2855    postar        0.320665   -0.320665              2
# 2302      ação        0.309422   -0.309422              1
# 2577  fundador        0.305641   -0.305641              1
# 3013  tocantim        0.302106   -0.302106              2
# 3014     tocar        0.299796   -0.299796              1
# 2757     nosso        0.291809   -0.291809              2
# Top 10 most explicative words for Fake (LogisticRegression)
#           word  avg_abs_weight  avg_weight  n_occurrences
# 3726     olher        0.191934    0.191934              1
# 3791   petista        0.191525    0.191525              5
# 3619     juíza        0.189658    0.189658              1
# 3100        15        0.182660    0.182660              2
# 3960        só        0.180301    0.180301              1
# 3816      povo        0.169989    0.169989              3
# 3250    atacar        0.165151    0.165151              1
# 3141     Filho        0.162675    0.162675              1
# 3853  publicar        0.159308    0.159308              3
# 3481  esquerda        0.151337    0.151337              3
# Top 10 most explicative words for REAL (LogisticRegression)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 3976   tocantim        0.248142   -0.248142              2
# 3261       ação        0.181883   -0.181883              1
# 4004         tô        0.180708   -0.180708              1
# 3623       lado        0.165976   -0.165976              3
# 3164    Supremo        0.155807   -0.155807              2
# 3724         oi        0.152835   -0.152835              2
# 3232      apoio        0.146219   -0.146219              4
# 3850        psl        0.146155   -0.146155              1
# 3115         30        0.144468   -0.144468              1
# 3355  confirmar        0.140583   -0.140583              1
# Top 10 most explicative words for Fake (MLP)
#             word  avg_abs_weight  avg_weight  n_occurrences
# 4643     mentira        0.693665    0.693665              1
# 4107       Filho        0.637635    0.637635              1
# 4313  comentário        0.631475    0.631475              1
# 4302  claramente        0.590517    0.590517              1
# 4884     rouanet        0.573464    0.573464              1
# 4074          21        0.564113    0.564113              1
# 4198      apenas        0.553637    0.553637              1
# 4944       tempo        0.511828    0.511828              1
# 4812   professor        0.485856    0.485856              3
# 4360        dado        0.477949    0.477949              1
# Top 10 most explicative words for REAL (MLP)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 4982         tô        0.614755   -0.614755              1
# 4598       lado        0.558596   -0.558596              3
# 4496      forma        0.553289   -0.553289              1
# 4234       ação        0.493881   -0.493881              1
# 4326  confirmar        0.490249   -0.490249              1
# 4544   histório        0.472540   -0.472540              1
# 4935     sérgio        0.471880   -0.471880              1
# 4134    Supremo        0.455498   -0.455498              2
# 4278   carreato        0.444953   -0.444953              1
# 4208       arma        0.443144   -0.443144              1
# Top 10 most explicative words for Fake (MultinomialNB)
#             word  avg_abs_weight  avg_weight  n_occurrences
# 5082       Filho        0.243188    0.243188              1
# 5568       juíza        0.241832    0.241832              1
# 5360  destruição        0.218476    0.218476              1
# 5817     quebrar        0.208971    0.208971              1
# 5858     rouanet        0.207508    0.207508              1
# 5682       olher        0.207220    0.207220              1
# 5122     absurdo        0.200404    0.200404              2
# 5804    publicar        0.191064    0.191064              3
# 5193      atacar        0.180099    0.180099              1
# 5326     cristão        0.179993    0.179993              1
# Top 10 most explicative words for REAL (MultinomialNB)
#           word  avg_abs_weight  avg_weight  n_occurrences
# 5924  tocantim        0.339842   -0.339842              2
# 5205      ação        0.256643   -0.256643              1
# 5951        tô        0.248967   -0.248967              1
# 5572      lado        0.222037   -0.222037              3
# 5252  carreato        0.219415   -0.219415              1
# 5989     válir        0.204969   -0.204969              2
# 5902     super        0.186410   -0.186410              1
# 5108   Supremo        0.185006   -0.185006              2
# 5598     manhã        0.184939   -0.184939              2
# 5801       psl        0.180210   -0.180210              1
# Top 10 most explicative words for Fake (RandomForest)
#           word  avg_abs_weight  avg_weight  n_occurrences
# 6801  publicar        0.394399    0.394399              3
# 6918        só        0.385142    0.385142              1
# 6556     juíza        0.375593    0.375593              1
# 6337     dever        0.371649    0.371649              1
# 7011     áudio        0.307629    0.307629              1
# 6734   petista        0.287675    0.287675              5
# 6313       dar        0.285262    0.285262              1
# 6612       mil        0.282053    0.282053              1
# 6012        15        0.276341    0.276341              2
# 6401  escrever        0.268085    0.268085              1
# Top 10 most explicative words for REAL (RandomForest)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 6991       você        0.314340   -0.314340              1
# 6961         tô        0.301124   -0.301124              1
# 6177       ação        0.280918   -0.280918              1
# 6559        kkk        0.273481   -0.273481              1
# 6287  continuar        0.265842   -0.265842              1
# 6509   histório        0.263454   -0.263454              1
# 6934   tocantim        0.253817   -0.253817              2
# 7017      único        0.223434   -0.223434              1
# 6449      feira        0.212962   -0.212962              2
# 6512       hoje        0.196230   -0.196230              5
# Top 10 most explicative words for Fake (SGDClassifier)
#             word  avg_abs_weight  avg_weight  n_occurrences
# 7600     mentira        0.723722    0.723722              1
# 7778    publicar        0.517194    0.517194              3
# 7882          só        0.504230    0.504230              1
# 7067       Folha        0.492632    0.492632              1
# 7275  comentário        0.466595    0.466595              1
# 7321        dado        0.460834    0.460834              1
# 7178      atacar        0.450549    0.450549              1
# 7844   segurança        0.433615    0.433615              2
# 7036          21        0.431118    0.431118              1
# 7066       Filho        0.425231    0.425231              1
# Top 10 most explicative words for REAL (SGDClassifier)
#           word  avg_abs_weight  avg_weight  n_occurrences
# 7925        tô        0.558891   -0.558891              1
# 7461     forma        0.537869   -0.537869              1
# 7092   Supremo        0.530933   -0.530933              2
# 7553      lado        0.456339   -0.456339              3
# 7918      tudo        0.435390   -0.435390              1
# 7701     pegar        0.407048   -0.407048              1
# 7738    postar        0.383988   -0.383988              2
# 7469  fundador        0.379329   -0.379329              1
# 7550        já        0.371281   -0.371281              1
# 7042        30        0.366445   -0.366445              1
# Top 10 most explicative words for Fake (SVM)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 8858         só        0.399158    0.399158              1
# 7984         15        0.351766    0.351766              2
# 8085      agora        0.337240    0.337240              1
# 8311      dever        0.334069    0.334069              1
# 8820  segurança        0.299970    0.299970              2
# 8066    absurdo        0.298804    0.298804              2
# 8376   esquerda        0.274851    0.274851              3
# 8917    verdade        0.266483    0.266483              2
# 8026      Filho        0.257419    0.257419              1
# 8142     atacar        0.254956    0.254956              1
# Top 10 most explicative words for REAL (SVM)
#            word  avg_abs_weight  avg_weight  n_occurrences
# 8761        que        0.204779   -0.204779              1
# 8900         tô        0.184603   -0.184603              1
# 8053    Supremo        0.173762   -0.173762              2
# 8745        psl        0.170357   -0.170357              1
# 8518       lado        0.157475   -0.157475              3
# 8950      único        0.157031   -0.157031              1
# 8247  confirmar        0.155237   -0.155237              1
# 8723    prestir        0.150863   -0.150863              1
# 8517        kkk        0.143299   -0.143299              1
# 8035    Justiça        0.141654   -0.141654              1

# %%
def consolidate_global_top_words(agg_df, top_n=10):
    all_top_words = []
    
    for model_name in agg_df['model'].unique():
        subset = agg_df[agg_df["model"] == model_name]
        
        top_fake = subset[subset["dominant_class"] == "fake"].nlargest(top_n, "avg_abs_weight")
        top_real = subset[subset["dominant_class"] == "real"].nlargest(top_n, "avg_abs_weight")
        
        # FAKE words
        for index, row in top_fake.iterrows():
            all_top_words.append({
                'model': model_name,
                'class': 'FAKE',
                'word': row['word'],
                'avg_abs_weight': row['avg_abs_weight'],
                'avg_weight': row['avg_weight'],
                'n_occurrences': row['n_occurrences']
            })
            
        # REAL words
        for index, row in top_real.iterrows():
            all_top_words.append({
                'model': model_name,
                'class': 'REAL',
                'word': row['word'],
                'avg_abs_weight': row['avg_abs_weight'],
                'avg_weight': row['avg_weight'],
                'n_occurrences': row['n_occurrences']
            })
            
    consolidated_df = pd.DataFrame(all_top_words)
    
    return consolidated_df

consolidated_results = consolidate_global_top_words(agg_df, top_n=10)
display(consolidated_results)
# Out:
#                 model class       word  avg_abs_weight  avg_weight  \
# 0    GradientBoosting  FAKE      padre        0.202786    0.202786
# 1    GradientBoosting  FAKE    quebrar        0.171676    0.171676
# 2    GradientBoosting  FAKE      áudio        0.168476    0.168476
# 3    GradientBoosting  FAKE      olher        0.152204    0.152204
# 4    GradientBoosting  FAKE     apenas        0.150760    0.150760
# ..                ...   ...        ...             ...         ...
# 175               SVM  REAL      único        0.157031   -0.157031
# 176               SVM  REAL  confirmar        0.155237   -0.155237
# 177               SVM  REAL    prestir        0.150863   -0.150863
# 178               SVM  REAL        kkk        0.143299   -0.143299
# 179               SVM  REAL    Justiça        0.141654   -0.141654
#
#      n_occurrences
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 175              1
# 176              1
# 177              1
# 178              1
# 179              1
#
# [180 rows x 6 columns]

# %%
word_counts = consolidated_results.groupby('word')['model'].count().sort_values(ascending=False)
word_counts
# Out:
# word
# tô          7
# só          6
# Supremo     6
# lado        6
# publicar    6
#            ..
# mil         1
# nosso       1
# oi          1
# padre       1
# já          1
# Name: model, Length: 81, dtype: int64

# %% [markdown]
# - model_consensus_count: number of models that have the word on the top 10
# - total_n_ocurrences: number of explanations where the word appeared on the top 10 (for de 300 instances)

# %%
def analyze_class_consensus(consolidated_df, top_n_classes=10):
    consensus_counts = consolidated_df.groupby(['word', 'class'])['model'].nunique().reset_index()
    consensus_counts.rename(columns={'model': 'model_consensus_count'}, inplace=True)
    
    avg_metrics = consolidated_df.groupby(['word', 'class']).agg(
        avg_abs_weight=('avg_abs_weight', 'mean'),
        total_n_occurrences=('n_occurrences', 'sum')
    ).reset_index()
    
    final_consensus = pd.merge(consensus_counts, avg_metrics, on=['word', 'class'])
    
    top_fake_consensus = final_consensus[final_consensus['class'] == 'FAKE']
    top_fake_consensus = top_fake_consensus.sort_values(by='model_consensus_count', ascending=False).head(top_n_classes)
    
    top_real_consensus = final_consensus[final_consensus['class'] == 'REAL']
    top_real_consensus = top_real_consensus.sort_values(by='model_consensus_count', ascending=False).head(top_n_classes)
    
    return top_fake_consensus, top_real_consensus

top_fake, top_real = analyze_class_consensus(consolidated_results, top_n_classes=10)

print("\n=========== TOP 10 GLOBAL CONSENSUS (FAKE) ===========")
display(top_fake)

print("\n=========== TOP 10 GLOBAL CONSENSUS (REAL) ===========")
display(top_real)
# Out:
# =========== TOP 10 GLOBAL CONSENSUS (FAKE) ===========
#         word class  model_consensus_count  avg_abs_weight  total_n_occurrences
# 5      Filho  FAKE                      6        0.365534                    6
# 69        só  FAKE                      6        0.342707                    6
# 60  publicar  FAKE                      6        0.327834                   18
# 15    atacar  FAKE                      5        0.291149                    5
# 1         15  FAKE                      4        0.292892                    8
# 49     olher  FAKE                      4        0.222985                    4
# 39     juíza  FAKE                      4        0.301961                    4
# 25      dado  FAKE                      4        0.364769                    4
# 28     dever  FAKE                      3        0.434829                    3
# 63   rouanet  FAKE                      3        0.364904                    3
# =========== TOP 10 GLOBAL CONSENSUS (REAL) ===========
#          word class  model_consensus_count  avg_abs_weight  \
# 74         tô  REAL                      7        0.359425
# 42       lado  REAL                      6        0.322909
# 8     Supremo  REAL                      6        0.322736
# 16       ação  REAL                      6        0.320158
# 71   tocantim  REAL                      5        0.271288
# 37   histório  REAL                      3        0.378077
# 59        psl  REAL                      3        0.165574
# 19   carreato  REAL                      3        0.257797
# 22  confirmar  REAL                      3        0.262023
# 3          30  REAL                      3        0.214335
#
#     total_n_occurrences
# 74                    7
# 42                   18
# 8                    12
# 16                    6
# 71                   10
# 37                    3
# 59                    3
# 19                    3
# 22                    3
# 3                     3

# %%
publicar_consensus = consolidated_results[
    (consolidated_results['word'] == 'publicar') & 
    (consolidated_results['class'] == 'FAKE')
]['model'].unique()

print("Modelos que consideraram 'publicar' no Top 10 FAKE:")
print(publicar_consensus)


publicar_consensus = consolidated_results[
    (consolidated_results['word'] == 'absurdo') & 
    (consolidated_results['class'] == 'FAKE')
]['model'].unique()

print("Modelos que consideraram 'absurdo' no Top 10 FAKE:")
print(publicar_consensus)


publicar_consensus = consolidated_results[
    (consolidated_results['word'] == 'Supremo') & 
    (consolidated_results['class'] == 'REAL')
]['model'].unique()

print("Modelos que consideraram 'Supremo' no Top 10 REAL:")
print(publicar_consensus)


publicar_consensus = consolidated_results[
    (consolidated_results['word'] == 'tocantim') & 
    (consolidated_results['class'] == 'REAL')
]['model'].unique()

print("Modelos que consideraram 'tocantim' no Top 10 REAL:")
print(publicar_consensus)
# Out:
# Modelos que consideraram 'publicar' no Top 10 FAKE:
# ['KNN' 'LinearSVC' 'LogisticRegression' 'MultinomialNB' 'RandomForest'
#  'SGDClassifier']
# Modelos que consideraram 'absurdo' no Top 10 FAKE:
# ['KNN' 'MultinomialNB' 'SVM']
# Modelos que consideraram 'Supremo' no Top 10 REAL:
# ['LinearSVC' 'LogisticRegression' 'MLP' 'MultinomialNB' 'SGDClassifier'
#  'SVM']
# Modelos que consideraram 'tocantim' no Top 10 REAL:
# ['GradientBoosting' 'LinearSVC' 'LogisticRegression' 'MultinomialNB'
#  'RandomForest']

# %% [markdown]
# - Identifying the most stable model

# %% [markdown]
# Calculate the concentration proportion = avg_abs_weight of the most influent word/sum(avg_abs_weight of all words)

# %% [markdown]
# Find the most influent word for each model

# %% [markdown]
#  - Denominator (for each model sum all abg_abs_weight for all the words, resulting on nine rows)

# %%
total_influence = agg_df.groupby('model')['avg_abs_weight'].sum().reset_index()
total_influence.rename(columns={'avg_abs_weight': 'total_abs_weight'}, inplace=True)

# %% [markdown]
#  - Numerator (for each model finds the avg_abs_weight of all the words)

# %%
max_influence = agg_df.loc[agg_df.groupby('model')['avg_abs_weight'].idxmax()].reset_index(drop=True)
max_influence.rename(columns={'avg_abs_weight':'max_abs_weight','word':'max_word'}, inplace=True)
max_influence = max_influence[['model','max_word','max_abs_weight']]

# %% [markdown]
#  - Concentration Proportion

# %%
concentration_df = pd.merge(total_influence, max_influence, on='model')

concentration_df['concentration_ratio'] = concentration_df['max_abs_weight'] / concentration_df['total_abs_weight']

concentration_df = concentration_df.sort_values(by='concentration_ratio', ascending=True)

print("\nConcentration Weight Table ")
display(concentration_df)
# Out:
# Concentration Weight Table
#                 model  total_abs_weight  max_word  max_abs_weight  \
# 2           LinearSVC         57.665263   Supremo        0.435409
# 4                 MLP         88.460405   mentira        0.693665
# 3  LogisticRegression         31.250930  tocantim        0.248142
# 6        RandomForest         43.743263  publicar        0.394399
# 1                 KNN         65.708124     dever        0.598767
# 7       SGDClassifier         76.797846   mentira        0.723722
# 5       MultinomialNB         34.195675  tocantim        0.339842
# 8                 SVM         37.983711        só        0.399158
# 0    GradientBoosting         14.874749     linkr        0.250940
#
#    concentration_ratio
# 2             0.007551
# 4             0.007842
# 3             0.007940
# 6             0.009016
# 1             0.009113
# 7             0.009424
# 5             0.009938
# 8             0.010509
# 0             0.016870

# %% [markdown]
# - By class

# %%
agg_df.columns
# Out:
# Index(['model', 'word', 'dominant_class', 'avg_weight', 'avg_abs_weight',
#        'n_occurrences'],
#       dtype='object')

# %%
total_influence = agg_df.groupby(['model', 'dominant_class'])['avg_abs_weight'].sum().reset_index()
total_influence.rename(columns={'avg_abs_weight': 'total_abs_weight'}, inplace=True)

# %%
max_influence = agg_df.loc[agg_df.groupby(['model', 'dominant_class'])['avg_abs_weight'].idxmax()].reset_index(drop=True)

max_influence.rename(columns={'avg_abs_weight':'max_abs_weight', 'word':'max_word'}, inplace=True)
max_influence = max_influence[['model', 'dominant_class', 'max_word', 'max_abs_weight']]

# %%
concentration_df = pd.merge(total_influence, max_influence, on=['model', 'dominant_class'])

concentration_df['concentration_ratio'] = concentration_df['max_abs_weight'] / concentration_df['total_abs_weight']

concentration_df = concentration_df.sort_values(by='concentration_ratio', ascending=True)

print("\nConcentration Weight Table by Dominant Class")
display(concentration_df)
# Out:
# Concentration Weight Table by Dominant Class
#                  model dominant_class  total_abs_weight   max_word  \
# 6   LogisticRegression           fake         16.345025      olher
# 4            LinearSVC           fake         30.962008     atacar
# 10       MultinomialNB           fake         18.560532      Filho
# 9                  MLP           real         42.070531         tô
# 17                 SVM           real         13.755830        que
# 8                  MLP           fake         46.389874    mentira
# 13        RandomForest           real         19.589342       você
# 14       SGDClassifier           fake         44.864824    mentira
# 5            LinearSVC           real         26.703256    Supremo
# 12        RandomForest           fake         24.153921   publicar
# 16                 SVM           fake         24.227881         só
# 2                  KNN           fake         36.088080      dever
# 7   LogisticRegression           real         14.905905   tocantim
# 15       SGDClassifier           real         31.933022         tô
# 3                  KNN           real         29.620045  continuar
# 11       MultinomialNB           real         15.635142   tocantim
# 0     GradientBoosting           fake          8.136105      padre
# 1     GradientBoosting           real          6.738645      linkr
#
#     max_abs_weight  concentration_ratio
# 6         0.191934             0.011743
# 4         0.404989             0.013080
# 10        0.243188             0.013102
# 9         0.614755             0.014612
# 17        0.204779             0.014887
# 8         0.693665             0.014953
# 13        0.314340             0.016046
# 14        0.723722             0.016131
# 5         0.435409             0.016305
# 12        0.394399             0.016329
# 16        0.399158             0.016475
# 2         0.598767             0.016592
# 7         0.248142             0.016647
# 15        0.558891             0.017502
# 3         0.536435             0.018111
# 11        0.339842             0.021736
# 0         0.202786             0.024924
# 1         0.250940             0.037239

# %%
top_3_words = agg_df.groupby(['model', 'dominant_class']).apply(
    lambda x: x.nlargest(3, 'avg_abs_weight')
).reset_index(drop=True)

# Seleciona as colunas de interesse
top_3_words = top_3_words[['model', 'dominant_class', 'word', 'avg_abs_weight', 'avg_weight']]

print("Top 3 Words (Real e Fake Juntos)")
display(top_3_words)
# Out:
# Top 3 Words (Real e Fake Juntos)
# /var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/ipykernel_2093/740842927.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_3_words = agg_df.groupby(['model', 'dominant_class']).apply(
#                  model dominant_class        word  avg_abs_weight  avg_weight
# 0     GradientBoosting           fake       padre        0.202786    0.202786
# 1     GradientBoosting           fake     quebrar        0.171676    0.171676
# 2     GradientBoosting           fake       áudio        0.168476    0.168476
# 3     GradientBoosting           real       linkr        0.250940   -0.250940
# 4     GradientBoosting           real    tocantim        0.212531   -0.212531
# 5     GradientBoosting           real       feira        0.160909   -0.160909
# 6                  KNN           fake       dever        0.598767    0.598767
# 7                  KNN           fake       agora        0.496470    0.496470
# 8                  KNN           fake       Filho        0.467055    0.467055
# 9                  KNN           real   continuar        0.536435   -0.536435
# 10                 KNN           real         que        0.444711   -0.444711
# 11                 KNN           real    histório        0.398237   -0.398237
# 12           LinearSVC           fake      atacar        0.404989    0.404989
# 13           LinearSVC           fake     mentira        0.396727    0.396727
# 14           LinearSVC           fake        dado        0.372488    0.372488
# 15           LinearSVC           real     Supremo        0.435409   -0.435409
# 16           LinearSVC           real          tô        0.426927   -0.426927
# 17           LinearSVC           real        lado        0.377031   -0.377031
# 18  LogisticRegression           fake       olher        0.191934    0.191934
# 19  LogisticRegression           fake     petista        0.191525    0.191525
# 20  LogisticRegression           fake       juíza        0.189658    0.189658
# 21  LogisticRegression           real    tocantim        0.248142   -0.248142
# 22  LogisticRegression           real        ação        0.181883   -0.181883
# 23  LogisticRegression           real          tô        0.180708   -0.180708
# 24                 MLP           fake     mentira        0.693665    0.693665
# 25                 MLP           fake       Filho        0.637635    0.637635
# 26                 MLP           fake  comentário        0.631475    0.631475
# 27                 MLP           real          tô        0.614755   -0.614755
# 28                 MLP           real        lado        0.558596   -0.558596
# 29                 MLP           real       forma        0.553289   -0.553289
# 30       MultinomialNB           fake       Filho        0.243188    0.243188
# 31       MultinomialNB           fake       juíza        0.241832    0.241832
# 32       MultinomialNB           fake  destruição        0.218476    0.218476
# 33       MultinomialNB           real    tocantim        0.339842   -0.339842
# 34       MultinomialNB           real        ação        0.256643   -0.256643
# 35       MultinomialNB           real          tô        0.248967   -0.248967
# 36        RandomForest           fake    publicar        0.394399    0.394399
# 37        RandomForest           fake          só        0.385142    0.385142
# 38        RandomForest           fake       juíza        0.375593    0.375593
# 39        RandomForest           real        você        0.314340   -0.314340
# 40        RandomForest           real          tô        0.301124   -0.301124
# 41        RandomForest           real        ação        0.280918   -0.280918
# 42       SGDClassifier           fake     mentira        0.723722    0.723722
# 43       SGDClassifier           fake    publicar        0.517194    0.517194
# 44       SGDClassifier           fake          só        0.504230    0.504230
# 45       SGDClassifier           real          tô        0.558891   -0.558891
# 46       SGDClassifier           real       forma        0.537869   -0.537869
# 47       SGDClassifier           real     Supremo        0.530933   -0.530933
# 48                 SVM           fake          só        0.399158    0.399158
# 49                 SVM           fake          15        0.351766    0.351766
# 50                 SVM           fake       agora        0.337240    0.337240
# 51                 SVM           real         que        0.204779   -0.204779
# 52                 SVM           real          tô        0.184603   -0.184603
# 53                 SVM           real     Supremo        0.173762   -0.173762

# %%
columns_to_group = ['model', 'dominant_class']

def aggregate_word_data(group):
    """Função para agregar as colunas de palavras e pesos numa string."""
    words = group['word'].tolist()
    abs_weights = [f"{w:.4f}" for w in group['avg_abs_weight']]
    weights = [f"{w:.4f}" for w in group['avg_weight']]

    return pd.Series({
        'Top_3_Words': ', '.join(words),
        'Top_3_Abs_Weights': ', '.join(abs_weights),
        'Top_3_Weights': ', '.join(weights)
    })

aggregated_top_3 = top_3_words.groupby(columns_to_group).apply(
    aggregate_word_data
).reset_index()
# Out:
# /var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/ipykernel_2093/2767890467.py:15: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   aggregated_top_3 = top_3_words.groupby(columns_to_group).apply(

# %%
top_3_real_compact = aggregated_top_3[
    aggregated_top_3['dominant_class'] == 'real'
].drop(columns=['dominant_class'])

print("\nTop 3 Words (Compacto) - Class 'REAL'")
display(top_3_real_compact)
# Out:
# Top 3 Words (Compacto) - Class 'REAL'
#                  model               Top_3_Words       Top_3_Abs_Weights  \
# 1     GradientBoosting    linkr, tocantim, feira  0.2509, 0.2125, 0.1609
# 3                  KNN  continuar, que, histório  0.5364, 0.4447, 0.3982
# 5            LinearSVC         Supremo, tô, lado  0.4354, 0.4269, 0.3770
# 7   LogisticRegression        tocantim, ação, tô  0.2481, 0.1819, 0.1807
# 9                  MLP           tô, lado, forma  0.6148, 0.5586, 0.5533
# 11       MultinomialNB        tocantim, ação, tô  0.3398, 0.2566, 0.2490
# 13        RandomForest            você, tô, ação  0.3143, 0.3011, 0.2809
# 15       SGDClassifier        tô, forma, Supremo  0.5589, 0.5379, 0.5309
# 17                 SVM          que, tô, Supremo  0.2048, 0.1846, 0.1738
#
#                 Top_3_Weights
# 1   -0.2509, -0.2125, -0.1609
# 3   -0.5364, -0.4447, -0.3982
# 5   -0.4354, -0.4269, -0.3770
# 7   -0.2481, -0.1819, -0.1807
# 9   -0.6148, -0.5586, -0.5533
# 11  -0.3398, -0.2566, -0.2490
# 13  -0.3143, -0.3011, -0.2809
# 15  -0.5589, -0.5379, -0.5309
# 17  -0.2048, -0.1846, -0.1738

# %%
top_3_fake_compact = aggregated_top_3[
    aggregated_top_3['dominant_class'] == 'fake'
].drop(columns=['dominant_class'])

print("\nTop 3 Words (Compacto) - Class 'FAKE'")
display(top_3_fake_compact)
# Out:
# Top 3 Words (Compacto) - Class 'FAKE'
#                  model                 Top_3_Words       Top_3_Abs_Weights  \
# 0     GradientBoosting       padre, quebrar, áudio  0.2028, 0.1717, 0.1685
# 2                  KNN         dever, agora, Filho  0.5988, 0.4965, 0.4671
# 4            LinearSVC       atacar, mentira, dado  0.4050, 0.3967, 0.3725
# 6   LogisticRegression       olher, petista, juíza  0.1919, 0.1915, 0.1897
# 8                  MLP  mentira, Filho, comentário  0.6937, 0.6376, 0.6315
# 10       MultinomialNB    Filho, juíza, destruição  0.2432, 0.2418, 0.2185
# 12        RandomForest         publicar, só, juíza  0.3944, 0.3851, 0.3756
# 14       SGDClassifier       mentira, publicar, só  0.7237, 0.5172, 0.5042
# 16                 SVM               só, 15, agora  0.3992, 0.3518, 0.3372
#
#              Top_3_Weights
# 0   0.2028, 0.1717, 0.1685
# 2   0.5988, 0.4965, 0.4671
# 4   0.4050, 0.3967, 0.3725
# 6   0.1919, 0.1915, 0.1897
# 8   0.6937, 0.6376, 0.6315
# 10  0.2432, 0.2418, 0.2185
# 12  0.3944, 0.3851, 0.3756
# 14  0.7237, 0.5172, 0.5042
# 16  0.3992, 0.3518, 0.3372

# %% [markdown]
# #### Check the instances where a word appears

# %% [markdown]
# - check the word "xxx"

# %%
word_to_check = 'Supremo'

try:
    feature_index = vectorizer.vocabulary_[word_to_check]
    print(f"A palavra '{word_to_check}' está no índice de feature: {feature_index}")
except KeyError:
    print(f"ERRO: A palavra '{word_to_check}' não foi incluída no vocabulário do vetorizador. A análise será interrompida.")
# Out:
# A palavra 'Supremo' está no índice de feature: 88

# %%
feature_index = 94
if 'X_test' in locals():
    opinionstage_column = X_test[:, feature_index].toarray().flatten()

    document_indices = np.where(opinionstage_column > 0)[0]

    print(f"Documentos (índices) no X_test que contêm {word_to_check}: {document_indices}")
else:
    print("ERRO: O objeto 'X_test' não está definido. Certifique-se de que a matriz de teste foi carregada.")
# Out:
# Documentos (índices) no X_test que contêm Supremo: [115 183 703]

# %%
if 'texts_test' in locals():
    print("\n--- Conteúdo dos Documentos ---")
    for doc_index in document_indices:
        print(f"\nÍndice {doc_index}:")
        if hasattr(texts_test, 'iloc'):
            print(texts_test.iloc[doc_index])
    
        else:
            print(texts_test[doc_index])
else:
    print("ERRO: O objeto 'texts_test' não está definido. Não é possível inspecionar o texto.")
# Out:
# --- Conteúdo dos Documentos ---
#
# Índice 115:
#   💣 💣 💣 💣 absurdo
#
# Índice 183:
# que absurdo
#
# Índice 703:
# absurdo

# %%
if 'y_test' in locals():
    print(f"Classe dos Documentos Contendo '{word_to_check}'")
    for doc_index in document_indices:
        if hasattr(y_test, 'iloc'):
            document_class = y_test.iloc[doc_index]
        else:
            document_class = y_test[doc_index]

        print(f"Índice {doc_index} pertence à Classe: {document_class}")

else:
    print("ERRO: O objeto 'y_test' (rótulos de classe de teste) não está definido.")
# Out:
# Classe dos Documentos Contendo 'Supremo'
# Índice 115 pertence à Classe: 1
# Índice 183 pertence à Classe: 0
# Índice 703 pertence à Classe: 1

# %% [markdown]
# - Check the Top 10 consistence

# %%
def calculate_top10_consistency(agg_df):
    consistency_results = []
    
    for model_name in agg_df['model'].unique():
        subset = agg_df[agg_df['model'] == model_name]
        
        top_10 = subset.nlargest(10, "avg_abs_weight")
        
        avg_n_occurrences = top_10['n_occurrences'].mean()
        std_n_occurrences = top_10['n_occurrences'].std() # Baixo STD indica baixa variação
        
        n_occurrences_max_word = top_10.iloc[0]['n_occurrences']
        max_abs_weight_max_word = top_10.iloc[0]['avg_abs_weight']
        
        consistency_results.append({
            'model': model_name,
            'top10_avg_n_occurrences': avg_n_occurrences,
            'top10_std_n_occurrences': std_n_occurrences,
            'n_occurrences_max_word': n_occurrences_max_word,
            'max_abs_weight_max_word': max_abs_weight_max_word
        })
        
    return pd.DataFrame(consistency_results).sort_values(by='top10_avg_n_occurrences', ascending=False)

consistency_df = calculate_top10_consistency(agg_df)
display(consistency_df)
# Out:
#                 model  top10_avg_n_occurrences  top10_std_n_occurrences  \
# 3  LogisticRegression                      2.0                 1.333333
# 6        RandomForest                      1.6                 1.349897
# 8                 SVM                      1.6                 0.699206
# 0    GradientBoosting                      1.5                 0.971825
# 2           LinearSVC                      1.5                 0.849837
# 7       SGDClassifier                      1.5                 0.849837
# 5       MultinomialNB                      1.3                 0.674949
# 4                 MLP                      1.2                 0.632456
# 1                 KNN                      1.1                 0.316228
#
#    n_occurrences_max_word  max_abs_weight_max_word
# 3                       2                 0.248142
# 6                       3                 0.394399
# 8                       1                 0.399158
# 0                       4                 0.250940
# 2                       2                 0.435409
# 7                       1                 0.723722
# 5                       2                 0.339842
# 4                       1                 0.693665
# 1                       1                 0.598767

# %% [markdown]
# - Sentences where the two most words appear (for class real and fake)

# %%
words_to_audit = ['tocantim', 'Supremo', 'publicar', 'absurdo']

for word_to_check in words_to_audit:
    try:
        feature_index = vectorizer.vocabulary_[word_to_check]

        feature_column = X_test[:, feature_index]

        document_indices = np.where(feature_column.toarray().flatten() > 0)[0]

        print(f"\n  Sentence that word: '{word_to_check}' appear. (Feature Index: {feature_index}) ---")
        
        if len(document_indices) > 0:
            for doc_index in document_indices:
                if hasattr(texts_test, 'iloc'):
                    text_instance = texts_test.iloc[doc_index]
                else:
                    text_instance = texts_test[doc_index]
                    
                print(f"Index {doc_index}: {text_instance[:100]}...")
        else:
            print("Nenhuma ocorrência desta palavra foi encontrada no seu conjunto de teste X_test.")
            
    except KeyError:
        print(f"\nAVISO: A palavra '{word_to_check}' não foi incluída no vocabulário final do vetorizador.")
    except Exception as e:
        print(f"ERRO ao processar '{word_to_check}': {e}")
# Out:
#   Sentence that word: 'tocantim' appear. (Feature Index: 1126) ---
# Index 204: soldado bolsonaro tocantim...
# Index 233: montoya tocantim :...
# Index 357: Ibope tocantim : vicentinho , 34 %...
# Index 362: o infindável familiocracria político tocantim : negócio pai filho , irmão , marido esposo...
# Index 497: cidade tocantim confirmar ato nacional : # ptnão dia 21 outubro...
# Index 716: candidato psl 17 bolsonaro tocantim...
# Index 763: candidato federal desistir : adir gentil ( poder ) , desistir candidatura deputado federal dedicar i...
# Index 895: o governador candidato reeleição , mauro carler , receber final tarde de este segundo - feira , 24 ,...
#
#   Sentence that word: 'Supremo' appear. (Feature Index: 88) ---
# Index 43:   " fechar Supremo Tribunal federal " , dizer deputado pt...
# Index 238:   " fechar Supremo Tribunal federal " , dizer deputado pt -...
#
#   Sentence that word: 'publicar' appear. (Feature Index: 971) ---
# Index 126: publicar facebook gen...
# Index 236: o extensa ficha criminal Fernando haddad publicar Justiça...
# Index 259:   * publicar facebook gen cupertino ( excelente ) *...
# Index 322: em o último domingo caetano veloso publicar artigo folha criticar escritor olavo Carvalho , apoiador...
#
#   Sentence that word: 'absurdo' appear. (Feature Index: 94) ---
# Index 115:   💣 💣 💣 💣 absurdo...
# Index 183: que absurdo...
# Index 703: absurdo...

# %% [markdown]
# ### Experience 3 - LIME stability

# %% [markdown]
# - **Testing Stability**

# %%
def test_lime_stability(model, vectorizer, text_instance, model_name, n_runs=20, num_features=7, num_samples=1000):
    print(f"\n--- Testing LIME stability for {model_name} (N={n_runs}) ---")
    
    def predict_proba(texts_list):
        X = vectorizer.transform(texts_list)
        if hasattr(model, "predict_proba"):
            return model.predict_proba(X)
        else:
            scores = model.decision_function(X)
            if scores.ndim == 1:
                scores = np.vstack([-scores, scores]).T
            probs = np.exp(scores) / np.exp(scores).sum(axis=1, keepdims=True)
            return probs

    explainer = LimeTextExplainer(class_names=["real", "fake"])
    
    all_feature_sets = []
    
    for run in range(n_runs):
        try:
            exp = explainer.explain_instance(
                text_instance, 
                predict_proba, 
                num_features=num_features,
                num_samples=num_samples
            )
            features_list = [item[0] for item in exp.as_list()]
            all_feature_sets.append(set(features_list))
        except ValueError as e:
            print(f"\n! AVISO: LIME falhou na execução {run+1}/{n_runs} para {model_name} na instância '{text_instance[:30]}...'. Erro: {e}")
            continue 

    successful_runs = len(all_feature_sets) 
    jaccard_scores = []
    
    for i in range(successful_runs):
        for j in range(i + 1, successful_runs):
            jaccard = utils.calculate_jaccard(all_feature_sets[i], all_feature_sets[j]) 
            jaccard_scores.append(jaccard)
                        
    if not jaccard_scores:
        avg_jaccard = 0.0
        if successful_runs < 2:
            print(f"!!! ESTABILIDADE BAIXA: Apenas {successful_runs} execuções de LIME bem-sucedidas. Média Jaccard: 0.0")
    else:
        avg_jaccard = np.mean(jaccard_scores)
        
    print(f"Instance : {text_instance[:30]}...")
    print(f"Jaccard Index Mean (Top {num_features} Features): {avg_jaccard:.4f}")
    
    return avg_jaccard, all_feature_sets


instance_idx = 125
text_to_test = texts_test[instance_idx] 

stability_results = {}

for name, model_tuple in trained_models.items():
    model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple
    
    if hasattr(model, "predict_proba") or hasattr(model, "decision_function"):
        avg_jaccard, _ = test_lime_stability(model, vectorizer, text_to_test, name, n_runs=20, num_features=5)
        stability_results[name] = avg_jaccard
    else:
         print(f"Warning: Model {name} doesn't have 'predict_proba' neither 'decision_function'.")

print("\nLIME Stability Ranking: ")
sorted_stability = sorted(stability_results.items(), key=lambda item: item[1], reverse=True)

df_stability = pd.DataFrame(sorted_stability, columns=['Model', 'Avg. Jaccard Index (Stability)'])

csv_filename = METRICS_PATH / "lime_stability_ranking.csv"
df_stability.to_csv(csv_filename, index=False)

print(df_stability)
print(f"\nResults saved:: {csv_filename}")
# Out:
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.9667
#
# --- Testing LIME stability for MultinomialNB (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8263
#
# --- Testing LIME stability for LinearSVC (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for SGDClassifier (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.9667
#
# --- Testing LIME stability for SVM (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8308
#
# --- Testing LIME stability for KNN (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.5613
#
# --- Testing LIME stability for RandomForest (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8263
#
# --- Testing LIME stability for GradientBoosting (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.6496
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8877
#
# LIME Stability Ranking:
#                 Model  Avg. Jaccard Index (Stability)
# 0           LinearSVC                        1.000000
# 1  LogisticRegression                        0.966667
# 2       SGDClassifier                        0.966667
# 3                 MLP                        0.887719
# 4                 SVM                        0.830827
# 5       MultinomialNB                        0.826316
# 6        RandomForest                        0.826316
# 7    GradientBoosting                        0.649624
# 8                 KNN                        0.561299
#
# Results saved:: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/metrics/lime_stability_ranking.csv

# %%
df_stability
# Out:
#                 Model  Avg. Jaccard Index (Stability)
# 0           LinearSVC                        1.000000
# 1  LogisticRegression                        0.966667
# 2       SGDClassifier                        0.966667
# 3                 MLP                        0.887719
# 4                 SVM                        0.830827
# 5       MultinomialNB                        0.826316
# 6        RandomForest                        0.826316
# 7    GradientBoosting                        0.649624
# 8                 KNN                        0.561299

# %% [markdown]
# - **Hyperparameters Otimization**

# %%
def test_lime_hyperparams_modified(model, vectorizer, text_instance, model_name, num_features=5):
    
    num_samples_list = [500, 1000, 2000]
    results = []
    
    print(f"\nTesting Hyperparameters for model: {model_name} ---")

    for n_samples in num_samples_list:        
        avg_jaccard, single_run_features = test_lime_stability(
            model, 
            vectorizer,
            text_instance, 
            model_name, 
            n_runs=10, 
            num_features=num_features, 
            num_samples=n_samples
        )
        
        results.append({
            'N_Samples': n_samples, 
            'Avg. Jaccard Index (Stability)': avg_jaccard,
            'Top_Features_Sample': single_run_features[0] 
        })
    
    df_results = pd.DataFrame(results)
    return df_results

# %%
def run_hyperparams_for_all_models(trained_models, vectorizer, texts_test, instance_idx, num_features=5):
    
    all_results_df = []
    text_to_test = texts_test[instance_idx]
    
    for name, model_tuple in trained_models.items():
        model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple
        
        if hasattr(model, "predict_proba"):
            print(f"\n>>>> Processing Model: {name} <<<<")
            
            model_results = test_lime_hyperparams_modified(
                model, 
                vectorizer, 
                text_to_test, 
                name, 
                num_features=num_features
            )
            
            model_results['Model'] = name
            all_results_df.append(model_results)
        else:
            print(f"AVISO: {name} não suporta 'predict_proba'. Ignorando.")

    if all_results_df:
        final_df = pd.concat(all_results_df, ignore_index=True)
        
        CSV_GLOBAL_FILENAME = METRICS_PATH / "lime_hyperparam_ranking_all_models.csv"
        final_df.to_csv(CSV_GLOBAL_FILENAME, index=False)
        print(f"\nResults saved on: {CSV_GLOBAL_FILENAME}")
        
        print("\nStability Global Ranking by Model and num_smaples")
        return final_df.sort_values(['Model', 'Avg. Jaccard Index (Stability)'], ascending=[True, False])
    else:
        return pd.DataFrame()

df_results = run_hyperparams_for_all_models(trained_models, vectorizer, texts_test, 125)
# Out:
# >>>> Processing Model: LogisticRegression <<<<
#
# Testing Hyperparameters for model: LogisticRegression ---
#
# --- Testing LIME stability for LogisticRegression (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.9333
#
# --- Testing LIME stability for LogisticRegression (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# >>>> Processing Model: MultinomialNB <<<<
#
# Testing Hyperparameters for model: MultinomialNB ---
#
# --- Testing LIME stability for MultinomialNB (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8000
#
# --- Testing LIME stability for MultinomialNB (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8815
#
# --- Testing LIME stability for MultinomialNB (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8148
# AVISO: LinearSVC não suporta 'predict_proba'. Ignorando.
# AVISO: SGDClassifier não suporta 'predict_proba'. Ignorando.
#
# >>>> Processing Model: SVM <<<<
#
# Testing Hyperparameters for model: SVM ---
#
# --- Testing LIME stability for SVM (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.7323
#
# --- Testing LIME stability for SVM (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for SVM (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# >>>> Processing Model: KNN <<<<
#
# Testing Hyperparameters for model: KNN ---
#
# --- Testing LIME stability for KNN (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.3258
#
# --- Testing LIME stability for KNN (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.5836
#
# --- Testing LIME stability for KNN (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.7640
#
# >>>> Processing Model: RandomForest <<<<
#
# Testing Hyperparameters for model: RandomForest ---
#
# --- Testing LIME stability for RandomForest (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8148
#
# --- Testing LIME stability for RandomForest (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8815
#
# --- Testing LIME stability for RandomForest (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.8444
#
# >>>> Processing Model: GradientBoosting <<<<
#
# Testing Hyperparameters for model: GradientBoosting ---
#
# --- Testing LIME stability for GradientBoosting (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.6106
#
# --- Testing LIME stability for GradientBoosting (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.6381
#
# --- Testing LIME stability for GradientBoosting (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.7185
#
# >>>> Processing Model: MLP <<<<
#
# Testing Hyperparameters for model: MLP ---
#
# --- Testing LIME stability for MLP (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 0.7852
#
# --- Testing LIME stability for MLP (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=10) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# Results saved on: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/metrics/lime_hyperparam_ranking_all_models.csv
#
# Stability Global Ranking by Model and num_smaples

# %%
df_results
# Out:
#     N_Samples  Avg. Jaccard Index (Stability)  \
# 17       2000                        0.718519
# 16       1000                        0.638095
# 15        500                        0.610582
# 11       2000                        0.764021
# 10       1000                        0.583598
# 9         500                        0.325838
# 0         500                        1.000000
# 2        2000                        1.000000
# 1        1000                        0.933333
# 19       1000                        1.000000
# 20       2000                        1.000000
# 18        500                        0.785185
# 4        1000                        0.881481
# 5        2000                        0.814815
# 3         500                        0.800000
# 13       1000                        0.881481
# 14       2000                        0.844444
# 12        500                        0.814815
# 7        1000                        1.000000
# 8        2000                        1.000000
# 6         500                        0.732275
#
#                            Top_Features_Sample               Model
# 17          {comprar, pedir, valer, bem, pena}    GradientBoosting
# 16     {comprar, apresentar, valer, bem, pena}    GradientBoosting
# 15          {rua, comprar, pedir, valer, pena}    GradientBoosting
# 11  {comprar, apresentar, pedir, ônibus, pena}                 KNN
# 10      {comprar, apresentar, bem, colo, pena}                 KNN
# 9    {comprar, receita, apresentar, bem, pena}                 KNN
# 0          {quando, comprar, valer, bem, pena}  LogisticRegression
# 2          {quando, comprar, valer, bem, pena}  LogisticRegression
# 1   {quando, comprar, apresentar, valer, pena}  LogisticRegression
# 19       {quando, comprar, pedir, valer, pena}                 MLP
# 20       {quando, comprar, pedir, valer, pena}                 MLP
# 18       {quando, comprar, pedir, valer, pena}                 MLP
# 4      {comprar, apresentar, valer, bem, pena}       MultinomialNB
# 5      {comprar, apresentar, valer, bem, pena}       MultinomialNB
# 3   {quando, comprar, apresentar, valer, pena}       MultinomialNB
# 13         {quando, comprar, valer, bem, pena}        RandomForest
# 14          {comprar, pedir, valer, bem, pena}        RandomForest
# 12          {comprar, pedir, valer, bem, pena}        RandomForest
# 7      {rua, comprar, apresentar, valer, pena}                 SVM
# 8      {rua, comprar, apresentar, valer, pena}                 SVM
# 6      {comprar, apresentar, valer, bem, pena}                 SVM

# %% [markdown]
# #### Global Approach - Stability

# %%
def calculate_global_average_stability(trained_models, vectorizer, texts_test, n_instances_to_test=300, n_runs=20, num_features=5):
    """
    Calcula a Estabilidade Média Global para múltiplos modelos, 
    usando a média do Jaccard Index em N instâncias de teste.
    """
    
    global_stability_results = []
    
    # 1. Definir o número de amostras a testar (máximo 500 ou o tamanho do set de teste)
    num_samples = min(n_instances_to_test, len(texts_test))
    
    print(f"--- Calculando Estabilidade Média em {num_samples} Instâncias ---")

    for name, model_tuple in trained_models.items():
        model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple
        
        if not hasattr(model, "predict_proba") and not hasattr(model, "decision_function"):
            print(f"AVISO: O modelo {name} foi excluído por falta de função de score.")
            continue
            
        print(f"\n>>>> Processando Modelo: {name} <<<<")
        
        all_instance_jaccards = []
        
        for i in range(num_samples):
            if i >= len(texts_test):
                print(f"!!! ERRO ENCONTRADO !!! i={i} | len(texts_test)={len(texts_test)}")
                break

            text_instance = texts_test[i]
            
            avg_jaccard_per_instance, _ = test_lime_stability(
                model, 
                vectorizer, 
                text_instance, 
                name, 
                n_runs=n_runs, 
                num_features=num_features
            )
            all_instance_jaccards.append(avg_jaccard_per_instance)

            if (i + 1) % 50 == 0:
                print(f"   -> Progresso: {i + 1}/{num_samples} instâncias processadas.")
                
        mean_global_jaccard = np.mean(all_instance_jaccards)
        
        global_stability_results.append({
            'Model': name,
            f'Avg. Jaccard Index (Global over {num_samples} samples)': mean_global_jaccard
        })

    df_global_stability = pd.DataFrame(global_stability_results)
    csv_filename = METRICS_PATH / "lime_global_stability_average.csv"
    df_global_stability.to_csv(csv_filename, index=False)
    
    print(f"\n✅ Resultados agregados salvos com sucesso em: {csv_filename}")
    
    df_global_stability = df_global_stability.sort_values(by=df_global_stability.columns[1], ascending=False)
    print("\n--- Ranking de Estabilidade Média Global ---")
    print(df_global_stability)
    
    return df_global_stability

global_avg_df = calculate_global_average_stability(trained_models, vectorizer, texts_test, n_instances_to_test=300)
# Out:
# --- Calculando Estabilidade Média em 300 Instâncias ---
#
# >>>> Processando Modelo: LogisticRegression <<<<
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : bom dia...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : eu votar meio meio...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * atenção *...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : cena malhação...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : governo comprar r $ 23 bilhão ...
# Jaccard Index Mean (Top 5 Features): 0.7439
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o alkmin atacar mito tudo...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : governador pezão flagrar video...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : hoje dia 17 / 08 22h , acontec...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o petista admitir difícil faze...
# Jaccard Index Mean (Top 5 Features): 0.6860
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * cidade pedro valor cuidar ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : juíza quebrar sigilo agressor ...
# Jaccard Index Mean (Top 5 Features): 0.7912
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : psl - partido social liberal 1...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : adesivaçar Bolsonaro...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : haver dia todo voltaremo feliz...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : carar...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : quando falar educação carente ...
# Jaccard Index Mean (Top 5 Features): 0.8316
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : hj manhã percebi globo colocar...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : bom dia...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : a gang petista acabar cometer ...
# Jaccard Index Mean (Top 5 Features): 0.7702
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : já excluir facebook bloquear W...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : recebi anônimo...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : hoje disposto falar político...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * existir almoço grátis *...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : alguém conseguir criar notícia...
# Jaccard Index Mean (Top 5 Features): 0.9368
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * venezuela primeiro país su...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : humildade fazer melhor ninguém...
# Jaccard Index Mean (Top 5 Features): 0.7737
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * hemorragia controlar *...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : votação maciço parte manhã...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o casa cair : conspiração traz...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o verdade trás ursal...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : mestre renzo Gracie tocar real...
# Jaccard Index Mean (Top 5 Features): 0.7491
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : até irmão velho daniela Mercur...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : atenção todo :...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : professor ir faculdade ministr...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : referência : jo 5 : 6...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : um urna 777 eleitor...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * ❗ ❗ urgente ❗ ❗ *...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   👆 direita volver - bolsodóri...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : sem palavra , divulgar contato...
# Jaccard Index Mean (Top 5 Features): 0.8877
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : bom tarde...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   " fechar Supremo Tribunal fe...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : este plano , assim fazer união...
# Jaccard Index Mean (Top 5 Features): 0.8263
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : amigo colaborador ,...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : acer linkr entrar grupo whatsa...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   [ 11 : 15 , 8 / 10 / 2018 ] ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : deathrash :...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : frase marcante histório :...
# Jaccard Index Mean (Top 5 Features): 1.0000
#    -> Progresso: 50/300 instâncias processadas.
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : repar grande...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : passo passo atentado...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '  😨 😧 😳 😱 😡 🤢...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance :   😨 😧 😳 😱 😡 🤢...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   😱 marina Silva sofrer atenta...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : para nunca ver polícia militar...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : camisa personalizar bolsonaro...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : começar remoção símbolo comuni...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : deputado pt , advogado Lula , ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : atenção , pesquisa abaixo faze...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o facar bolsonaro...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : haddad pedir voto várias igrej...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : senhora aparecer propagandar h...
# Jaccard Index Mean (Top 5 Features): 0.8684
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : não saber ainda candidato pres...
# Jaccard Index Mean (Top 5 Features): 0.8684
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * urgente...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : tô rir agora...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '  🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance :   🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 🔵 ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : parabéns paraná kkk...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : compartilhem...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o exército começar torturar no...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : como falar presidente minuto :...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : eleitor Lgbt 🏳 🌈 pt paquerar e...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ontem manau parar grande manif...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ser bolsonaro ditadura petista...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ciro Gomes sabatina Jornal glo...
# Jaccard Index Mean (Top 5 Features): 0.8316
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : uol : raquel dodge pedir tse b...
# Jaccard Index Mean (Top 5 Features): 0.6326
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : carta donar isabel sobre plano...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : divulguir video todo saibam bo...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : se enviar apenas 20 contato mi...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * mensagem cabo darciolo cri...
# Jaccard Index Mean (Top 5 Features): 0.8877
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : gente Amor Deus , família Bras...
# Jaccard Index Mean (Top 5 Features): 0.9667
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : transposição Rio Francisco , 5...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o mito certo tse roubar descar...
# Jaccard Index Mean (Top 5 Features): 0.9667
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : se alguém disser combater dar ...
# Jaccard Index Mean (Top 5 Features): 0.7456
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : acer linkr entrar grupo whatsa...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : tse suspender propaganda pt as...
# Jaccard Index Mean (Top 5 Features): 0.8579
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : espetacular entrevisto repórte...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : espalhar ver chegar polícia fe...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : prefiro revistar cada esquina ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : jair bolsonaro campanha módico...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : vídeo : uso frota ônibus campa...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : oi , datafolha lançar novo pes...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '  👏 👏 👏 👏...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance :   👏 👏 👏 👏...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : acontecer maceio - al...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : bom dia...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : igreja declarar abertamente ap...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : e reportagem joice hasselman...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : história de esse foto - / / 20...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : cel rel chefe estar grande pol...
# Jaccard Index Mean (Top 5 Features): 1.0000
#    -> Progresso: 100/300 instâncias processadas.
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * urgente...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : para conhece , alok , dj badal...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : olhar gente...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : esse local entregar adesivo ☝ ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ontem manau parar grande manif...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : pessoal , passar dar algum com...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : paraguai adotar tratamento vip...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * perca conta pedido impugna...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ser repassar , dois merda ter ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * pesquisa ibope mostrar Fer...
# Jaccard Index Mean (Top 5 Features): 0.7912
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : olhar origem kit gay 👆 explica...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : esse país todo marginal mandar...
# Jaccard Index Mean (Top 5 Features): 0.6287
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : vejar deputado Paulo Ramos , p...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : por favor jair Ande sempre aro...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : sudação , querer agradecer 2...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   💣 💣 💣 💣 absurdo...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o pai chegar casa vestir novís...
# Jaccard Index Mean (Top 5 Features): 0.8877
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ir dar " dislike " vídeo artis...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : haddad prometer gás r $ 49 , 0...
# Jaccard Index Mean (Top 5 Features): 0.6912
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : que virar pai...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : petição público - fiscalização...
# Jaccard Index Mean (Top 5 Features): 0.7491
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : presídio segurança maximo rome...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : propagandar aniversário grande...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o luta continuar , campanha ja...
# Jaccard Index Mean (Top 5 Features): 0.7526
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : quando alguém rua apresentar r...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : publicar facebook gen...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : não tirer foto comprovante vot...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : ajudar danilo gentili colocar ...
# Jaccard Index Mean (Top 5 Features): 0.9351
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   * bom parte vídeo...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : só refrescar memoria população...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : o trágico campanha errar...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : industr multo ação...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : não poder ter eleição , arma c...
# Jaccard Index Mean (Top 5 Features): 0.6308
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : Bolsonaro começar semana 60 / ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   🏷 adesivaçar Bolsonaro...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : gente , caso algum problema ho...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : tbm pc 95...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : achar vir ainda...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : esse arquivo ano 80 " enterrar...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : assembleia fazer contrato mili...
# Jaccard Index Mean (Top 5 Features): 0.5494
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : enquanto rio janeirer bicho pe...
# Jaccard Index Mean (Top 5 Features): 0.7667
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : tá acontecer Carlos...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance :   😡 bom noite...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
# Instance : estar passar contar oficialmen...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for LogisticRegression (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para LogisticRegression na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para LogisticRegression na instância '...'. Erro: low >= high
# ...
# Instance :   * aviso importante *...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para MLP na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance :   * receber desafio verdade * ...
# Jaccard Index Mean (Top 5 Features): 0.9368
#
# --- Testing LIME stability for MLP (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para MLP na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : bomba...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : assalto agência bancário santa...
# Jaccard Index Mean (Top 5 Features): 0.6556
#
# --- Testing LIME stability for MLP (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para MLP na instância '  👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance :   👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 👆 🏻 ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for MLP (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para MLP na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : olhar , chegar cortar coração ...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : parecer mentira ser...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : ver meme mdi...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : Lula criar prouni...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : o pt desisperar bom jair acost...
# Jaccard Index Mean (Top 5 Features): 0.7667
#
# --- Testing LIME stability for MLP (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para MLP na instância '  😡 😡 😡...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance :   😡 😡 😡...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance :   * relação # marqueteiro jair...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : e Bolsonaro fascista...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance :   👏 🏻r 👏 🏻r 👏 🏻r 👏 🏻r 👏 🏻r 👏 🏻...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : eu amar rede social , pouco mi...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance :   " urgente " debandar pdt cir...
# Jaccard Index Mean (Top 5 Features): 0.9368
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : Portugal abraçar causo direito...
# Jaccard Index Mean (Top 5 Features): 0.6539
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : nosso , apoio eymael haddad vi...
# Jaccard Index Mean (Top 5 Features): 0.7491
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : urgente : stj acabar deferir h...
# Jaccard Index Mean (Top 5 Features): 0.8105
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : esse único eleitorado sentir v...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
#
# ! AVISO: LIME falhou na execução 1/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 2/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 3/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 4/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 5/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 6/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 7/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 8/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 9/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 10/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 11/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 12/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 13/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 14/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 15/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 16/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 17/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 18/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 19/20 para MLP na instância '...'. Erro: low >= high
#
# ! AVISO: LIME falhou na execução 20/20 para MLP na instância '...'. Erro: low >= high
# !!! ESTABILIDADE BAIXA: Apenas 0 execuções de LIME bem-sucedidas. Média Jaccard: 0.0
# Instance : ...
# Jaccard Index Mean (Top 5 Features): 0.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : nosso , relato de esse oficial...
# Jaccard Index Mean (Top 5 Features): 0.9667
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : se ouvir áudio pessoa ainda al...
# Jaccard Index Mean (Top 5 Features): 1.0000
#
# --- Testing LIME stability for MLP (N=20) ---
# Instance : alguém favor postar vídeo dois...
# Jaccard Index Mean (Top 5 Features): 1.0000
#    -> Progresso: 300/300 instâncias processadas.
#
# ✅ Resultados agregados salvos com sucesso em: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/metrics/lime_global_stability_average.csv
#
# --- Ranking de Estabilidade Média Global ---
#                 Model  Avg. Jaccard Index (Global over 300 samples)
# 1       MultinomialNB                                      0.859346
# 0  LogisticRegression                                      0.855059
# 2           LinearSVC                                      0.853194
# 3       SGDClassifier                                      0.849855
# 4                 SVM                                      0.847521
# 8                 MLP                                      0.837567
# 6        RandomForest                                      0.831389
# 7    GradientBoosting                                      0.801827
# 5                 KNN                                      0.750738

# %%
global_avg_df
# Out:
#                 Model  Avg. Jaccard Index (Global over 300 samples)
# 1       MultinomialNB                                      0.859346
# 0  LogisticRegression                                      0.855059
# 2           LinearSVC                                      0.853194
# 3       SGDClassifier                                      0.849855
# 4                 SVM                                      0.847521
# 8                 MLP                                      0.837567
# 6        RandomForest                                      0.831389
# 7    GradientBoosting                                      0.801827
# 5                 KNN                                      0.750738

# %%
trained_models.items()
# Out:
# dict_items([('LogisticRegression', (LogisticRegression(), (0.6535947712418301, 0.6513090084518657, nan, 0.6535947712418301, nan, 0.6524498378942124, nan, 0.6957852748942714, '              precision    recall  f1-score   support\n\n           0       0.66      0.76      0.71       510\n           1       0.64      0.51      0.57       408\n\n    accuracy                           0.65       918\n   macro avg       0.65      0.64      0.64       918\nweighted avg       0.65      0.65      0.65       918\n'))), ('MultinomialNB', (ComplementNB(), (0.6394335511982571, 0.6409007330993147, nan, 0.6394335511982571, nan, 0.6401662515001447, nan, 0.699543444828912, '              precision    recall  f1-score   support\n\n           0       0.68      0.66      0.67       510\n           1       0.59      0.61      0.60       408\n\n    accuracy                           0.64       918\n   macro avg       0.64      0.64      0.64       918\nweighted avg       0.64      0.64      0.64       918\n'))), ('LinearSVC', (LinearSVC(dual=False), (0.6514161220043573, 0.648904818797292, nan, 0.6514161220043573, nan, 0.6501579953674713, nan, nan, '              precision    recall  f1-score   support\n\n           0       0.67      0.73      0.70       510\n           1       0.62      0.55      0.58       408\n\n    accuracy                           0.65       918\n   macro avg       0.65      0.64      0.64       918\nweighted avg       0.65      0.65      0.65       918\n'))), ('SGDClassifier', (SGDClassifier(), (0.6470588235294118, 0.6442906574394464, nan, 0.6470588235294118, nan, 0.6456717235327977, nan, nan, '              precision    recall  f1-score   support\n\n           0       0.66      0.75      0.70       510\n           1       0.62      0.52      0.57       408\n\n    accuracy                           0.65       918\n   macro avg       0.64      0.63      0.63       918\nweighted avg       0.64      0.65      0.64       918\n'))), ('SVM', (SVC(probability=True), (0.6688453159041394, 0.6685001833516685, nan, 0.6688453159041394, nan, 0.6686726550932419, nan, 0.7130358515955402, '              precision    recall  f1-score   support\n\n           0       0.67      0.80      0.73       510\n           1       0.67      0.51      0.58       408\n\n    accuracy                           0.67       918\n   macro avg       0.67      0.65      0.65       918\nweighted avg       0.67      0.67      0.66       918\n'))), ('KNN', (KNeighborsClassifier(n_jobs=-1, weights='distance'), (0.6296296296296297, 0.6264722477685811, nan, 0.6296296296296297, nan, 0.6280469204463737, nan, 0.6697592272203, '              precision    recall  f1-score   support\n\n           0       0.65      0.72      0.68       510\n           1       0.60      0.52      0.55       408\n\n    accuracy                           0.63       918\n   macro avg       0.62      0.62      0.62       918\nweighted avg       0.63      0.63      0.63       918\n'))), ('RandomForest', (RandomForestClassifier(n_jobs=-1), (0.6699346405228758, 0.6687594586414148, nan, 0.6699346405228758, nan, 0.6693464837614129, nan, 0.7223904267589389, '              precision    recall  f1-score   support\n\n           0       0.67      0.78      0.73       510\n           1       0.66      0.53      0.59       408\n\n    accuracy                           0.67       918\n   macro avg       0.67      0.66      0.66       918\nweighted avg       0.67      0.67      0.66       918\n'))), ('GradientBoosting', (GradientBoostingClassifier(n_estimators=200), (0.6187363834422658, 0.6229819563152896, nan, 0.6187363834422658, nan, 0.6208518618368444, nan, 0.6699058054594387, '              precision    recall  f1-score   support\n\n           0       0.61      0.85      0.71       510\n           1       0.63      0.34      0.44       408\n\n    accuracy                           0.62       918\n   macro avg       0.62      0.59      0.58       918\nweighted avg       0.62      0.62      0.59       918\n')) ...
#               verbose=True), (0.6230936819172114, 0.6338020118884317, nan, 0.6230936819172114, nan, 0.6284021812156151, nan, 0.691142829680892, '              precision    recall  f1-score   support\n\n           0       0.69      0.58      0.63       510\n           1       0.56      0.67      0.61       408\n\n    accuracy                           0.62       918\n   macro avg       0.63      0.63      0.62       918\nweighted avg       0.63      0.62      0.62       918\n')))])

# %%
def create_final_ranking(trained_models, stability_results, metric_to_use='F1_Score'):
    """
    Combina os resultados de estabilidade LIME (Jaccard Index) com as métricas de performance.
    
    Acessa o F1-Score no índice 1 da tupla de métricas do modelo.
    """
    
    final_ranking_data = []

    # O nome da coluna da estabilidade será sempre este:
    stability_col_name = 'LIME Stability (Avg. Jaccard)'
    
    for name, model_tuple in trained_models.items():
        
        # O formato esperado agora é: (modelo_obj, tupla_metricas)
        # O len da tupla completa do item é 2, mas você precisa de 3 itens 
        # (modelo, vetorizador, métricas_dict) para o código antigo funcionar.
        # ASSUMINDO que o formato é: (Objeto, Tupla de Métricas)
        
        # Vamos assumir o formato: ('Nome', (Objeto, Tupla_de_8_Metricas))
        if isinstance(model_tuple, tuple) and len(model_tuple) == 2:
            metrics_tuple = model_tuple[1]
            
            # O F1-Score é o segundo elemento (índice 1) da tupla de métricas
            # Assumimos que o F1-Score está sempre no índice 1
            if len(metrics_tuple) > 1:
                f1_score_value = metrics_tuple[1]
            else:
                f1_score_value = np.nan
            
            # Garante que o modelo existe no resultado de estabilidade
            if name in stability_results:
                
                final_ranking_data.append({
                    'Model': name,
                    stability_col_name: stability_results[name],
                    metric_to_use: f1_score_value # Nome da coluna é 'F1_Score'
                })

    df_final = pd.DataFrame(final_ranking_data)
    
    # 1. Conversão para numérico (trata 'nan's corretamente)
    # df_final[metric_to_use] já deve ser numérica se os dados vieram de np.nan
    
    # 2. Ordenar o ranking primariamente pelo F1-Score e secundariamente pela Estabilidade LIME
    df_final = df_final.sort_values(
        by=[metric_to_use, stability_col_name], 
        # F1 e Estabilidade devem ser Decrescentes (do maior para o menor)
        ascending=[False, False] 
    )

    return df_final

# --- Execução da Função ---

final_ranking_df = create_final_ranking(trained_models, stability_results, metric_to_use='F1_Score')
print("\n--- Ranking Final: Performance (F1-Score) vs. Estabilidade LIME ---")
final_ranking_df
# Out:
# --- Ranking Final: Performance (F1-Score) vs. Estabilidade LIME ---
#                 Model  LIME Stability (Avg. Jaccard)  F1_Score
# 6        RandomForest                       0.826316  0.668759
# 4                 SVM                       0.830827  0.668500
# 0  LogisticRegression                       0.966667  0.651309
# 2           LinearSVC                       1.000000  0.648905
# 3       SGDClassifier                       0.966667  0.644291
# 1       MultinomialNB                       0.826316  0.640901
# 8                 MLP                       0.887719  0.633802
# 5                 KNN                       0.561299  0.626472
# 7    GradientBoosting                       0.649624  0.622982

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# --- 0. Preparação de Dados ---
df_prep = final_ranking_df.copy()

# Ordenar o DataFrame pela Estabilidade LIME para visualização clara (Estável -> Instável)
df_sorted = df_prep.sort_values(by='LIME Stability (Avg. Jaccard)', ascending=False).reset_index(drop=True)

models = df_sorted['Model'].tolist()
num_models = len(models)
x_indices = np.arange(num_models) # Índices numéricos para o eixo X

# Definir as cores
# Estabilidade (Laranja/Amarelo - foco na interpretabilidade)
stability_color = 'tab:orange'
# Performance (Azul - foco na performance)
f1_color = 'tab:blue'

## 📈 1. Criação do Gráfico de Eixos Duplos

fig, ax1 = plt.subplots(figsize=(12, 7))

# --- Eixo Y Esquerdo (Estabilidade LIME) ---
ax1.set_xlabel('Model')
ax1.set_ylabel('Stability LIME (Avg. Jaccard Index)', color=stability_color)
ax1.tick_params(axis='y', labelcolor=stability_color)
ax1.set_ylim(0.5, 1.05) # Limites para focar nos resultados de Jaccard

# Plot da Estabilidade
line1 = ax1.plot(
    x_indices, 
    df_sorted['LIME Stability (Avg. Jaccard)'], 
    color=stability_color, 
    marker='o', 
    linestyle='-', 
    linewidth=2,
    label='Stability LIME (Jaccard)'
)

# --- Eixo Y Direito (F1-Score) ---
ax2 = ax1.twinx() # Cria um segundo eixo Y que compartilha o eixo X
ax2.set_ylabel('F1-Score (Performance)', color=f1_color)
ax2.tick_params(axis='y', labelcolor=f1_color)
ax2.set_ylim(0.60, 0.75) # Limites para focar na variação do F1-Score

# Plot do F1-Score
line2 = ax2.plot(
    x_indices, 
    df_sorted['F1_Score'], 
    color=f1_color, 
    marker='^', 
    linestyle='--', 
    linewidth=2,
    label='F1-Score (Performance)'
)

# Adiciona legendas
lines = line1 + line2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper right', bbox_to_anchor=(1.0, 0.95))

# Configuração do Eixo X (Nomes dos Modelos)
ax1.set_xticks(x_indices)
ax1.set_xticklabels(models, rotation=45, ha='right')

# Adiciona título e grid
plt.title('Trade-off between Performance and Stability (LIME)')
ax1.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Experience 4 - LIME Fidelity Analysis

# %%
def calculate_aopc(model, vectorizer, text, lime_explanation, num_features=5):
    """
    Calcula AOPC (Area Over Perturbation Curve) - Fidelidade Local
    
    Remove progressivamente as features mais importantes identificadas pelo LIME
    e mede a queda na confiança da predição.
    
    Quanto MAIOR o AOPC, MELHOR a fidelidade (explicação mais fiel ao modelo).
    """
    # Ordenar features por peso absoluto (mais importantes primeiro)
    features_sorted = sorted(lime_explanation, key=lambda x: abs(x[1]), reverse=True)
    
    # Predição original
    X_original = vectorizer.transform([text])
    if hasattr(model, 'predict_proba'):
        prob_original = model.predict_proba(X_original)[0, 1]  # classe fake
    else:
        score = model.decision_function(X_original)[0]
        prob_original = 1 / (1 + np.exp(-score))  # sigmoid
    
    prob_diffs = []
    
    # Remover progressivamente features
    for k in range(1, min(num_features + 1, len(features_sorted) + 1)):
        text_perturbed = text
        
        # Remover top-k features
        for i in range(k):
            feature = features_sorted[i][0]
            # Remover todas as ocorrências da palavra
            text_perturbed = ' '.join([w for w in text_perturbed.split() if w != feature])
        
        # Predição após remoção
        if text_perturbed.strip():  # verificar se ainda há texto
            X_perturbed = vectorizer.transform([text_perturbed])
            if hasattr(model, 'predict_proba'):
                prob_perturbed = model.predict_proba(X_perturbed)[0, 1]
            else:
                score = model.decision_function(X_perturbed)[0]
                prob_perturbed = 1 / (1 + np.exp(-score))
        else:
            prob_perturbed = 0.5  # neutro se texto vazio
        
        # Diferença absoluta na probabilidade
        prob_diff = abs(prob_original - prob_perturbed)
        prob_diffs.append(prob_diff)
    
    # AOPC: média das diferenças
    aopc = np.mean(prob_diffs) if prob_diffs else 0.0
    return aopc, prob_diffs


def calculate_comprehensiveness(model, vectorizer, text, lime_explanation, num_features=5):
    """
    Comprehensiveness: Mede o impacto de REMOVER as features importantes.
    
    Quanto MAIOR, MELHOR (significa que remover features importantes afeta muito a predição).
    """
    features_sorted = sorted(lime_explanation, key=lambda x: abs(x[1]), reverse=True)
    top_features = [f[0] for f in features_sorted[:num_features]]
    
    # Predição original
    X_original = vectorizer.transform([text])
    if hasattr(model, 'predict_proba'):
        prob_original = model.predict_proba(X_original)[0, 1]
    else:
        score = model.decision_function(X_original)[0]
        prob_original = 1 / (1 + np.exp(-score))
    
    # Remover top features
    text_without_top = ' '.join([w for w in text.split() if w not in top_features])
    
    if text_without_top.strip():
        X_perturbed = vectorizer.transform([text_without_top])
        if hasattr(model, 'predict_proba'):
            prob_perturbed = model.predict_proba(X_perturbed)[0, 1]
        else:
            score = model.decision_function(X_perturbed)[0]
            prob_perturbed = 1 / (1 + np.exp(-score))
    else:
        prob_perturbed = 0.5
    
    comprehensiveness = abs(prob_original - prob_perturbed)
    return comprehensiveness


def calculate_sufficiency(model, vectorizer, text, lime_explanation, num_features=5):
    """
    Sufficiency: Mede se APENAS as features importantes são suficientes.
    
    Quanto MENOR, MELHOR (significa que manter só as top features mantém a predição).
    """
    features_sorted = sorted(lime_explanation, key=lambda x: abs(x[1]), reverse=True)
    top_features = [f[0] for f in features_sorted[:num_features]]
    
    # Predição original
    X_original = vectorizer.transform([text])
    if hasattr(model, 'predict_proba'):
        prob_original = model.predict_proba(X_original)[0, 1]
    else:
        score = model.decision_function(X_original)[0]
        prob_original = 1 / (1 + np.exp(-score))
    
    # Manter APENAS top features
    text_only_top = ' '.join([w for w in text.split() if w in top_features])
    
    if text_only_top.strip():
        X_perturbed = vectorizer.transform([text_only_top])
        if hasattr(model, 'predict_proba'):
            prob_perturbed = model.predict_proba(X_perturbed)[0, 1]
        else:
            score = model.decision_function(X_perturbed)[0]
            prob_perturbed = 1 / (1 + np.exp(-score))
    else:
        prob_perturbed = 0.5
    
    sufficiency = abs(prob_original - prob_perturbed)
    return sufficiency

# %% [markdown]
# #### 4.2 - Fidelity Evaluation for all models

# %%
def evaluate_lime_fidelity(trained_models, vectorizer, texts_test, n_samples=100, num_features=5):
    """
    Avalia fidelidade do LIME para todos os modelos.
    
    Retorna DataFrame com métricas:
    - AOPC (quanto maior, melhor)
    - Comprehensiveness (quanto maior, melhor)
    - Sufficiency (quanto menor, melhor)
    """
    results = []
    
    for model_name, model_tuple in trained_models.items():
        model = model_tuple[0] if isinstance(model_tuple, tuple) else model_tuple
        
        if not (hasattr(model, 'predict_proba') or hasattr(model, 'decision_function')):
            print(f"Skipping {model_name} - no predict_proba or decision_function")
            continue
        
        print(f"\n{'='*60}")
        print(f"Evaluating LIME Fidelity for: {model_name}")
        print(f"{'='*60}")
        
        aopc_scores = []
        comp_scores = []
        suff_scores = []
        
        explainer = LimeTextExplainer(class_names=["real", "fake"])
        
        for idx in tqdm(range(min(n_samples, len(texts_test))), desc=f"{model_name}"):
            text = texts_test[idx]
            
            try:
                def predict_proba(texts_list):
                    X = vectorizer.transform(texts_list)
                    if hasattr(model, "predict_proba"):
                        return model.predict_proba(X)
                    else:
                        scores = model.decision_function(X)
                        if scores.ndim == 1:
                            scores = np.vstack([-scores, scores]).T
                        probs = np.exp(scores) / np.exp(scores).sum(axis=1, keepdims=True)
                        return probs
                
                # Gerar explicação LIME
                exp = explainer.explain_instance(
                    text, 
                    predict_proba, 
                    num_features=num_features * 2
                )
                
                explanation = exp.as_list()
                
                aopc, _ = calculate_aopc(model, vectorizer, text, explanation, num_features)
                comp = calculate_comprehensiveness(model, vectorizer, text, explanation, num_features)
                suff = calculate_sufficiency(model, vectorizer, text, explanation, num_features)
                
                aopc_scores.append(aopc)
                comp_scores.append(comp)
                suff_scores.append(suff)
                
            except Exception as e:
                print(f" ===== Error on sample {idx}: {e}")
                continue
        
        results.append({
            'Model': model_name,
            'AOPC_mean': np.mean(aopc_scores),
            'AOPC_std': np.std(aopc_scores),
            'Comprehensiveness_mean': np.mean(comp_scores),
            'Comprehensiveness_std': np.std(comp_scores),
            'Sufficiency_mean': np.mean(suff_scores),
            'Sufficiency_std': np.std(suff_scores),
            'n_samples': len(aopc_scores)
        })
        
        print(f"\n {model_name} Results:")
        print(f"   AOPC: {np.mean(aopc_scores):.4f} (±{np.std(aopc_scores):.4f})")
        print(f"   Comprehensiveness: {np.mean(comp_scores):.4f} (±{np.std(comp_scores):.4f})")
        print(f"   Sufficiency: {np.mean(suff_scores):.4f} (±{np.std(suff_scores):.4f})")
    
    df_fidelity = pd.DataFrame(results)
    return df_fidelity

# %%
# Avaliar fidelidade (ajusta n_samples conforme necessário)
df_fidelity = evaluate_lime_fidelity(
    trained_models, 
    vectorizer, 
    texts_test[:300], 
    n_samples=300,  
    num_features=5
)

# Salvar resultados
df_fidelity.to_csv(METRICS_PATH / 'lime_fidelity_results.csv', index=False)
print("\n✅ Fidelity results saved to 'lime_fidelity_results.csv'")

# Mostrar tabela
display(df_fidelity)
# Out:
# ============================================================
# Evaluating LIME Fidelity for: LogisticRegression
# ============================================================
# LogisticRegression:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# LogisticRegression:   7%|▋         | 22/300 [00:00<00:09, 28.85it/s]
#  ===== Error on sample 15: low >= high
# LogisticRegression:  12%|█▏        | 36/300 [00:01<00:09, 28.12it/s]
#  ===== Error on sample 31: low >= high
# LogisticRegression:  19%|█▊        | 56/300 [00:02<00:08, 29.45it/s]
#  ===== Error on sample 52: low >= high
# LogisticRegression:  23%|██▎       | 70/300 [00:02<00:07, 32.62it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# LogisticRegression:  32%|███▏      | 97/300 [00:03<00:07, 28.37it/s]
#  ===== Error on sample 92: low >= high
#  ===== Error on sample 98: low >= high
# LogisticRegression:  43%|████▎     | 129/300 [00:04<00:06, 24.86it/s]
#  ===== Error on sample 124: low >= high
# LogisticRegression:  44%|████▍     | 133/300 [00:04<00:05, 28.16it/s]
#  ===== Error on sample 130: low >= high
# LogisticRegression:  50%|█████     | 151/300 [00:05<00:04, 29.98it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# LogisticRegression:  52%|█████▏    | 155/300 [00:05<00:04, 30.83it/s]
#  ===== Error on sample 152: low >= high
# LogisticRegression:  56%|█████▌    | 167/300 [00:06<00:04, 27.87it/s]
#  ===== Error on sample 162: low >= high
# LogisticRegression:  58%|█████▊    | 175/300 [00:06<00:03, 32.27it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# LogisticRegression:  68%|██████▊   | 203/300 [00:07<00:03, 32.24it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
#  ===== Error on sample 201: low >= high
# LogisticRegression:  73%|███████▎  | 219/300 [00:07<00:02, 29.65it/s]
#  ===== Error on sample 214: low >= high
# LogisticRegression:  75%|███████▍  | 224/300 [00:07<00:02, 31.91it/s]
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# LogisticRegression:  80%|███████▉  | 239/300 [00:08<00:02, 28.75it/s]
#  ===== Error on sample 231: low >= high
# LogisticRegression:  85%|████████▍ | 254/300 [00:09<00:01, 24.61it/s]
#  ===== Error on sample 249: low >= high
# LogisticRegression:  91%|█████████ | 273/300 [00:09<00:01, 26.96it/s]
#  ===== Error on sample 269: low >= high
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# LogisticRegression:  96%|█████████▌| 288/300 [00:10<00:00, 34.88it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
#  ===== Error on sample 286: low >= high
# LogisticRegression: 100%|██████████| 300/300 [00:10<00:00, 27.84it/s]
#  ===== Error on sample 296: low >= high
#
#  LogisticRegression Results:
#    AOPC: 0.1153 (±0.0737)
#    Comprehensiveness: 0.1309 (±0.0952)
#    Sufficiency: 0.0108 (±0.0262)
#
# ============================================================
# Evaluating LIME Fidelity for: MultinomialNB
# ============================================================
# MultinomialNB:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# MultinomialNB:   6%|▌         | 18/300 [00:00<00:09, 29.85it/s]
#  ===== Error on sample 15: low >= high
# MultinomialNB:  12%|█▏        | 36/300 [00:01<00:09, 28.46it/s]
#  ===== Error on sample 31: low >= high
# MultinomialNB:  19%|█▊        | 56/300 [00:01<00:08, 29.61it/s]
#  ===== Error on sample 52: low >= high
# MultinomialNB:  24%|██▍       | 72/300 [00:02<00:07, 30.79it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# MultinomialNB:  33%|███▎      | 98/300 [00:03<00:07, 27.94it/s]
#  ===== Error on sample 92: low >= high
#  ===== Error on sample 98: low >= high
# MultinomialNB:  42%|████▏     | 127/300 [00:04<00:06, 25.62it/s]
#  ===== Error on sample 124: low >= high
# MultinomialNB:  45%|████▍     | 134/300 [00:04<00:05, 28.49it/s]
#  ===== Error on sample 130: low >= high
# MultinomialNB:  50%|█████     | 151/300 [00:05<00:05, 29.00it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# MultinomialNB:  53%|█████▎    | 159/300 [00:05<00:04, 29.30it/s]
#  ===== Error on sample 152: low >= high
# MultinomialNB:  55%|█████▌    | 166/300 [00:06<00:04, 28.33it/s]
#  ===== Error on sample 162: low >= high
# MultinomialNB:  59%|█████▉    | 178/300 [00:06<00:03, 32.29it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# MultinomialNB:  67%|██████▋   | 202/300 [00:07<00:03, 32.55it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
#  ===== Error on sample 201: low >= high
# MultinomialNB:  74%|███████▍  | 222/300 [00:07<00:02, 31.41it/s]
#  ===== Error on sample 214: low >= high
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# MultinomialNB:  79%|███████▉  | 237/300 [00:08<00:02, 28.22it/s]
#  ===== Error on sample 231: low >= high
# MultinomialNB:  85%|████████▍ | 254/300 [00:09<00:01, 24.73it/s]
#  ===== Error on sample 249: low >= high
# MultinomialNB:  91%|█████████ | 273/300 [00:10<00:01, 26.56it/s]
#  ===== Error on sample 269: low >= high
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# MultinomialNB:  96%|█████████▌| 288/300 [00:10<00:00, 34.66it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
#  ===== Error on sample 286: low >= high
# MultinomialNB: 100%|██████████| 300/300 [00:10<00:00, 27.69it/s]
#  ===== Error on sample 296: low >= high
#
#  MultinomialNB Results:
#    AOPC: 0.1250 (±0.0815)
#    Comprehensiveness: 0.1462 (±0.1059)
#    Sufficiency: 0.0093 (±0.0218)
#
# ============================================================
# Evaluating LIME Fidelity for: LinearSVC
# ============================================================
# LinearSVC:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# LinearSVC:   6%|▌         | 18/300 [00:00<00:09, 29.81it/s]
#  ===== Error on sample 15: low >= high
# LinearSVC:  12%|█▏        | 37/300 [00:01<00:09, 28.05it/s]
#  ===== Error on sample 31: low >= high
# LinearSVC:  19%|█▉        | 57/300 [00:02<00:08, 28.75it/s]
#  ===== Error on sample 52: low >= high
# LinearSVC:  23%|██▎       | 69/300 [00:02<00:07, 32.74it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# LinearSVC:  32%|███▏      | 96/300 [00:03<00:07, 28.33it/s]
#  ===== Error on sample 92: low >= high
#  ===== Error on sample 98: low >= high
# LinearSVC:  43%|████▎     | 129/300 [00:04<00:07, 24.25it/s]
#  ===== Error on sample 124: low >= high
# LinearSVC:  44%|████▍     | 133/300 [00:04<00:06, 27.77it/s]
#  ===== Error on sample 130: low >= high
# LinearSVC:  50%|█████     | 151/300 [00:05<00:05, 29.74it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# LinearSVC:  53%|█████▎    | 159/300 [00:05<00:04, 29.86it/s]
#  ===== Error on sample 152: low >= high
# LinearSVC:  55%|█████▌    | 166/300 [00:06<00:04, 27.99it/s]
#  ===== Error on sample 162: low >= high
# LinearSVC:  59%|█████▉    | 178/300 [00:06<00:03, 31.59it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# LinearSVC:  67%|██████▋   | 202/300 [00:07<00:02, 32.76it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
#  ===== Error on sample 201: low >= high
# LinearSVC:  74%|███████▍  | 222/300 [00:07<00:02, 32.03it/s]
#  ===== Error on sample 214: low >= high
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# LinearSVC:  79%|███████▉  | 237/300 [00:08<00:02, 28.17it/s]
#  ===== Error on sample 231: low >= high
# LinearSVC:  84%|████████▍ | 252/300 [00:09<00:01, 24.71it/s]
#  ===== Error on sample 249: low >= high
# LinearSVC:  91%|█████████▏| 274/300 [00:10<00:00, 26.21it/s]
#  ===== Error on sample 269: low >= high
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# LinearSVC:  95%|█████████▍| 284/300 [00:10<00:00, 34.80it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
#  ===== Error on sample 286: low >= high
# LinearSVC: 100%|██████████| 300/300 [00:10<00:00, 27.79it/s]
#  ===== Error on sample 296: low >= high
#
#  LinearSVC Results:
#    AOPC: 0.1084 (±0.0691)
#    Comprehensiveness: 0.1143 (±0.0772)
#    Sufficiency: 0.0088 (±0.0203)
#
# ============================================================
# Evaluating LIME Fidelity for: SGDClassifier
# ============================================================
# SGDClassifier:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# SGDClassifier:   6%|▌         | 18/300 [00:00<00:09, 29.84it/s]
#  ===== Error on sample 15: low >= high
# SGDClassifier:  12%|█▏        | 37/300 [00:01<00:09, 27.69it/s]
#  ===== Error on sample 31: low >= high
# SGDClassifier:  19%|█▉        | 58/300 [00:02<00:08, 28.53it/s]
#  ===== Error on sample 52: low >= high
# SGDClassifier:  23%|██▎       | 70/300 [00:02<00:06, 33.05it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# SGDClassifier:  33%|███▎      | 98/300 [00:03<00:07, 28.40it/s]
#  ===== Error on sample 92: low >= high
#  ===== Error on sample 98: low >= high
# SGDClassifier:  43%|████▎     | 129/300 [00:04<00:06, 24.72it/s]
#  ===== Error on sample 124: low >= high
# SGDClassifier:  44%|████▍     | 133/300 [00:04<00:05, 28.36it/s]
#  ===== Error on sample 130: low >= high
# SGDClassifier:  50%|█████     | 151/300 [00:05<00:05, 29.71it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# SGDClassifier:  52%|█████▏    | 155/300 [00:05<00:04, 30.75it/s]
#  ===== Error on sample 152: low >= high
# SGDClassifier:  55%|█████▌    | 166/300 [00:06<00:04, 27.75it/s]
#  ===== Error on sample 162: low >= high
# SGDClassifier:  59%|█████▉    | 178/300 [00:06<00:03, 31.96it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# SGDClassifier:  67%|██████▋   | 202/300 [00:07<00:03, 31.55it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
#  ===== Error on sample 201: low >= high
# SGDClassifier:  74%|███████▍  | 222/300 [00:07<00:02, 31.98it/s]
#  ===== Error on sample 214: low >= high
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# SGDClassifier:  79%|███████▉  | 237/300 [00:08<00:02, 28.23it/s]
#  ===== Error on sample 231: low >= high
# SGDClassifier:  85%|████████▍ | 254/300 [00:09<00:01, 25.18it/s]
#  ===== Error on sample 249: low >= high
# SGDClassifier:  91%|█████████ | 273/300 [00:09<00:01, 26.75it/s]
#  ===== Error on sample 269: low >= high
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# SGDClassifier:  95%|█████████▍| 284/300 [00:10<00:00, 34.78it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
#  ===== Error on sample 286: low >= high
# SGDClassifier: 100%|██████████| 300/300 [00:10<00:00, 27.96it/s]
#  ===== Error on sample 296: low >= high
#
#  SGDClassifier Results:
#    AOPC: 0.1889 (±0.1079)
#    Comprehensiveness: 0.2057 (±0.1266)
#    Sufficiency: 0.0154 (±0.0409)
#
# ============================================================
# Evaluating LIME Fidelity for: SVM
# ============================================================
# SVM:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# SVM:   6%|▌         | 17/300 [00:03<00:38,  7.31it/s]
#  ===== Error on sample 15: low >= high
# SVM:  11%|█         | 33/300 [00:06<00:43,  6.07it/s]
#  ===== Error on sample 31: low >= high
# SVM:  17%|█▋        | 52/300 [00:11<00:40,  6.08it/s]
#  ===== Error on sample 52: low >= high
# SVM:  23%|██▎       | 68/300 [00:14<00:29,  7.88it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# SVM:  31%|███▏      | 94/300 [00:20<00:38,  5.38it/s]
#  ===== Error on sample 92: low >= high
# SVM:  33%|███▎      | 98/300 [00:21<00:41,  4.87it/s]
#  ===== Error on sample 98: low >= high
# SVM:  41%|████▏     | 124/300 [00:28<00:36,  4.87it/s]
#  ===== Error on sample 124: low >= high
# SVM:  44%|████▍     | 132/300 [00:30<00:27,  6.06it/s]
#  ===== Error on sample 130: low >= high
# SVM:  48%|████▊     | 145/300 [00:33<00:28,  5.43it/s]
#  ===== Error on sample 145: low >= high
# SVM:  50%|████▉     | 149/300 [00:33<00:19,  7.60it/s]
#  ===== Error on sample 147: low >= high
# SVM:  51%|█████▏    | 154/300 [00:34<00:25,  5.82it/s]
#  ===== Error on sample 152: low >= high
# SVM:  55%|█████▍    | 164/300 [00:37<00:22,  6.00it/s]
#  ===== Error on sample 162: low >= high
# SVM:  58%|█████▊    | 173/300 [00:38<00:16,  7.51it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# SVM:  65%|██████▌   | 195/300 [00:44<00:30,  3.47it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
# SVM:  67%|██████▋   | 201/300 [00:44<00:19,  5.19it/s]
#  ===== Error on sample 201: low >= high
# SVM:  71%|███████▏  | 214/300 [00:47<00:19,  4.52it/s]
#  ===== Error on sample 214: low >= high
# SVM:  74%|███████▍  | 223/300 [00:49<00:13,  5.79it/s]
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# SVM:  77%|███████▋  | 231/300 [00:51<00:19,  3.46it/s]
#  ===== Error on sample 231: low >= high
# SVM:  84%|████████▎ | 251/300 [00:56<00:08,  6.01it/s]
#  ===== Error on sample 249: low >= high
# SVM:  90%|████████▉ | 269/300 [01:01<00:09,  3.19it/s]
#  ===== Error on sample 269: low >= high
# SVM:  91%|█████████▏| 274/300 [01:02<00:05,  4.54it/s]
#  ===== Error on sample 274: low >= high
# SVM:  93%|█████████▎| 278/300 [01:02<00:03,  7.08it/s]
#  ===== Error on sample 276: low >= high
# SVM:  93%|█████████▎| 279/300 [01:03<00:04,  4.97it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
# SVM:  95%|█████████▌| 286/300 [01:04<00:02,  6.05it/s]
#  ===== Error on sample 286: low >= high
# SVM:  99%|█████████▊| 296/300 [01:06<00:00,  4.19it/s]
#  ===== Error on sample 296: low >= high
# SVM: 100%|██████████| 300/300 [01:07<00:00,  4.45it/s]
#  SVM Results:
#    AOPC: 0.1717 (±0.1334)
#    Comprehensiveness: 0.2027 (±0.1646)
#    Sufficiency: 0.0120 (±0.0316)
#
# ============================================================
# Evaluating LIME Fidelity for: KNN
# ============================================================
# KNN:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# KNN:   6%|▌         | 17/300 [00:03<00:43,  6.51it/s]
#  ===== Error on sample 15: low >= high
# KNN:  11%|█         | 33/300 [00:06<00:46,  5.79it/s]
#  ===== Error on sample 31: low >= high
# KNN:  17%|█▋        | 52/300 [00:10<00:47,  5.18it/s]
#  ===== Error on sample 52: low >= high
# KNN:  23%|██▎       | 68/300 [00:13<00:30,  7.68it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# KNN:  31%|███▏      | 94/300 [00:19<00:37,  5.43it/s]
#  ===== Error on sample 92: low >= high
# KNN:  33%|███▎      | 98/300 [00:20<00:41,  4.91it/s]
#  ===== Error on sample 98: low >= high
# KNN:  41%|████▏     | 124/300 [00:26<00:42,  4.12it/s]
#  ===== Error on sample 124: low >= high
# KNN:  44%|████▍     | 132/300 [00:28<00:28,  5.80it/s]
#  ===== Error on sample 130: low >= high
# KNN:  48%|████▊     | 145/300 [00:31<00:32,  4.83it/s]
#  ===== Error on sample 145: low >= high
# KNN:  50%|████▉     | 149/300 [00:31<00:20,  7.31it/s]
#  ===== Error on sample 147: low >= high
# KNN:  51%|█████▏    | 154/300 [00:32<00:22,  6.46it/s]
#  ===== Error on sample 152: low >= high
# KNN:  55%|█████▍    | 164/300 [00:34<00:22,  5.98it/s]
#  ===== Error on sample 162: low >= high
# KNN:  58%|█████▊    | 173/300 [00:36<00:17,  7.26it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# KNN:  65%|██████▌   | 195/300 [00:41<00:25,  4.08it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
# KNN:  68%|██████▊   | 203/300 [00:42<00:15,  6.10it/s]
#  ===== Error on sample 201: low >= high
# KNN:  71%|███████▏  | 214/300 [00:44<00:19,  4.42it/s]
#  ===== Error on sample 214: low >= high
# KNN:  74%|███████▍  | 223/300 [00:46<00:10,  7.18it/s]
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# KNN:  78%|███████▊  | 233/300 [00:48<00:12,  5.28it/s]
#  ===== Error on sample 231: low >= high
# KNN:  83%|████████▎ | 249/300 [00:52<00:11,  4.47it/s]
#  ===== Error on sample 249: low >= high
# KNN:  90%|█████████ | 271/300 [00:57<00:05,  5.15it/s]
#  ===== Error on sample 269: low >= high
# KNN:  92%|█████████▏| 276/300 [00:58<00:04,  5.81it/s]
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# KNN:  93%|█████████▎| 279/300 [00:58<00:03,  5.90it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
# KNN:  95%|█████████▌| 286/300 [00:59<00:02,  5.69it/s]
#  ===== Error on sample 286: low >= high
# KNN:  99%|█████████▊| 296/300 [01:01<00:00,  4.34it/s]
#  ===== Error on sample 296: low >= high
# KNN: 100%|██████████| 300/300 [01:02<00:00,  4.79it/s]
#  KNN Results:
#    AOPC: 0.3045 (±0.1752)
#    Comprehensiveness: 0.2949 (±0.2139)
#    Sufficiency: 0.0783 (±0.1397)
#
# ============================================================
# Evaluating LIME Fidelity for: RandomForest
# ============================================================
# RandomForest:   1%|          | 2/300 [00:00<00:21, 13.56it/s]
#  ===== Error on sample 0: low >= high
# RandomForest:   6%|▌         | 17/300 [00:02<00:36,  7.66it/s]
#  ===== Error on sample 15: low >= high
# RandomForest:  11%|█         | 33/300 [00:05<00:38,  7.00it/s]
#  ===== Error on sample 31: low >= high
# RandomForest:  18%|█▊        | 54/300 [00:09<00:33,  7.44it/s]
#  ===== Error on sample 52: low >= high
# RandomForest:  23%|██▎       | 68/300 [00:11<00:25,  9.23it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# RandomForest:  31%|███▏      | 94/300 [00:16<00:31,  6.52it/s]
#  ===== Error on sample 92: low >= high
# RandomForest:  33%|███▎      | 100/300 [00:17<00:28,  6.93it/s]
#  ===== Error on sample 98: low >= high
# RandomForest:  42%|████▏     | 126/300 [00:22<00:28,  6.19it/s]
#  ===== Error on sample 124: low >= high
# RandomForest:  44%|████▍     | 132/300 [00:23<00:23,  7.08it/s]
#  ===== Error on sample 130: low >= high
# RandomForest:  49%|████▉     | 147/300 [00:26<00:21,  7.01it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# RandomForest:  51%|█████▏    | 154/300 [00:26<00:18,  8.09it/s]
#  ===== Error on sample 152: low >= high
# RandomForest:  55%|█████▍    | 164/300 [00:28<00:18,  7.19it/s]
#  ===== Error on sample 162: low >= high
# RandomForest:  58%|█████▊    | 173/300 [00:29<00:14,  8.61it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# RandomForest:  66%|██████▌   | 198/300 [00:34<00:12,  8.18it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
# RandomForest:  68%|██████▊   | 203/300 [00:34<00:13,  7.21it/s]
#  ===== Error on sample 201: low >= high
# RandomForest:  72%|███████▏  | 216/300 [00:37<00:12,  6.88it/s]
#  ===== Error on sample 214: low >= high
# RandomForest:  74%|███████▍  | 223/300 [00:37<00:08,  9.18it/s]
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# RandomForest:  78%|███████▊  | 233/300 [00:39<00:10,  6.46it/s]
#  ===== Error on sample 231: low >= high
# RandomForest:  84%|████████▎ | 251/300 [00:43<00:07,  6.52it/s]
#  ===== Error on sample 249: low >= high
# RandomForest:  90%|█████████ | 271/300 [00:46<00:04,  6.65it/s]
#  ===== Error on sample 269: low >= high
# RandomForest:  92%|█████████▏| 276/300 [00:47<00:03,  7.10it/s]
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# RandomForest:  93%|█████████▎| 279/300 [00:47<00:02,  7.39it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
# RandomForest:  96%|█████████▌| 288/300 [00:49<00:01,  7.86it/s]
#  ===== Error on sample 286: low >= high
# RandomForest:  99%|█████████▉| 298/300 [00:50<00:00,  6.75it/s]
#  ===== Error on sample 296: low >= high
# RandomForest: 100%|██████████| 300/300 [00:51<00:00,  5.87it/s]
#  RandomForest Results:
#    AOPC: 0.1971 (±0.1379)
#    Comprehensiveness: 0.2086 (±0.1556)
#    Sufficiency: 0.0228 (±0.0465)
#
# ============================================================
# Evaluating LIME Fidelity for: GradientBoosting
# ============================================================
# GradientBoosting:   1%|▏         | 4/300 [00:00<00:07, 37.49it/s]
#  ===== Error on sample 0: low >= high
# GradientBoosting:   6%|▌         | 18/300 [00:00<00:10, 27.18it/s]
#  ===== Error on sample 15: low >= high
# GradientBoosting:  11%|█▏        | 34/300 [00:01<00:10, 25.89it/s]
#  ===== Error on sample 31: low >= high
# GradientBoosting:  19%|█▊        | 56/300 [00:02<00:09, 26.21it/s]
#  ===== Error on sample 52: low >= high
# GradientBoosting:  23%|██▎       | 70/300 [00:02<00:07, 29.64it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# GradientBoosting:  32%|███▏      | 96/300 [00:03<00:07, 25.67it/s]
#  ===== Error on sample 92: low >= high
#  ===== Error on sample 98: low >= high
# GradientBoosting:  43%|████▎     | 130/300 [00:05<00:07, 23.36it/s]
#  ===== Error on sample 124: low >= high
#  ===== Error on sample 130: low >= high
# GradientBoosting:  50%|█████     | 151/300 [00:06<00:05, 27.09it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# GradientBoosting:  53%|█████▎    | 158/300 [00:06<00:05, 26.91it/s]
#  ===== Error on sample 152: low >= high
# GradientBoosting:  55%|█████▌    | 165/300 [00:06<00:05, 26.08it/s]
#  ===== Error on sample 162: low >= high
# GradientBoosting:  59%|█████▊    | 176/300 [00:07<00:04, 28.07it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# GradientBoosting:  66%|██████▋   | 199/300 [00:07<00:03, 28.15it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
#  ===== Error on sample 201: low >= high
# GradientBoosting:  73%|███████▎  | 219/300 [00:08<00:03, 26.21it/s]
#  ===== Error on sample 214: low >= high
# GradientBoosting:  74%|███████▍  | 223/300 [00:08<00:02, 29.55it/s]
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# GradientBoosting:  79%|███████▉  | 237/300 [00:09<00:02, 25.65it/s]
#  ===== Error on sample 231: low >= high
# GradientBoosting:  84%|████████▍ | 252/300 [00:10<00:02, 23.30it/s]
#  ===== Error on sample 249: low >= high
# GradientBoosting:  91%|█████████ | 273/300 [00:11<00:01, 23.64it/s]
#  ===== Error on sample 269: low >= high
#  ===== Error on sample 274: low >= high
# GradientBoosting:  94%|█████████▍| 282/300 [00:11<00:00, 31.95it/s]
#  ===== Error on sample 276: low >= high
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
# GradientBoosting:  97%|█████████▋| 290/300 [00:11<00:00, 31.32it/s]
#  ===== Error on sample 286: low >= high
# GradientBoosting: 100%|██████████| 300/300 [00:11<00:00, 25.21it/s]
#  ===== Error on sample 296: low >= high
#
#  GradientBoosting Results:
#    AOPC: 0.0874 (±0.0805)
#    Comprehensiveness: 0.0942 (±0.0903)
#    Sufficiency: 0.0147 (±0.0330)
#
# ============================================================
# Evaluating LIME Fidelity for: MLP
# ============================================================
# MLP:   0%|          | 0/300 [00:00<?, ?it/s]
#  ===== Error on sample 0: low >= high
# MLP:   7%|▋         | 22/300 [00:00<00:09, 28.89it/s]
#  ===== Error on sample 15: low >= high
# MLP:  12%|█▏        | 36/300 [00:01<00:09, 28.55it/s]
#  ===== Error on sample 31: low >= high
# MLP:  19%|█▊        | 56/300 [00:02<00:08, 29.49it/s]
#  ===== Error on sample 52: low >= high
# MLP:  23%|██▎       | 70/300 [00:02<00:07, 31.96it/s]
#  ===== Error on sample 65: low >= high
#  ===== Error on sample 66: low >= high
# MLP:  33%|███▎      | 98/300 [00:03<00:07, 28.18it/s]
#  ===== Error on sample 92: low >= high
#  ===== Error on sample 98: low >= high
# MLP:  43%|████▎     | 129/300 [00:04<00:06, 24.68it/s]
#  ===== Error on sample 124: low >= high
# MLP:  44%|████▍     | 133/300 [00:04<00:05, 28.23it/s]
#  ===== Error on sample 130: low >= high
# MLP:  50%|█████     | 150/300 [00:05<00:04, 31.65it/s]
#  ===== Error on sample 145: low >= high
#  ===== Error on sample 147: low >= high
# MLP:  53%|█████▎    | 158/300 [00:05<00:04, 29.26it/s]
#  ===== Error on sample 152: low >= high
# MLP:  55%|█████▌    | 166/300 [00:06<00:04, 28.12it/s]
#  ===== Error on sample 162: low >= high
# MLP:  59%|█████▉    | 178/300 [00:06<00:03, 31.91it/s]
#  ===== Error on sample 170: low >= high
#  ===== Error on sample 171: low >= high
# MLP:  67%|██████▋   | 202/300 [00:07<00:03, 32.18it/s]
#  ===== Error on sample 195: low >= high
#  ===== Error on sample 196: low >= high
#  ===== Error on sample 201: low >= high
# MLP:  72%|███████▏  | 217/300 [00:07<00:02, 31.17it/s]
#  ===== Error on sample 214: low >= high
# MLP:  75%|███████▌  | 225/300 [00:08<00:02, 30.72it/s]
#  ===== Error on sample 220: low >= high
#  ===== Error on sample 221: low >= high
# MLP:  79%|███████▉  | 237/300 [00:08<00:02, 28.38it/s]
#  ===== Error on sample 231: low >= high
# MLP:  85%|████████▍ | 254/300 [00:09<00:01, 24.52it/s]
#  ===== Error on sample 249: low >= high
# MLP:  91%|█████████ | 273/300 [00:10<00:01, 26.64it/s]
#  ===== Error on sample 269: low >= high
#  ===== Error on sample 274: low >= high
#  ===== Error on sample 276: low >= high
# MLP:  95%|█████████▍| 284/300 [00:10<00:00, 35.10it/s]
#  ===== Error on sample 279: low >= high
#  ===== Error on sample 280: low >= high
#  ===== Error on sample 286: low >= high
# MLP: 100%|██████████| 300/300 [00:10<00:00, 27.57it/s]
#  ===== Error on sample 296: low >= high
#
#  MLP Results:
#    AOPC: 0.3270 (±0.1766)
#    Comprehensiveness: 0.3509 (±0.2003)
#    Sufficiency: 0.0145 (±0.0486)
#
# ✅ Fidelity results saved to 'lime_fidelity_results.csv'
#                 Model  AOPC_mean  AOPC_std  Comprehensiveness_mean  \
# 0  LogisticRegression   0.115330  0.073706                0.130873
# 1       MultinomialNB   0.125027  0.081497                0.146184
# 2           LinearSVC   0.108381  0.069057                0.114314
# 3       SGDClassifier   0.188948  0.107890                0.205701
# 4                 SVM   0.171685  0.133441                0.202662
# 5                 KNN   0.304476  0.175154                0.294887
# 6        RandomForest   0.197102  0.137852                0.208631
# 7    GradientBoosting   0.087433  0.080519                0.094160
# 8                 MLP   0.327025  0.176560                0.350910
#
#    Comprehensiveness_std  Sufficiency_mean  Sufficiency_std  n_samples
# 0               0.095235          0.010802         0.026228        269
# 1               0.105949          0.009269         0.021820        269
# 2               0.077226          0.008804         0.020349        269
# 3               0.126587          0.015364         0.040872        269
# 4               0.164584          0.012047         0.031584        269
# 5               0.213855          0.078261         0.139712        269
# 6               0.155577          0.022750         0.046543        269
# 7               0.090313          0.014730         0.032970        269
# 8               0.200347          0.014547         0.048597        269

# %% [markdown]
# #### 4.3 - Results and Visualization

# %%
def plot_fidelity_comparison(df_fidelity, save_path=FIGURES_PATH / 'lime_fidelity_comparison.png'):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    metrics = [
        ('AOPC_mean', 'AOPC_std', 'AOPC\n(Higher is Better)', 0),
        ('Comprehensiveness_mean', 'Comprehensiveness_std', 'Comprehensiveness\n(Higher is Better)', 1),
        ('Sufficiency_mean', 'Sufficiency_std', 'Sufficiency\n(Lower is Better)', 2)
    ]
    
    colors = plt.cm.viridis(np.linspace(0.2, 0.8, len(df_fidelity)))
    
    for metric_mean, metric_std, title, idx in metrics:
        ax = axes[idx]
        
        df_sorted = df_fidelity.sort_values(metric_mean, ascending=(idx != 2))
        
        bars = ax.barh(
            df_sorted['Model'], 
            df_sorted[metric_mean],
            xerr=df_sorted[metric_std],
            color=colors,
            edgecolor='black',
            linewidth=1.2,
            alpha=0.85,
            capsize=5
        )
        
        ax.set_xlabel('Score', fontsize=12, fontweight='bold')
        ax.set_title(title, fontsize=13, fontweight='bold', pad=15)
        ax.grid(axis='x', alpha=0.3, linestyle='--')
        ax.set_axisbelow(True)
        
        max_val = df_sorted[metric_mean].max()
        offset = max_val * 0.02 
        
        for i, (bar, val) in enumerate(zip(bars, df_sorted[metric_mean])):
            ax.text(val + offset, bar.get_y() + bar.get_height()/2, 
                   f'{val:.3f}', 
                   va='center', ha='left', 
                   fontsize=8, fontweight='bold',
                   bbox=dict(boxstyle='round,pad=0.3', facecolor='white', 
                            edgecolor='none', alpha=0.8))
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"\n💾 Plot saved as '{save_path}'")
    
    plt.show()
    
    return fig


plot_fidelity_comparison(df_fidelity, save_path= FIGURES_PATH / 'lime_fidelity_comparison.png')
# Out:
# 💾 Plot saved as '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/figures/lime_fidelity_comparison.png'

# %% [markdown]
# #### 4.4 - Fidelity Ranking

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_fidelity['AOPC_norm'] = scaler.fit_transform(df_fidelity[['AOPC_mean']])
df_fidelity['Comp_norm'] = scaler.fit_transform(df_fidelity[['Comprehensiveness_mean']])
df_fidelity['Suff_norm'] = 1 - scaler.fit_transform(df_fidelity[['Sufficiency_mean']])  

df_fidelity['Fidelity_Score'] = (
    df_fidelity['AOPC_norm'] + 
    df_fidelity['Comp_norm'] + 
    df_fidelity['Suff_norm']
) / 3

df_ranking = df_fidelity[[
    'Model', 
    'Fidelity_Score', 
    'AOPC_norm', 
    'Comp_norm', 
    'Suff_norm', 
    'AOPC_mean', 
    'Comprehensiveness_mean', 
    'Sufficiency_mean'
]].sort_values('Fidelity_Score', ascending=False)

df_ranking = df_ranking.round(4) 

print("\nLIME Fidelity Ranking (Combined Score):")
print("="*70)
display(df_ranking)

df_ranking.to_csv(METRICS_PATH / 'lime_fidelity_ranking.csv', index=False)
print("\nRanking saved to 'lime_fidelity_ranking.csv'")
# Out:
# LIME Fidelity Ranking (Combined Score):
# ======================================================================
#                 Model  Fidelity_Score  AOPC_norm  Comp_norm  Suff_norm  \
# 8                 MLP          0.9724     1.0000     1.0000     0.9173
# 3       SGDClassifier          0.5879     0.4237     0.4344     0.9056
# 4                 SVM          0.5759     0.3516     0.4226     0.9533
# 6        RandomForest          0.5676     0.4577     0.4458     0.7992
# 5                 KNN          0.5626     0.9059     0.7818     0.0000
# 1       MultinomialNB          0.4509     0.1569     0.2026     0.9933
# 0  LogisticRegression          0.4102     0.1164     0.1430     0.9712
# 2           LinearSVC          0.3886     0.0874     0.0785     1.0000
# 7    GradientBoosting          0.3049     0.0000     0.0000     0.9147
#
#    AOPC_mean  Comprehensiveness_mean  Sufficiency_mean
# 8     0.3270                  0.3509            0.0145
# 3     0.1889                  0.2057            0.0154
# 4     0.1717                  0.2027            0.0120
# 6     0.1971                  0.2086            0.0228
# 5     0.3045                  0.2949            0.0783
# 1     0.1250                  0.1462            0.0093
# 0     0.1153                  0.1309            0.0108
# 2     0.1084                  0.1143            0.0088
# 7     0.0874                  0.0942            0.0147
# Ranking saved to 'lime_fidelity_ranking.csv'

# %% [markdown]
# ### Setup - Experience 5

# %% [markdown]
# - **Correlation vs Causality**

# %% [markdown]
# - Using top_3_fake_compact and top_3_real_compact

# %% [markdown]
# - Check and save the sentences where these words are present

# %%
import numpy as np

# Nome do ficheiro de saída
output_filename = OUTPUT_PATH / "top_3_words_sentences.txt"

# --- 1. PREPARAÇÃO E LIMPEZA DA LISTA ---
raw_list = top_3_fake_compact['Top_3_Words'].tolist()
words_to_audit = []

for item in raw_list:
    if isinstance(item, str):
        # Remove caracteres de lista Python stringificada ([], '') e separa por vírgula
        cleaned = item.replace('[', '').replace(']', '').replace("'", "").replace('"', "")
        parts = cleaned.split(',')
        for part in parts:
            if part.strip():
                words_to_audit.append(part.strip())
    elif isinstance(item, list):
        words_to_audit.extend(item)

# Remove duplicados e ordena alfabeticamente
words_to_audit = sorted(list(set(words_to_audit)))

print(f"A preparar relatório para {len(words_to_audit)} palavras únicas...")
print(f"A escrever no ficheiro: {output_filename} ...")

# --- 2. LOOP DE AUDITORIA E ESCRITA NO FICHEIRO ---
with open(output_filename, "w", encoding="utf-8") as f:
    f.write(f"RELATÓRIO DE AUDITORIA DE PALAVRAS\n")
    f.write(f"Total de palavras analisadas: {len(words_to_audit)}\n")
    f.write("="*60 + "\n\n")

    for word_to_check in words_to_audit:
        try:
            # Tenta encontrar a palavra (usa lower() pois o vectorizer costuma normalizar)
            word_clean = str(word_to_check).lower()
            
            # Recupera índice e documentos
            feature_index = vectorizer.vocabulary_[word_clean]
            feature_column = X_test[:, feature_index]
            document_indices = np.where(feature_column.toarray().flatten() > 0)[0]

            # --- ESCREVENDO NO FICHEIRO ---
            f.write(f"PALAVRA: '{word_to_check}'\n")
            f.write(f"Ocorrências encontradas: {len(document_indices)}\n")
            f.write("-" * 40 + "\n")
            
            if len(document_indices) > 0:
                # Limite de frases para não tornar o txt gigante (opcional, aqui pus 10)
                limit = 10 
                for i, doc_index in enumerate(document_indices):
                    if i >= limit:
                        f.write(f"... [e mais {len(document_indices) - limit} textos omitidos]\n")
                        break
                    
                    # Extrair texto
                    if hasattr(texts_test, 'iloc'):
                        text_instance = texts_test.iloc[doc_index]
                    else:
                        text_instance = texts_test[doc_index]
                    
                    # Limpa quebras de linha do texto original para ficar bonito no txt
                    clean_text = str(text_instance).replace('\n', ' ').strip()
                    
                    # Escreve o ID e o Texto (Se for preciso limitar o numero de tokens mais para ter contexto)
                    f.write(f"[Doc ID {doc_index}]: {clean_text[:500]}...\n")
            else:
                f.write(" (Nenhuma ocorrência encontrada neste conjunto de teste)\n")
            
            f.write("\n" + "="*60 + "\n\n") # Separador entre palavras

        except KeyError:
            # Se a palavra não existe no vocabulário, regista isso também
            f.write(f"PALAVRA: '{word_to_check}'\n")
            f.write("STATUS: Não consta no vocabulário do Vectorizer (ignorada ou filtrada).\n")
            f.write("\n" + "="*60 + "\n\n")
            
        except Exception as e:
            f.write(f"ERRO ao processar '{word_to_check}': {str(e)}\n\n")

print(f"Concluído! Verifique o ficheiro '{output_filename}'.")
# Out:
# A preparar relatório para 17 palavras únicas...
# A escrever no ficheiro: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/top_3_words_sentences.txt ...
# Concluído! Verifique o ficheiro '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/top_3_words_sentences.txt'.

# %%
output_filename = OUTPUT_PATH / "frases_filtradas_por_classe.txt"

# --- 1. RECUPERAR A LISTA DE PALAVRAS (Mesma lógica de antes) ---
raw_list = top_3_fake_compact['Top_3_Words'].tolist()
words_to_audit = []

for item in raw_list:
    if isinstance(item, str):
        cleaned = item.replace('[', '').replace(']', '').replace("'", "").replace('"', "")
        parts = cleaned.split(',')
        for part in parts:
            if part.strip():
                words_to_audit.append(part.strip())
    elif isinstance(item, list):
        words_to_audit.extend(item)

words_to_audit = sorted(list(set(words_to_audit)))

# --- 2. ENCONTRAR OS ÍNDICES DAS FRASES RELEVANTES ---
# Usamos um 'set' para garantir que não repetimos a mesma frase 
# (caso a frase tenha 2 palavras da lista, só queremos que ela entre uma vez)
relevant_indices = set()

print(f"A procurar frases que contenham as {len(words_to_audit)} palavras-chave...")

for word in words_to_audit:
    try:
        word_clean = str(word).lower()
        feature_index = vectorizer.vocabulary_[word_clean]
        
        # Pega na coluna correspondente a esta palavra
        feature_column = X_test[:, feature_index]
        
        # Encontra os índices dos documentos onde esta palavra aparece
        doc_indices = np.where(feature_column.toarray().flatten() > 0)[0]
        
        # Adiciona ao conjunto de índices relevantes
        relevant_indices.update(doc_indices)
        
    except KeyError:
        continue # Palavra não está no vocabulário, ignora

print(f"Total de frases únicas encontradas: {len(relevant_indices)}")

# --- 3. ORGANIZAR E ESCREVER NO FICHEIRO POR CLASSE ---
print(f"A escrever no ficheiro '{output_filename}'...")

with open(output_filename, "w", encoding="utf-8") as f:
    
    # Converter o set para lista para podermos iterar
    final_indices = list(relevant_indices)
    
    # --- GRUPO FAKE (Class 1) ---
    f.write("=== CLASS: FAKE ===\n")
    count_fake = 0
    for idx in final_indices:
        # Verifica se a classe desta frase é 1 (Fake)
        # Nota: ajusta o acesso ao y_test dependendo se é Series ou Array
        label = y_test.iloc[idx] if hasattr(y_test, 'iloc') else y_test[idx]
        
        if label == 1:
            if hasattr(texts_test, 'iloc'):
                text = texts_test.iloc[idx]
            else:
                text = texts_test[idx]
            
            clean_text = str(text).replace('\n', ' ').strip()
            if len(clean_text) > 5:
                f.write(f"{clean_text}\n")
                count_fake += 1

    # --- GRUPO REAL (Class 0) ---
    f.write("\n=== CLASS: REAL ===\n")
    count_real = 0
    for idx in final_indices:
        # Verifica se a classe desta frase é 0 (Real)
        label = y_test.iloc[idx] if hasattr(y_test, 'iloc') else y_test[idx]
        
        if label == 0:
            if hasattr(texts_test, 'iloc'):
                text = texts_test.iloc[idx]
            else:
                text = texts_test[idx]
                
            clean_text = str(text).replace('\n', ' ').strip()
            if len(clean_text) > 5:
                f.write(f"{clean_text}\n")
                count_real += 1

print(f"Concluído! Foram gravadas {count_fake} frases FAKE e {count_real} frases REAL contendo as palavras-chave.")
# Out:
# A procurar frases que contenham as 17 palavras-chave...
# Total de frases únicas encontradas: 80
# A escrever no ficheiro '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/frases_filtradas_por_classe.txt'...
# Concluído! Foram gravadas 51 frases FAKE e 29 frases REAL contendo as palavras-chave.

# %%
# --- CONFIGURAÇÃO ---
# Substitua pelo nome real da coluna de texto no seu DataFrame original
coluna_texto_original = 'text'  # Ex: 'noticia_completa', 'text', 'body'
coluna_classe = 'misinformation'         # Ex: 'fake', 'label' (0 ou 1)
nome_dataframe = df             # O seu dataframe original carregado (antes do split)

output_filename = OUTPUT_PATH / "frases_originais_para_augment.txt"

# --- 1. RECUPERAR PALAVRAS (Código padrão) ---
raw_list = top_3_fake_compact['Top_3_Words'].tolist()
words_to_audit = []
for item in raw_list:
    if isinstance(item, str):
        cleaned = item.replace('[', '').replace(']', '').replace("'", "").replace('"', "")
        parts = cleaned.split(',')
        for part in parts:
            if part.strip():
                words_to_audit.append(part.strip())
    elif isinstance(item, list):
        words_to_audit.extend(item)
words_to_audit = sorted(list(set(words_to_audit)))

# --- 2. ENCONTRAR ÍNDICES REAIS ---
# Vamos usar um Set para guardar os índices REAIS do dataframe original
indices_reais_para_auditar = set()

print(f"A rastrear índices originais para {len(words_to_audit)} palavras...")

for word in words_to_audit:
    try:
        word_clean = str(word).lower()
        feature_index = vectorizer.vocabulary_[word_clean]
        
        # Pega na coluna no X_test
        feature_column = X_test[:, feature_index]
        internal_indices = np.where(feature_column.toarray().flatten() > 0)[0]
        
        # O TRUQUE: Mapear índice interno do X_test -> Índice Real do DataFrame
        # y_test.index contém os índices originais preservados pelo train_test_split
        for internal_idx in internal_indices:
            real_index = y_test.index[internal_idx]
            indices_reais_para_auditar.add(real_index)
            
    except KeyError:
        continue

print(f"Encontradas {len(indices_reais_para_auditar)} notícias originais contendo as palavras.")

# --- 3. EXTRAIR DO DATAFRAME ORIGINAL E SALVAR ---
print(f"A escrever textos originais em '{output_filename}'...")

with open(output_filename, "w", encoding="utf-8") as f:
    
    # Converter para lista para processar
    lista_indices = list(indices_reais_para_auditar)
    
    # -- CLASSE FAKE (1) --
    f.write("=== CLASS: FAKE ===\n")
    count = 0
    for real_idx in lista_indices:
        # Aceder ao DF original
        try:
            row = nome_dataframe.loc[real_idx]
            label = row[coluna_classe]
            
            if label == 1: # Se for Fake
                texto_cru = row[coluna_texto_original]
                # Remove quebras de linha para o ficheiro ficar limpo
                texto_limpo = str(texto_cru).replace('\n', ' ').strip()
                if len(texto_limpo) > 10:
                    f.write(f"{texto_limpo}\n")
                    count += 1
        except KeyError:
            print(f"Erro: Índice {real_idx} não encontrado no DF original.")

    # -- CLASSE REAL (0) --
    f.write("\n=== CLASS: REAL ===\n")
    for real_idx in lista_indices:
        try:
            row = nome_dataframe.loc[real_idx]
            label = row[coluna_classe]
            
            if label == 0: # Se for Real
                texto_cru = row[coluna_texto_original]
                texto_limpo = str(texto_cru).replace('\n', ' ').strip()
                if len(texto_limpo) > 10:
                    f.write(f"{texto_limpo}\n")
        except KeyError:
            pass

print(f"Sucesso! {count} textos FAKE originais prontos para geração.")
# Out:
# A rastrear índices originais para 17 palavras...
# Encontradas 80 notícias originais contendo as palavras.
# A escrever textos originais em '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI - LIME/experiments/output/frases_originais_para_augment.txt'...
# Sucesso! 51 textos FAKE originais prontos para geração.

# %% [markdown]
# ### Experience 5 - LIME & PTT5

# %% [markdown]
# - To adapt Polyjuice to portuguese language i will create synthetic data with distillation

# %% [markdown]
# **Design and Taxonomy of Control**
#
# Definition of the eight control codes (like Polyjuice) to guide my own generator:
# - [negation]: add or remove negation ("é bom" -> "não é bom")
# - [quantification]: replace quantities ("muitos" -> "alguns")
# - [insertion]: add a new adjective or adverb
# - [remotion]: remove a non-essential word
# - [substitution]: replacing a word with a synonym or antonym (lexical change)
# - [restructure]: change the voice (active/passive) or the sentence order.
# - [soften]: To make the tone less intense ("horrível" to "mau")
# - [Intensify]: To make the tone stronger ("bom" to "excelente").

# %% [markdown]
# **Generate Synthetic Data**
#
# I use Gemini 2.5 Flash to generate my training dataset.
#
# The goal is to create a file "polyjuice_pt_train.json" with a range of 5000-10000 examples.
#
# The input used is reviews sentences from the B2W-Reviews dataset.
#
# Prompt used: "És um especialista em linguística portuguesa. Gera pares de contrafactuais para treinar um modelo de XAI. Dada uma frase original, gera 3 variações aplicando códigos de controlo específicos.
# Regras:
# A variação deve ser mínima (preservar a maior parte do texto original).
# A gramática deve ser perfeita em Português Europeu (ou BR, escolhe um padrão).
# Deves fornecer o output estritamente em JSON: [{'original': '...', 'control_code': '[negar]', 'counterfactual': '...'}]"

# %% [markdown]
# **Training the model**
#
# The model that i trained to generate the inference was T5: unicamp-dl/ptt5-base-portuguese-vocab [https://huggingface.co/unicamp-dl/ptt5-base-portuguese-vocab]
#
# Data format: text-to-text
# - Input: gerar contrafactual: [negar] O serviço foi extremamente lento.
# - Target: O serviço não foi extremamente lento.
#
# Training Hyperparameters:
#
# | Batch Size | Learning Rate | Epochs | Weight Decay |Optimizer |
# | --- | --- | --- | --- | --- |
# | 8 or 16 or 32 | 1e-4 or 2e-4 or 5e-4 | 5 to 10 (monitoring val. loss) | 0 or 0.1 or 0.01 | AdamW |

# %% [markdown]
# **Selection Mechanism**
#
# Post-processing inference pipeline:
# - Equality Filter: if input == output (model failed - discard)
# - Perplexity Filter: i used a soft causal model (pierreguillou/gpt2-small-portuguese) to measure the perplexity of the generated sentence and defined a threshold to guaranted the text was natural.

# %% [markdown]
# **Evaluation**
#
# Evaluation Configuration:
# - Validation Encoder: used BERTimbau (neuralmind/bert-base-portuguese-cased) to generate embeddings
# - Metric 1 - Proximity: calculated the cossene distance between the original text embedding and the generated counterfactual text embedding (the distance has to be lower than if i used a random method)
# - Metric 2 - Connectedness: ran the DBSCAN on the generated counterfactuals embeddings to verify if they form dense clusters or they are noise.
# - Metric 3 - Success Rate: used a PT sentiment classifier to verify if the generated text change the class.

# %% [markdown]
# - Generate Dataset with Gemini 2.5 Pro via API

# %%
import google.generativeai as genai
from google.generativeai.types import HarmCategory, HarmBlockThreshold
import json
import time
import os
import re
from tqdm import tqdm
from datasets import load_dataset
from dotenv import load_dotenv
# Out:
# /var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/ipykernel_4085/1144159923.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")

if not api_key:
    print("ERRO: Chave API não encontrada. Verifique o seu ficheiro .env")
else:
    # 3. Configurar a API
    genai.configure(api_key=api_key)

    print("--- Modelos Disponíveis para Geração de Texto ---")
    try:
        for m in genai.list_models():
            # Filtramos apenas os modelos que conseguem gerar conteúdo
            if 'generateContent' in m.supported_generation_methods:
                print(f"Nome: {m.name}")
                print(f"   Descrição: {m.description}")
                print(f"   Limite de Entrada: {m.input_token_limit} tokens")
                print("-" * 40)
    except Exception as e:
        print(f"Erro ao listar modelos: {e}")
# Out:
# --- Modelos Disponíveis para Geração de Texto ---
# Nome: models/gemini-2.5-flash
#    Descrição: Stable version of Gemini 2.5 Flash, our mid-size multimodal model that supports up to 1 million tokens, released in June of 2025.
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-pro
#    Descrição: Stable release (June 17th, 2025) of Gemini 2.5 Pro
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash-exp
#    Descrição: Gemini 2.0 Flash Experimental
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash
#    Descrição: Gemini 2.0 Flash
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash-001
#    Descrição: Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in January of 2025.
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash-lite-001
#    Descrição: Stable version of Gemini 2.0 Flash-Lite
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash-lite
#    Descrição: Gemini 2.0 Flash-Lite
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash-lite-preview-02-05
#    Descrição: Preview release (February 5th, 2025) of Gemini 2.0 Flash-Lite
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.0-flash-lite-preview
#    Descrição: Preview release (February 5th, 2025) of Gemini 2.0 Flash-Lite
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-exp-1206
#    Descrição: Experimental release (March 25th, 2025) of Gemini 2.5 Pro
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-flash-preview-tts
#    Descrição: Gemini 2.5 Flash Preview TTS
#    Limite de Entrada: 8192 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-pro-preview-tts
#    Descrição: Gemini 2.5 Pro Preview TTS
#    Limite de Entrada: 8192 tokens
# ----------------------------------------
# Nome: models/gemma-3-1b-it
#    Descrição:
#    Limite de Entrada: 32768 tokens
# ----------------------------------------
# Nome: models/gemma-3-4b-it
#    Descrição:
#    Limite de Entrada: 32768 tokens
# ----------------------------------------
# Nome: models/gemma-3-12b-it
#    Descrição:
#    Limite de Entrada: 32768 tokens
# ----------------------------------------
# Nome: models/gemma-3-27b-it
#    Descrição:
#    Limite de Entrada: 131072 tokens
# ----------------------------------------
# Nome: models/gemma-3n-e4b-it
#    Descrição:
#    Limite de Entrada: 8192 tokens
# ----------------------------------------
# Nome: models/gemma-3n-e2b-it
#    Descrição:
#    Limite de Entrada: 8192 tokens
# ----------------------------------------
# Nome: models/gemini-flash-latest
#    Descrição: Latest release of Gemini Flash
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-flash-lite-latest
#    Descrição: Latest release of Gemini Flash-Lite
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-pro-latest
#    Descrição: Latest release of Gemini Pro
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-flash-lite
#    Descrição: Stable version of Gemini 2.5 Flash-Lite, released in July of 2025
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-flash-image-preview
#    Descrição: Gemini 2.5 Flash Preview Image
#    Limite de Entrada: 32768 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-flash-image
#    Descrição: Gemini 2.5 Flash Preview Image
#    Limite de Entrada: 32768 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-flash-preview-09-2025
#    Descrição: Gemini 2.5 Flash Preview Sep 2025
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-flash-lite-preview-09-2025
#    Descrição: Preview release (Septempber 25th, 2025) of Gemini 2.5 Flash-Lite
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-3-pro-preview
#    Descrição: Gemini 3 Pro Preview
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-3-flash-preview
#    Descrição: Gemini 3 Flash Preview
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-3-pro-image-preview
#    Descrição: Gemini 3 Pro Image Preview
#    Limite de Entrada: 131072 tokens
# ----------------------------------------
# Nome: models/nano-banana-pro-preview
#    Descrição: Gemini 3 Pro Image Preview
#    Limite de Entrada: 131072 tokens
# ----------------------------------------
# Nome: models/gemini-robotics-er-1.5-preview
#    Descrição: Gemini Robotics-ER 1.5 Preview
#    Limite de Entrada: 1048576 tokens
# ----------------------------------------
# Nome: models/gemini-2.5-computer-use-preview-10-2025
#    Descrição: Gemini 2.5 Computer Use Preview 10-2025
#    Limite de Entrada: 131072 tokens
# ----------------------------------------
# Nome: models/deep-research-pro-preview-12-2025
#    Descrição: Preview release (December 12th, 2025) of Deep Research Pro
#    Limite de Entrada: 131072 tokens
# ----------------------------------------

# %% [markdown]
# - **Teacher Configuration**

# %% [markdown]
# Configuração do Gemini para agir como professor que vai criar os dados (frases contrafactuais).

# %%
# ==========================================
# 1. CONFIGURAÇÃO (GEMINI 2.5 FLASH)
# ==========================================

# Login via API KEY
genai.configure(api_key=api_key)

# Configurações de segurança no mínimo para não bloquear notícias
# Para este dataset de notícias posso precisar de frases com estes conteúdos
safety_settings = {
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}

# Objeto que vai gerar o texto
model_teacher = genai.GenerativeModel(
    model_name="models/gemini-2.5-flash", # Modelo rápido e com alta quota
    safety_settings=safety_settings,
    # Para obrigar o Gemini a responder apenas em formato JSON 
    generation_config={
        "response_mime_type": "application/json", 
        "temperature": 0.8 # Um pouco mais criativo para variar as alterações
    }
)

# %% [markdown]
# - Load the ASSIN 2 dataset via Hugging Face

# %% [markdown]
# ASSIN 2 - contém frases em Português de alta qualidade para servir de inspiração ao modelo Teacher

# %%
# ==========================================
# 2. CARREGAR ASSIN 2 (VIA HUGGING FACE)
# ==========================================

print("Loading ASSIN 2 Dataset...")
try:
    # Carregamos a versão de treino do ASSIN 2
    dataset_assin = load_dataset("assin2", split="train")
    
    print(f"Colunas encontradas: {dataset_assin.column_names}") 
    
    # Convertemos para lista Python normal antes de somar
    # Premisa: Frase Original 
    lista_premissas = list(dataset_assin['premise'])
    # Hipótese: Frase Relacionada
    lista_hipoteses = list(dataset_assin['hypothesis'])
    
    # Agora somamos as listas e fazemos o set para remover duplicados
    # Junta duas listas numa gigante
    # O set não permite elementos repetidos - ao converter a lista para set elimina automaticamente qualquer frase duplicada do dataset
    # Converte de novo para lista para ser possível utilizar
    frases_input = list(set(lista_premissas + lista_hipoteses))
    
    print(f"ASSIN 2 Uploaded! {len(frases_input)} informative sentences available.")

# Caso a Internet falhe ou o HuggingFace esteja em baixo o código não crash
except Exception as e:
    print(f"Error loading ASSIN 2 Dataset: {e}")
    frases_input = ["O governo anunciou novas medidas económicas.", "A seleção nacional venceu o jogo ontem."]
# Out:
# Loading ASSIN 2 Dataset...
# Colunas encontradas: ['sentence_pair_id', 'premise', 'hypothesis', 'relatedness_score', 'entailment_judgment']
# ASSIN 2 Uploaded! 4140 informative sentences available.

# %%
frases_input
# Out:
# ['A flauta está sendo tocada por um homem',
#  'O carro branco de um homem está sendo levado',
#  'Uma bicicleta está sendo pedalada por um homem',
#  'Um homem está sentado em uma cadeira e esfregando seus olhos',
#  'Uma mulher está usando um lápis para olhos e está aplicando delineador em sua pálpebra',
#  'Um menino está batendo numa bola de beisebol',
#  'Um cachorro preto está pulando de uma doca para uma lagoa',
#  'Um elefante bebê está comendo uma árvore pequenina',
#  'Três infantes estão correndo morro abaixo',
#  'Um rinoceronte, que é pequeno, está seguindo um rinoceronte adulto',
#  'Um cachorro está perseguindo a cauda de um animal na grama',
#  'Um homem está preparando algum prato',
#  'Uma senhora está sendo beijada por um homem',
#  'Um jogador de roxo, branco e preto está jogando perto do final do campo',
#  'Os corredores não estão participando da corrida',
#  'A menina com um capacete está empoleirada em uma bicicleta',
#  'Alguém está tocando piano',
#  'Alguns ciclistas estão voando sobre a pista perto da água e a linha do horizonte',
#  'Uma menina da Ásia, em frente a uma janela feita de tijolos, parece surpresa',
#  'Um gato está comendo um pouco de milho',
#  'O homem está despejando pepinos fatiados na água fria',
#  'Um avião de desenho está pousando',
#  'Um cachorro preto está correndo na grama',
#  'Uma banana está sendo descascada por uma pessoa',
#  'Um homem está limpando a pia',
#  'Um homem está parado no topo das rochas com nuvens atrás',
#  'Um gato preto está balançando em um ventilador',
#  'Uma pessoa está montando um touro mecânico',
#  'O chefe está cuidadosamente despejando óleo dentro de uma frigideira',
#  'Um homem está saindo do carro',
#  'Uma mulher está picando uma cebola',
#  'Um homem está sentado em um barco de frente para o pôr do sol, perto de uma bandeira',
#  'O violão está sendo tocado pelo homem, que tem o estojo do violão aberto para doações',
#  'O homem está apagando o trabalho de outro homem do painel',
#  'Não tem nenhum homem correndo na estrada',
#  'A mulher usando calça prata com boca de sino rosa e um cachecol vermelho está andando de bicicleta alegremente',
#  'Alguma pessoa está de pé em um vasto campo de gelo glacial',
#  'Duas crianças estão penduradas em um galho grande',
#  'Uma pessoa está olhando para uma moto projetada para motocross que está deitada de lado e outra está correndo por ali',
#  'Alguém está caindo de um cavalo',
#  'Três homens estão pulando de um muro alto',
#  'Quatro meninos estão ajoelhados próximos uns aos outros em frente a uma bola',
#  'Alguém está colocando ingredientes em uma wok',
#  'Uma pessoa está andando em uma moto motorizada em um evento relacionado a motocross',
#  'Um homem está abruptamente caindo de um cavalo em uma pista na natureza',
#  'Uma pessoa está rasgando papel',
#  'Adultos e crianças de pé estão brincando em frente de degraus próximos a uma área arborizada',
#  'Alguém está mexendo macarrão na água',
#  'Uma mulher vestindo luvas rosas e jaqueta marrom está sorrindo na neve',
#  'Uma senhora loira está olhando uma torre',
#  'O homem está de pé estavelmente ao lado de uma gaiola de pássaros',
#  'O microfone em frente ao papagaio falante está sendo silenciado',
#  'Um lêmure está segurando em uma corda',
#  'O macaco está escovando um buldogue',
#  'Uma mulher está praticando wakeboard em um lago',
#  'A pessoa que está praticando snowboard pula pelo ar',
#  'Os filhotes de gato estão comendo a comida nas bandejas',
#  'Não tem nenhum trem de brinquedo batendo em um carro de brinquedo',
#  'Um homem vestido de preto e branco está segurando uma raquete de tênis e aguardando pela bola',
#  'Não tem nenhuma mulher espremendo o suco de um limão',
#  'Os dados de cor laranja estão sendo lançados por um cozinheiro para ganhar a pimenta',
#  'Uma criança está cantando e tocando um violão',
#  'Um menino molhado está alegremente pulando na grama suja e molhada',
#  'Alguém está descascando uma banana',
#  'Um capacete preto está sendo usado por um homem que está empurrando uma bicicleta',
#  'O menino está sentado perto do oceano azul',
#  'Um homem está tocando uma flauta feita de bambu',
#  'Não tem nenhum homem fritando uma tortilha',
#  'Uma menina pequena está saindo do palco',
#  'Três meninas jovens estão dançando no cômodo',
#  'Um cachorro está correndo morro acima',
#  'Um menino está passando pela areia',
#  'Um grupo de cachorros criados para corrida está usando uniformes listrados e está correndo pelo caminho',
#  'A pessoa está descascando uma cebola',
#  'Uma criança está vestindo shorts vermelhos e está pulando em uma piscina infantil',
#  'Duas equipes estão jogando futebol de campo',
#  'Um grupo de amigos está navegando a corrente em um bote',
#  'O elefante não está sendo montado pela mulher',
#  'Um cachorro castanho e preto está correndo pelas folhas',
#  'O homem está concedendo uma entrevista',
#  'Um homem está cortando tomates',
#  'Um cachorro preto e branco está carregando uma grande vara na grama verde',
#  'Uma mulher está usando protetor auricular e está atirando com uma arma em um estande de tiro ao ar livre',
#  'O jogador está enterrando a bola de basquete e uma multidão está ao fundo',
#  'Duas pessoas estão lutando com os punhos em um ringue',
#  'Um homem está desenhando em uma lousa digital',
#  'Uma bola, que é verde e grande, está golpeando uma batata',
#  'Não tem nenhum menino olhando para um calendário',
#  'Um homem está tocando piano',
#  'Alguém está em um cavalo',
#  'Um menino está afastando o violão',
#  'As pessoas vestindo figurinos estão se reunindo em uma floresta e estão olhando na mesma direção',
#  'Não tem nenhum homem tocando dois teclados',
#  'Um pequeno cachorro preto está usando uma coleira vermelha e está no meio das folhas com uma bola azul',
#  'O homem está temperando a carne',
#  'A pista de patinação no gelo colocada ao ar livre está cheia de pessoas',
#  'Este peixe está nadando',
#  'A mulher está despejando óleo na frigideira',
#  'Alguns peixes estão nadando',
#  'As pessoas estão sentadas sem rumo em um banco em frente a um restaurante',
#  'Um homem está correndo na estrada',
#  'Uma criança de pele bronzeada está olhando para a câmera',
#  'Uma mulher está abrindo um refrigerante e o bebendo',
#  'Dois homens estão brigando em um pasto para vacas',
#  'Não tem nenhum homem sentado na cadeira',
#  'Um homem está misturando',
#  'Um indivíduo está cortando um tomate',
#  'O menino está brincando entusiasmadamente na lama',
#  'Um menino está sentado em uma sala e está tocando piano ao lado de uma luminária',
#  'O animal com olhos grandes está comendo',
#  'Um cachorro branco está usando uma tiara de rena de Natal e está brincando com um cachorro castanho na grama',
#  'O homem está sendo derrubado do cavalo',
#  'Uma mulher está cortando um peixe',
#  'Uma mulher está passando batom',
#  'Duas meninas estão rindo e outras meninas estão olhando-as',
#  'Um homem está cortando uma árvore com um machado',
#  'O homem não está praticando kickboxing com um treinador',
#  'A criança jovem está espirrando água',
#  'Não tem nenhuma pessoa usando chapéu e sentada na grama',
#  'Um menino está jogando fora um calendário',
#  'A pessoa está indo para o mar',
#  'Um cachorro com pelagem caramelo está pulando para cima e pegando uma bola de tênis',
#  'Uma mulher está cortando algumas flores',
#  'Um bebê tigre está brincando com uma bola',
#  'Um carro de rali branco está jogando lama no ar e está se aproximando de uma curva na pista',
#  'Um menino pequeno com um babador está assistindo a câmera',
#  'Uma criança está espirrando água',
#  'Uma pessoa vestindo jeans está sentada feliz no topo de uma sela de cavalo',
#  'Um cachorro branco grande está pulando para cima na neve',
#  'Uma mulher está fatiando alho',
#  'Um filhote de cachorro está rolando de um lado para outro de costas repetidamente',
#  'Um menino está pendurando uma vara de pesca e correndo na frente de um peixe',
#  'Um grou, que é grande e branco, está voando perto da água',
#  'Um chefe está preparando uma refeição',
#  'Um homem está de pé em um jipe \u200b\u200bpreto em um morro de terra',
#  'Uma menina está cortando a manteiga em dois pedaços',
#  'Um policial está sentado em uma motocicleta',
#  'O policial está sentado em uma bicicleta de policial',
#  'Um menino está dizendo uma palavra',
#  'Uma placa de papel está sendo cortada por um homem',
#  'Uma menina está derretendo dois pedaços de manteiga juntos',
#  'O menino não está brincando na lama',
#  'Quatro pessoas estão flutuando em um bote',
#  'Uma menina em uma banda está tocando a flauta',
#  'Uma criança está acordando devagar',
#  'Um pai está empurrando sua filha em um carrinho de kart e outra menina está observando',
#  'Um homem está caminhando na floresta',
#  'A mulher está pegando um bebê canguru',
#  'Um homem está imprudentemente subindo em uma corda',
#  'Algumas pessoas em uma corrida de arrancada estão olhando para as chamas que estão saindo dos carros',
#  'Duas meninas estão brincando dentro de uma casinha de pula-pula',
#  'As mulheres estão dançando do lado de fora',
#  'O sol está brilhando na face da menina que está com o vestido tingido de amarelo',
#  'Uma mulher está esfregando uma abobrinha com uma escova de vegetais',
#  'Um cavalo branco está sendo cavalgado por um homem com um chapéu azul de vaqueiro',
#  'Uma menina em um uniforme, que é azul, está rapidamente levantando seu braço',
#  'Um homem está segurando uma máscara em sua mão levantada',
#  'Um homem fazendo exercícios está sendo derrubado',
#  'Uma pessoa com uma camisa verde está pulando alto sobre a grama',
#  'A pessoa está andando de moto em uma pista arenosa',
#  'Dois homens estão lutando',
#  'Um homem está telefonando',
#  'O homem está jogando um jogo na grama',
#  'Um grande animal branco está pulando para cima na neve',
#  'Um homem está acompanhando uma mulher pela floresta',
#  'Um homem está escalando uma parede feita de pedra e outro homem está segurando a corda',
#  'Um homem e uma mulher estão de pé parados no bosque',
#  'Uma tartaruga marinha não está caçando peixes',
#  'Um homem está tocando um violão embaixo de uma janela',
#  'Não tem nenhuma mulher dançando e cantando na chuva',
#  'Duas crianças jovens estão usando chapéus e mostrando suas línguas coloridas',
#  'Um homem está fazendo um truque de bicicleta',
#  'Um homem não está cautelosamente alimentando com um rato a cobra',
#  'Um pequenino cachorro castanho e branco está correndo na calçada',
#  'Um animal está correndo em círculos',
#  'Uma mulher está fatiando tofu',
#  'Algum cachorro castanho e preto está correndo pelas folhas',
#  'Dois salsichas estão brincando com uma bola vermelha',
#  'Uma criança jovem está correndo ao ar livre sobre as folhas caídas',
#  'Dois homens estão jogando tênis de mesa',
#  'O cavalo marrom está muito perto de um barril vermelho no rodeio',
#  'Um homem está andando a cavalo no deserto',
#  'Um homem está comendo',
#  'Uma pessoa vestindo jeans está sentada em cima de uma sela de cavalo',
#  'Um homem está colocando alho em algumas fatias de pão',
#  'Dois homens estão passeando dois cachorros com pelagens douradas na neve',
#  'Um homem está caminhando ao longo de uma pista através da natureza',
#  'Um motociclista sem capacete está esperando em uma moto azul perto da estrada',
#  'Um homem calvo em uma banda está tocando violão na luz',
#  'Um cachorro castanho e branco está pulando no ar com uma bola de tênis na boca',
#  'Crianças cobertas de folhas estão brincando com camisas vermelhas',
#  'A mulher está pegando e segurando um bebê canguru',
#  'Não tem nenhum homem comendo alguma comida',
#  'A mulher está mexendo carne em uma tigela',
#  'Uma mulher está rapidamente praticando snowboard ladeira abaixo e outra mulher está de pé atrás dela',
#  'Os homens estão colocando bagagens dentro do porta-malas de um carro',
#  'Uma mulher está praticando com uma flauta',
#  'Dois cachorros na grama estão brincando com um brinquedo de plástico',
#  'Uma pessoa está segurando um gambá',
#  'Uma menina da Ásia, em frente a uma janela de tijolos, não parece surpresa',
#  'Cinco crianças estão em pé juntas e uma criança tem uma arma',
#  'O peixe está sendo frito por uma mulher',
#  'Um homem está segurando uma placa e está buscando dinheiro',
#  'Duas pessoas estão andando com cestas carregadas e cobertores',
#  'Uma mulher está vestindo um casaco longo e preto e um chapéu marrom e está caminhando por um parque com um monte de árvores florescendo',
#  'Uma criança está brincando com uma bica de água ao ar livre e o resto de sua família está assistindo',
#  'Uma pessoa está dobrando um pedaço de papel',
#  'Um homem está pegando uma lata',
#  'O homem musculoso está dançando e o homem atrás dele está usando miçangas verdes',
#  'Não tem nenhum homem despejando óleo em uma frigideira',
#  'O homem e o menino estão parados no topo das escadas, que estão ao ar livre',
#  'Uma pessoa está tocando apaixonadamente um violão na frente de um público',
#  'Uma criança vestindo uma camisa listrada está correndo com os pés descalços no morro arenoso',
#  'Três adolescentes estão morgando no quarto',
#  'As pessoas em uma corrida de arrancada estão olhando para as chamas que estão saindo dos carros',
#  'O homem e a mulher não estão andando',
#  'Os médicos não estão revivendo um homem',
#  'Um homem está entrando em um carro',
#  'Bebidas estão sendo seguradas por pessoas apontando para a câmera',
#  'Uma menina com rosto pintado está em pé ao lado de outras crianças',
#  'Uma menina está escovando seus cabelos',
#  'Uma menina está tocando um instrumento de sopro',
#  'Um cachorro está lambendo um bebê',
#  'Um cachorro branco e um cachorro preto estão correndo lado a lado na grama verde',
#  'Um jogador de futebol de campo está chutando a bola dentro do gol',
#  'Um cachorro negro está saltando de um fardo de feno cilíndrico',
#  'O papagaio está silencioso em frente ao microfone',
#  'Um menino de camiseta vermelha está na frente de uma parede, que é longa e azul, e está desconfiadamente levantando uma sobrancelha para a câmera',
#  'Um grupo de mulheres está usando orelhas de coelho rosa e está apontando para a direita',
#  'Alguns meninos estão pulando de uma plataforma',
#  'Um homem está montando um cavalo em uma terra arenosa',
#  'Não tem nenhuma banda tocando',
#  'A mulher está bebendo',
#  'Um homem está quebrando um bloco de concreto com uma marreta',
#  'Um cachorro preto está pulando de uma doca dentro da água',
#  'Um jogador de futebol de uniforme vermelho e branco está sendo erguido por dois colegas de time',
#  'Três pessoas estão dirigindo quadriciclos',
#  'Uma mulher está cozinhando ovos',
#  'Um homem está espalhando massa',
#  'Algum homem barbado está em pé perto de um carrinho de compras e está segurando uma placa de papelão',
#  'O homem está vestindo um traje de mergulho e está montando uma prancha de surf',
#  'Cinco pessoas estão paradas na grama com três cachorros',
#  'Uma menina está praticando o piano',
#  'Uma pessoa está dançando na chuva',
#  'Um cachorro grande está escalando selvagemente um morro íngreme',
#  'Uma mulher está usando óculos escuros de tamanho grande e está segurando jornais nas duas mãos',
#  'O homem está fatiando batatas',
#  'A noiva e o noivo estão partindo após o casamento',
#  'Um menino está pulando para fora do lado de uma fonte de água feita de pedra em frente a um prédio',
#  'Os homens estão correndo uma corrida',
#  'A bola de futebol não está entre os pés de um menino que está deitado na grama',
#  'Uma mulher está refrigerando uma batata',
#  'Alguns homens em uma competição estão correndo no exterior',
#  'A peça é sobre um menino feliz tocando piano',
#  'Um cozinheiro está fatiando alguns pimentões',
#  'O homem sem camisa com shorts listrados e óculos de sol está de pé perto de um homem com uma camisa branca e óculos de sol',
#  'Um homem está despejando um prato de queijo ralado em uma panela de molho',
#  'Não tem nenhuma pessoa escrevendo',
#  'Um cavalo marrom está longe de um barril vermelho em um rodeio',
#  'Um adolescente está tocando o violão',
#  'Um cavalo e seu cavaleiro estão pulando rapidamente sobre uma barreira',
#  'Um homem está rezando',
#  'Os homens estão jogando com uma bola',
#  'Uma pessoa está cuspindo',
#  'O gato está olhando para fora da janela na mesa do poleiro',
#  'Uma pessoa usando calça cinza está pulando no ar em um snowboard',
#  'Um jogador de basquete está no chão da quadra e a bola está sendo agarrada por outro',
#  'Uma pessoa está tirando a carne da sautese',
#  'Um peixe não está nadando',
#  'Um homem com chapéu preto está tocando uma caixa de papelão',
#  'Um homem está de pé ao lado de uma gaiola de pássaros que é grande e colorida',
#  'Um homem está guardando um trompete',
#  'Uma pessoa está dirigindo um jet ski nas ondas',
#  'O homem está cuidadosamente alimentando uma cobra com um rato',
#  'Alguns homens estão correndo em uma corrida',
#  'O homem está limpando o desenho da lousa',
#  'Um cachorro de pelos muito longos e uma roupinha vermelha está correndo na grama',
#  'Um homem está vestindo uma camisa de xadrez azul e está andando feliz de monociclo na rua',
#  'Não tem nenhum macaco vadeando através de um pântano',
#  'Duas pessoas estão olhando para uma estátua de ouro',
#  'Não tem nenhuma criança segurando uma pistola de água',
#  'Crianças de camisas vermelhas estão dormindo nas folhas',
#  'A mulher não está despejando óleo em uma sautese',
#  'O homem está entrando na água',
#  'O homem de camiseta tingida de cinza está sentado em uma pedra na frente de uma cachoeira',
#  'Dois cachorros estão brincando na neve',
#  'Uma criança, que tem cabelo loiro, está segurando uma garrafa amarela',
#  'Um homem de terno está sendo cercado por fotógrafos',
#  'Não tem nenhum urso panda comendo um pouco de bambu',
#  'Alguém está saltando no ar em uma prancha',
#  'O menino jovem de camisa azul está pulando para dentro da água',
#  'Um piloto de motocross está dando uma moto para uma pessoa em um evento',
#  'Um cachorro está animadamente brincando com água na grama',
#  'Uma pessoa está acariciando o pelo de um gato',
#  'Um homem de patins está patinando em uma pista de skate',
#  'Duas meninas estão sentadas no chão',
#  'Uma criança pequena está espirrando água dentro de uma piscina infantil azul',
#  'Um cachorro que tem uma pelagem castanha e branca está sentado no raso',
#  'Uma mulher está picando brócolis',
#  'Um cachorro que é peludo e preto está no quintal e está carregando uma cesta em sua boca',
#  'O cachorro está nadando em um lago e o sol está brilhando nele',
#  'Um homem está lavando um grande pedaço de carne',
#  'Três homens estão olhando para a distância',
#  'Um pai está jogando a filha na piscina',
#  'Um homem está parado no meio de uma academia e está usando uma camisa de time',
#  'Uma mulher está habilmente tocando uma flauta',
#  'Não há nenhuma pessoa cortando uma cebola',
#  'Um menino, que é jovem, está tocando um instrumento de sopro',
#  'Um homem está dirigindo um carro',
#  'Uma mulher está usando peças de fantasia e tinta e está andando de bicicleta em uma rua vazia',
#  'Um homem está correndo estrada abaixo',
#  'Um menino pequeno está mostrando sua língua para a câmera e outro menino está olhando',
#  'Uma pessoa está untando uma assadeira',
#  'Um cachorro castanho e branco está se movendo pela grama selvagem',
#  'Uma mulher está fervendo ovos',
#  'Uma menina está caindo no sono',
#  'O homem de chapéu branco está tocando violão no palco',
#  'Não tem nenhum homem fatiando cebola',
#  'Uma pessoa está despejando óleo para cozinhar em uma panela',
#  'Uma mulher de vestido vermelho está tocando um instrumento',
#  'Um oficial está conversando com os recrutas',
#  'Um homem com tatuagens está descansando em um sofá e segurando um lápis',
#  'Um cachorro preto está pulando de uma doca para dentro da água',
#  'Uma mulher está removendo ingredientes de uma tigela',
#  'Uma batata está sendo fatiada pelo homem',
#  'Dois homens estão segurando varas de pescar',
#  'Uma mulher está se apresentando na chuva',
#  'Um gato está abrindo uma gaveta e escalando para dentro',
#  'Um menino está cortando a grama com tesouras',
#  'Um filhote de gato está bebendo leite fresco',
#  'Algumas pessoas estão dançando',
#  'Não tem nenhum homem imprudentemente andando a cavalo',
#  'Dois homens e uma menina na frente de uma parede de madeira estão fazendo caretas engraçadas',
#  'Um gato com pelagem branca, empoleirado em um pequeno armário de madeira, está olhando para fora da janela',
#  'Não tem nenhum motociclista pilotando uma moto ao longo de uma estrada',
#  'Não tem nenhuma senhora misturando uma mistura de carne em uma tigela',
#  'Um cachorro vermelho e castanho está enfiando seu focinho na sacola de presente',
#  'Alguns ciclistas estão fazendo acrobacias em um caminho perto da água e um horizonte',
#  'Um homem vestido de preto elegantemente está usando uma máscara preta elaborada',
#  'Uma mulher com uma camisa tingida de amarelo está surfando em uma prancha de surf rosa',
#  'Um cachorro castanho está correndo na neve',
#  'O homem está tirando uma foto dele mesmo e de outro cara',
#  'Pessoas não estão jogando críquete',
#  'O macarrão está sendo fervido em água por uma mulher',
#  'Uma motocicleta está sendo pilotada por um homem',
#  'Um mágico está cortando uma menina em dois pedaços como se fosse manteiga',
#  'Uma família está comprando algo em uma máquina de venda',
#  'Um cachorro, que é grande e cinza, está carregando uma bola na boca e correndo através da grama',
#  'O homem está atirando facas na árvore',
#  'As crianças estão brincando em uma fonte que está espirrando água do chão',
#  'Duas mulheres com cachorros estão andando em um caminho de um bosque',
#  'Um homem está cantando para uma mulher',
#  'O animal está pastando na grama',
#  'Uma camisa preta está sendo vestida por um homem que está sentado na mesa e rindo',
#  'Um homem está dançando com um capacete usado',
#  'Um jogador de futebol está usando braçadeiras pretas',
#  'O chefe está cuidadosamente despejando óleo na frigideira',
#  'A pessoa está voando pelo ar na bicicleta',
#  'A mulher não está usando óculos ou touca',
#  'Um homem está dançando na chuva',
#  'A menina está carregando uma placa e um grupo de pessoas está a seguindo',
#  'Um homem está realizando uma parada de mão na praia',
#  'Uma criança está espirrando água em uma piscina para crianças e outros meninos estão brincando ao fundo',
#  'Não tem nenhuma mulher preparando um ovo em uma sautese',
#  'Um homem e uma mulher estão caminhando pela floresta',
#  'O homem está cantando e tocando o violão',
#  'Uma menina está tocando violão',
#  'Uma menina jovem está em pé em um grupo e está vestindo uma camisa preta e miçangas rosas',
#  'Algumas pessoas estão de pé',
#  'Um cachorro preto e branco com um grande galho está correndo na grama',
#  'Uma mulher está rachando alguns ovos em uma tigela',
#  'O piano está sendo tocado por alguém',
#  'Um homem rindo está tingindo uma camisa de preto em uma mesa na qual você não pode se sentar',
#  'Um grupo de pessoas estão vadeando pela água',
#  'Um homem está sacudindo uma bebida',
#  'Um jovem menino está tocando violão',
#  'Uma mulher está escovando sua mão',
#  'Quatro homens jovens estão explodindo e um carro está parado atrás deles',
#  'Uma senhora está misturando uma mistura feita de carne em uma tigela',
#  'Um homem está chutando uma bola de futebol de campo com força',
#  'A menina está carregando uma placa e está sendo seguida por um grupo de pessoas',
#  'Um menino pequeno está orgulhosamente usando uma camisa de futebol verde e está correndo na grama',
#  'Um grupo de pessoas está perto do oceano',
#  'Uma mulher está amalgamando ovos',
#  'Times diferentes estão jogando futebol no campo',
#  'Um homem está picando manteiga em um recipiente',
#  'Uma criança está sentada em um carro de brinquedo vermelho e amarelo',
#  'Um gato está se afastando de um pouco de milho',
#  'Não tem nenhum macaco chutando a mão com luva de uma pessoa',
#  'Algumas pessoas estão sentadas em um banco debaixo de umas palmeiras',
#  'Um menino está falando com uma folha',
#  'Um homem em uma motocicleta está virando a esquina',
#  'Um cão pastor está agrupando um rebanho de ovelhas',
#  'O cervo está saltando sobre a cerca',
#  'Uma menina está de pé em um grupo e está usando uma camisa preta e miçangas rosas',
#  'Um cachorro preto e um cachorro branco estão lutando no chão',
#  'Uma pessoa está rapidamente cortando cogumelos com uma faca',
#  'Um homem está arrumando uma máquina de taquigrafia',
#  'Uma mulher asiática está segurando um cachecol de pele',
#  'Dois cachorros estão olhando para uma bancada de cozinha',
#  'Um homem está usando um capacete preto e empurrando uma bicicleta',
#  'Um homem está andando a cavalo',
#  'Um homem está comendo alguma comida',
#  'A mulher está alegremente tocando um violão, que é acústico, e cantando',
#  'Um menino pequeno de roupa de ginástica está em uma poça na rua',
#  'Uma pessoa está picando uma cebola roxa',
#  'Um jovem homem em uma bicicleta bmx está pulando de uma pirâmide',
#  'Dois bebês pandas estão brincando',
#  'Uma pessoa que está praticando snowboard cai pelo ar',
#  'O macaco não está praticando artes marciais',
#  'A mulher está apagando o desenho no quadro',
#  'Um homem está jogando uma criança na piscina que está perto do oceano',
#  'Uma mulher está atirando em um alvo de prática',
#  'Não tem nenhum homem de pé sobre um telhado tocando um violino',
#  'Calça boca de sino rosa e cachecol rosa não estão sendo usados por mulheres com calças prateadas ou pessoas andando de bicicleta',
#  'Três mulheres estão sentadas juntas perto de paredes de tecido',
#  'Uma mulher está despejando ovos em uma panela',
#  'Um homem de jaqueta vermelha está de pé perto de um caiaque amarelo sobre algumas rochas no oceano',
#  'Um homem com equipamento de escalada está pendurado em uma rocha, que é vertical e branca',
#  'Não tem nenhum homem sentado no chão tocando violão',
#  'O homem está tocando o violão',
#  'O menino está tocando o piano',
#  'Um homem está cortando uma corda grossa com uma espada',
#  'Não tem nenhum homem falando no palco',
#  'Algumas campainhas estão soando perto de um cozinheiro fatiando pimentas',
#  'Um cavalo branco está parado',
#  'Uma criança está correndo para dentro e para fora das ondas oceânicas',
#  'Um cachorro castanho e branco está descansando na grama',
#  'Uma flauta de madeira é tocada por um homem',
#  'Um homem solitário está em um estacionamento e está jogando tênis contra um grande muro',
#  'Uma mulher está esvaziando a água de uma caneca',
#  'Um homem está fatiando tomates',
#  'Uma mulher está usando protetor auricular e está disparando uma arma em um campo de tiro coberto',
#  'O ciclista está acelerando em uma rua da cidade',
#  'Uma chita está perseguindo sem ar sua presa através de um campo',
#  'Um cavalo está sendo cavalgado por uma menina',
#  'Uma mulher está usando uma camisa, que é azul, com um colete branco e um boné branco e está falando e caminhando',
#  'O teclado está sendo tocado com o nariz por um homem',
#  'A mulher e o homem estão viajando de automóvel',
#  'Um homem está andando no quintal',
#  'O pedaço de papel não está sendo cortado',
#  'Não tem nenhum cachorro lambendo um bebê',
#  'Um homem está fazendo um truque de skate em uma varanda',
#  'Um homem está ficando de pé cansadamente ao lado de um ônibus',
#  'Os jogadores de futebol de vermelho e branco estão pulando e se abraçando',
#  'Uma mulher e um cachorro estão sentados tranquilamente em um toco de árvore',
#  'Uma pequena menina com cabelos loiros está sorrindo e sentada em um balanço',
#  'Alguém está batendo uma lente de câmera contra um prego',
#  'A mulher não está rachando dois ovos em uma tigela de vidro',
#  'Os médicos estão revivendo um homem',
#  'As pessoas estão andando por uma rua que está lotada',
#  'Uma pessoa na motocicleta está levantando um braço',
#  'Uma pessoa anda de bicicleta por uma trilha',
#  'Duas pessoas estão dirigindo uma motocicleta',
#  'Uma criança está descendo a rua e um jipe está parando',
#  'A mulher está sentada em um banco e está usando uma jaqueta cinza e calça preta',
#  'Não tem nenhuma mulher fatiando um dente de alho',
#  'Uma menina está vestindo uma camiseta e tem a sua boca aberta',
#  'Um homem está segurando um pequenino animal em uma mão',
#  'Não tem nenhum homem despejando um pouco de óleo nos tomates',
#  'Um grande grupo de pessoas asiáticas está comendo em um restaurante',
#  'O homem está empinando uma motocicleta em um campo que é praticamente árido',
#  'O homem está desenhando',
#  'Um homem está conversando',
#  'O cachorro branco usando orelhas de rena está próximo de um cachorro castanho',
#  'Um grupo de pessoas está em uma praia',
#  'Alguns animais estão fora da água',
#  'Um homem está fatiando batatas',
#  'Um jovem casal está dormindo na cama',
#  'O cachorro pequeno está correndo na areia',
#  'Um homem barbado está em pé perto de um carrinho de compras e está segurando uma placa de papelão',
#  'Um grupo de jogadores de futebol está correndo no campo',
#  'Um cachorro castanho peludo está atravessando a área gramada',
#  'Um jogador de futebol de campo está marcando um gol',
#  'Uma flauta está sendo tocada de maneira adorável por uma menina',
#  'Um cachorro que é peludo e preto está em um quintal dos fundos e está carregando uma cesta em sua boca',
#  'Um menino debaixo de um guarda-chuva está sendo segurado por seu pai que está vestindo um casaco tingido de azul',
#  'Um homem está pilotando uma moto em um evento relacionado a motocross',
#  'Um homem está adicionando pedaços de manteiga a uma tigela de misturas',
#  'Uma chita está sendo sacudida por sua presa através de um campo',
#  'Um cachorro preto e branco está brincando com uma bola de vôlei destruída em um campo marrom',
#  'Dois cachorros estão dormindo perto de uma árvore',
#  'As pessoas estão sentadas em mesas quadradas em um quarto vermelho',
#  'Um menino embaixo de um guarda-chuva está sendo segurado por seu pai que está usando um casaco azul',
#  'Um cachorro está latindo para uma bola',
#  'Algumas pessoas estão cantando',
#  'Um menino sorridente de roupas de inverno está acenando suas mãos enluvadas do lado de fora de um prédio na neve',
#  'O homem de camiseta cinza está sentado em uma pedra em frente a cachoeira',
#  'Um buldogue está sendo escovado pelo macaco',
#  'Uma menina pequena está sorrindo e correndo para fora',
#  'O homem está sentado do lado de fora sob um guarda-chuva roxo',
#  'Um macaco está chutando raivosamente um alvo',
#  'Um homem em uma moto está pilotando na pista e acenando',
#  'Alguém está despejando a carne em uma frigideira',
#  'Um menino jovem está tocando um instrumento de sopro',
#  'Dois homens estão tocando violão',
#  'Uma pessoa está cortando uma cebola em cubos',
#  'Um homem está picando rapidamente alguns cogumelos com uma faca',
#  'Um cachorro castanho está correndo por um caminho nevado',
#  'Duas pessoas estão discutindo perto de uma multidão',
#  'Uma fita está sendo girada por uma menina de rosa',
#  'O homem está mexendo o óleo',
#  'As pessoas estão andando de bote e remando',
#  'Um homem está atirando com uma arma de fogo',
#  'Alguma coisa está sendo celebrada por um ciclista frio',
#  'Uma pessoa está despejando azeite de oliva dentro de uma panela no fogão',
#  'Uma pessoa está dançando',
#  'Duas pessoas usando roupas para neve estão no chão fazendo anjos da neve',
#  'Uma batata está sendo descascada por uma mulher',
#  'O equipamento de montanhismo está firmemente posicionado em frente ao ciclista em pé',
#  'Um homem está removendo a pele de uma cebola',
#  'Uma criança jovem vestida para o clima frio está de pé lá fora',
#  'Um cachorro preto e um branco estão correndo alegremente na grama',
#  'Alguém está dando comida a um animal',
#  'A jovem mulher de camisa tingida de vermelho está soprando uma bolha que é gigante',
#  'Não tem muitas pessoas no parque de patinação no gelo',
#  'Um truque de mágica está sendo performado pelo mágico',
#  'Algumas pessoas que jogam rúgbi estão se enfrentando',
#  'Algumas mulheres estão sentadas juntas perto de paredes de tecidos',
#  'Uma pessoa está sentada',
#  'O homem está correndo na estrada',
#  'O urso panda está deitado sobre os troncos',
#  'A menina está sentada no sofá e está fazendo crochê',
#  'Um cachorro preto está saltando de uma bola de feno para outra bola de feno',
#  'Uma foto dele mesmo e outro cara está sendo tirada pelo homem',
#  'Uma mulher está distraidamente descascando uma batata',
#  'A mulher está tocando um violão elétrico',
#  'Um homem está restaurando azulejos com suas mãos',
#  'Uma mulher está misturando ovos',
#  'O menino não está tocando o piano',
#  'Um cachorro preto e um cachorro amarelo estão brincando um com o outro',
#  'Um homem está sentado no chão e está tocando um violão',
#  'O padre está descendo o corredor para casar um casal',
#  'Um homem está guardando o violão',
#  'Um sapato está sendo amarrado por um homem',
#  'Uma criança está sorrindo para a câmera e nadando debaixo de água',
#  'Ninguém está sentado confortavelmente no banco',
#  'A pessoa está brincando com um crânio',
#  'Alguém está dobrando um pedaço de papel',
#  'Uma mulher está costurando com uma máquina',
#  'A pessoa não está fatiando cebolas',
#  'Um casal está olhando um guia de rua',
#  'Duas pessoas estão na neve, usando roupas que oferecem camuflagem',
#  'Uma mulher está pulando com uma bicicleta',
#  'Duas mulheres estão dançando',
#  'Um homem está picando um tronco com um machado',
#  'Um macaco está puxando a cauda de um cachorro',
#  'O sol está brilhando no rosto da menina que está de vestido amarelo',
#  'Um policial está sentado cansadamente em uma motocicleta',
#  'Dois cachorros de raças diferentes estão se olhando através da rua',
#  'Um grupo de pessoas está em silêncio',
#  'Um homem está removendo uma cenoura de uma máquina',
#  'Dois meninos assustados estão conversando no telefone',
#  'Os vegetais estão sendo fatiados por um homem',
#  'Um homem está sentado no gramado e bebendo de uma garrafa de água',
#  'Uma mulher está mostrando um cachorro pequenino para uma criança',
#  'Um cachorro está pegando uma bola',
#  'O surfista está surfando uma grande onda',
#  'Uma menina está usando uma camisa rosa que tem escrita branca e está ficando deitada na grama',
#  'Não tem nenhum gato deslizando de cabeça para baixo debaixo de um sofá',
#  'Um animal está pulando em uma bola de futebol azul brilhante em um campo de folhas secas',
#  'Uma pessoa está tomando suco de laranja e caminhando',
#  'Um cachorro branco com manchas beges está correndo por um campo',
#  'Quatro homens jovens estão fugindo e um carro está permanecendo parado atrás deles',
#  'Um cachorro está comendo uma boneca',
#  'Uma flauta está sendo tocada por um homem',
#  'O homem está usando uma marreta para quebrar um bloco de concreto que está sobre outra pessoa',
#  'Um jogador de futebol de campo está chutando uma bola para fora do gol',
#  'Um homem está espancando um menino com uma espada de plástico',
#  'Um avião está voando',
#  'Um cachorro, que é grande e cinza, está carregando uma bola em sua boca com dificuldade e correndo através da grama',
#  'Um cachorro, que é branco, está em pé nas folhas caídas',
#  'A jovem e tranquila menina está deitada sobre a grama de camisa rosa',
#  'Uma mulher está sentada e olhando para a cachoeira',
#  'Várias pessoas estão passando na fronteira de uma ponte',
#  'Peixe está sendo cozido por uma mulher',
#  'Uma menina está tocando um violão',
#  'Um homem de bicicleta está pedalando na praia',
#  'O homem não está tocando uma flauta',
#  'Um leão está cansadamente andando ansiosamente em uma jaula',
#  'Um cachorro está perseguindo outro e está segurando uma vara na sua boca',
#  'Jogadores de futebol de campo estão chutando uma bola de futebol de campo no gol',
#  'Uma velha mulher está vestindo uma camisa com um padrão de rosas e está desajeitadamente carregando dois jornais',
#  'Uma mulher está dançando com graça',
#  'A pimenta está sendo fatiada por uma mulher com uma faca',
#  'Um lápis está sendo apontado pela máquina',
#  'O homem está cuidadosamente alimentando a cobra com um rato',
#  'Uma menina pequena está tocando o piano',
#  'Um homem está sentado no bosque',
#  'Uma senhora está surfando e pegando uma onda',
#  'Duas mulheres estão dançando e cantando em frente a muitas pessoas',
#  'Um cachorro branco e um preto estão correndo alegremente lado a lado na grama',
#  'Uma mulher de camisa amarela está surfando em uma prancha rosa',
#  'Uma mulher está fritando algo em uma frigideira',
#  'Um homem de terno está de pé em frente a um microfone e cantando',
#  'A mulher não está tocando um violão, que é acústico, ou cantando',
#  'Alguém está coçando a barriga de um animal',
#  'Um leão está cansando todo o curral andando ansiosamente',
#  'Duas pessoas estão na neve segurando dois cachorros com pelagens douradas',
#  'Um animal está rastejando sob uma peça de mobiliário',
#  'A banda está cantando',
#  'Poucos furões estão escalando para fora da gaiola',
#  'Uma menina com uma sacola preta está em um trem lotado',
#  'Um homem está andando na chuva',
#  'Uma pessoa habilidosa está andando de bicicleta sobre uma roda',
#  'A criança está espirrando água em uma piscina',
#  'Não tem ninguém na costa',
#  'Um lápis está sendo apontado',
#  'Uma menina de uniforme, que é azul, está levantando seu braço',
#  'Um homem está realizando um truque em uma prancha de surf na água',
#  'Uma mulher está tirando a casca de uma batata',
#  'Um cachorro está mordendo uma lata',
#  'Não tem nenhum homem fatiando um tomate',
#  'Dois homens estão carregando cestas coloridas e cobertores e andando perto de um prédio',
#  'Uma mulher não está tocando um violão elétrico',
#  'Um cachorro está pastoreando um grupo de ovelhas brancas em uma fazenda empoeirada',
#  'Uma mulher está fatiando uma pimenta que é grande',
#  'Uma menina loira está olhando para as ondas',
#  'O pedaço de papel está sendo cortado',
#  'Diversos nadadores estão pulando para fora de água',
#  'Um cachorro está perseguindo uma bola',
#  'Uma menina, que é pequena, está tocando piano',
#  'Uma criança está encarando as ondas do oceano',
#  'O homem está comendo cereal',
#  'Uma mulher está cortando as batatas',
#  'O cachorro está se divertindo com um brinquedo',
#  'O homem está distraidamente comendo uma banana perto de uma árvore',
#  'Uma pessoa está tocando trompete',
#  'Duas crianças pequenas estão comendo em um carrinho muito pequenino cheio de enroladinhos',
#  'A menina de azul está perseguindo o jogador com um número na camisa de time',
#  'Um peixe está sendo fatiado por um homem',
#  'Um homem está comendo uma banana',
#  'Uma pessoa com equipamento de escalada rosa passou a corda pela rocha',
#  'Um gato está tocando um teclado',
#  'Uma mulher, sem sapato, está sentada com um cobertor sob um guarda-chuva lilás',
#  'Não tem nenhuma mulher limpando o camarão',
#  'Uma pessoa está penteando o pelo de um gato',
#  'A criança está imóvel na neve',
#  'Um homem está rasgando as fotos de um lago',
#  'Uma mulher está puxando uma gosma pegajosa para fora de uma tigela',
#  'O óleo está sendo derramado em uma sautese pela mulher',
#  'O homem não está tocando intensamente o violão',
#  'A criança pequenina está andando pela água e está sendo guiada por outra pessoa',
#  'A pessoa está voando pelo ar em uma bicicleta',
#  'As crianças estão usando calças pretas e pulando',
#  'Uma pessoa jovem de camisa branca e chapéu dourado e preto está sentada com as pernas cruzadas',
#  'O cachorro castanho e o cachorro preto estão na grama',
#  'O carro do motorista é estacionado por um homem',
#  'Um homem está cortando uma fatia de pão',
#  'Uma mulher está colocando carne em uma frigideira',
#  'Batatas estão sendo fatiadas por um homem',
#  'Uma mulher está cortando uma cebola',
#  'A mulher está dançando e um homem está tocando o teclado',
#  'Um cachorro dourado está correndo por um campo de grama alta',
#  'O homem está fazendo exercício',
#  'Não há nenhuma mulher dançando em uma gaiola',
#  'O homem está em pé sobre uma montanha, que é rochosa, e nuvens cinzas estão ao fundo',
#  'Os filhotes de gatos nas bandejas estão sendo comidos como alimentos para uma propaganda',
#  'A flauta está sendo tocada por uma mulher',
#  'Uma mulher está sendo lambuzada com uma substância marrom e uma multidão embaçada está ao fundo',
#  'Um pássaro, que é preto, está sentado em uma árvore morta',
#  'A pessoa na motocicleta está levantando seu braço',
#  'Um casal está sentado em um pátio e está encarando o oceano',
#  'Um grupo de quatro cachorros castanhos estão brincando em um campo de grama marrom',
#  'Um homem está andando perigosamente de moto por uma cidade',
#  'Um cachorro grande está subindo um morro íngreme',
#  'Uma grande flauta está sendo tocada por um homem',
#  'Uma criança de camiseta branca está espirrando água no raso',
#  'Um pequeno trem preto está na sacola de uma menina',
#  'Um menino está penteando seu cabelo',
#  'O conteúdo de uma tigela está sendo misturado por um homem',
#  'Uma mulher está se livrando de uma flauta',
#  'O gato está brincando com uma melancia',
#  'O homem está encenando em um microfone e está cantando',
#  'Um homem com uma camisa de time está enterrando uma bola em um jogo de basquete',
#  'Dois cachorros estão sendo acariciados por um homem',
#  'Um homem está assustado',
#  'Duas pessoas estão de pé no oceano e vendo o pôr do sol',
#  'A mulher está pegando um canguru que é pequeno',
#  'Uma mulher está quebrando um ovo em uma tigela',
#  'Um elefante está sendo montado por uma mulher',
#  'Um cara está aparando o gramado',
#  'Uma bicicleta está sendo pedalada por uma mulher usando peças de fantasia e tinta em uma rua movimentada',
#  'Três pessoas estão paradas ao lado de um galho de árvore',
#  'Não há nenhuma mulher fatiando uma berinjela',
#  'Uma mulher está dançando e cantando na chuva',
#  'Uma menina pequenina está dirigindo um carro de brinquedo',
#  'Um cachorro escuro preto e um cachorro castanho claro estão brincando no quintal',
#  'Uma mulher está usando um lápis de olho e está aplicando delineador em sua pálpebra',
#  'Alguns nadadores estão competindo em um lago',
#  'Uma pessoa está cortando alguns cogumelos',
#  'Uma menina adolescente está guardando miçangas que são vermelhas',
#  'Uma mulher está preparando um ovo em uma sautese',
#  'Dois cachorros estão brincando em uma praia',
#  'Um menino na adolescência está falando com uma menina com uma webcam',
#  'Uma pessoa em uma jaqueta azul está pulando de uma parede de cimento alta',
#  'Um animal está correndo cansadamente em círculos',
#  'Um grupo de crianças em uniformes está parado em um portão e uma está beijando a mãe',
#  'Um cachorro preto e um cachorro caramelo estão brigando',
#  'Uma menina está usando língua de sinais',
#  'Um homem e uma mulher estão andando por uma área arborizada',
#  'A senhora está pegando o canguru',
#  'Um homem está atirando com uma arma',
#  'Duas crianças estão olhando para a câmera e uma está mostrando a língua',
#  'Não tem nenhum homem andando do lado de fora',
#  'Um homem está apresentando-se com um violão',
#  'Uma mulher está cortando batatas',
#  'Um adulto está no anfiteatro e está falando seriamente com um menino',
#  'Uma criança está conversando',
#  'Um chefe está cozinhando uma refeição',
#  'A menina está sentada no sofá e fazendo crochê',
#  'Os homens de shorts marrons estão andando nas rochas ao lado de um rio',
#  'O homem está despejando pepinos fatiados na água',
#  'Um homem está dançando em um telhado',
#  'Um cachorro preto e branco está brincando com uma bola de voleibol esfarrapada em um campo marrom',
#  'Uma mulher está dançando sozinha',
#  'Uma mulher de jeans está sentada na sela de um cavalo',
#  'O menino está tocando um instrumento musical',
#  'Um homem está fatiando a cenoura com uma máquina',
#  'Uma jovem mulher com roupa indiana e henna na mão está passando por burocracia',
#  'Um cavalo está parado',
#  'Tofu não está sendo fatiado pela mulher',
#  'Uma pessoa está cortando uma cebola em pedaços',
#  'Um homem está cortando cebolas',
#  'Um bebê rinoceronte e sua mãe estão em pé em uma jaula',
#  'A corrente está sendo navegada por um grupo de amigos em um bote',
#  'Uma montanha está sendo escalada por dois homens',
#  'Algum gato está brincando com uma melancia',
#  'Um menino está de pé fora da água',
#  'Não tem nenhum homem tocando violão',
#  'Uma menina loira está suspensa por cordas de ginástica',
#  'Três pessoas estão dirigindo veículos de quatro rodas em um campo',
#  'Uma criança jovem está usando botas verdes e brincando em uma poça cheia de lama',
#  'Um homem com um chapéu tingido de roxo está operando uma câmera que faz vídeos',
#  'Um menino pequeno está correndo no chão e brincando com a menina pequena',
#  'O animal com grandes olhos está comendo vorazmente',
#  'Uma batata está sendo cortada por um homem',
#  'O homem está fatiando vegetais',
#  'Um cachorro está correndo para cima de um morro cheio de grama',
#  'Nem todo mundo é capaz de passear com um leão',
#  'Um cachorro castanho está olhando atentamente para um cachorro castanho e branco',
#  'Alguns cavalos estão competindo furiosamente sobre a grama verde e pulando um obstáculo',
#  'O homem com cabelo castanho está usando óculos de sol e está sentado em uma mesa com latas de refrigerante e outras bebidas',
#  'O ciclista está pedalando sobre o topo de uma cerca',
#  'Um bebê está lambendo um cachorro',
#  'Dois homens estão de pé perto da água e estão segurando ferramentas de pesca',
#  'Vários nadadores estão pulando na água',
#  'Um homem está de pé no topo de um telhado e tocando um violino',
#  'Um animal preto está pulando de uma doca para a água',
#  'Um homem está tocando um piano',
#  'O homem está conversando no aparelho de telefone',
#  'A senhora está fatiando um tomate',
#  'Mulheres estão usando orelhas de coelho e números de corrida e estão curiosamente apontando para algo distante',
#  'Uma mulher está olhando a vista de uma cidade',
#  'Os homens estão lutando com seus punhos em um ringue',
#  'Não tem nenhum homem cuspindo',
#  'Um lêmure está comendo rapidamente',
#  'O cachorro está perseguindo a bola',
#  'Dois homens estão competindo em uma corrida de pneus',
#  'Um cachorro está pulando no ar no interior',
#  'Uma pessoa está despejando óleo de cozinha em uma panela',
#  'Dois homens estão segurando bicicletas e parados ao lado de uma estrada coberta de neve',
#  'Uma mulher está andando a cavalo',
#  'O homem está rachando ovos em uma tigela',
#  'A mulher com um suéter branco está fazendo uma tatuagem na mão de um adolescente',
#  'Alguém está limpando um animal',
#  'Um piano está sendo tocado por alguém',
#  'Uma pessoa está olhando uma moto de motocross que está deitada de lado e outra está correndo por ali',
#  'Os corredores estão correndo em uma competição',
#  'Uma pessoa está andando de bicicleta na areia ao lado do oceano',
#  'A mulher está brincando com dois jovens meninos em um parque',
#  'Uma menina da Ásia, na frente de uma janela de tijolos, parece surpresa',
#  'O avião sul-africano está voando no céu azul',
#  'Dois crocodilos estão nadando em uma piscina verde perto de crianças brincando',
#  'Duas mulheres jovens estão brigando em uma luta de kickboxing',
#  'Um teclado está sendo tocado por uma pessoa',
#  'Alguém está em uma motocicleta preta e branca e está sentado no assento',
#  'Um homem está praticando bateria',
#  'Duas crianças e um adulto não estão parados próximos a um galho de árvore',
#  'A menina de uniforme azul e branco está torcendo',
#  'Um homem e uma mulher estão dirigindo pela estrada abaixo em um carro',
#  'Um homem todo equipado está usando um capacete com logotipo do patrocinador e está pilotando uma motocicleta esportiva vermelha',
#  'Um homem em uma camisa tingida de roxo está se afastando de um homem com uma camisa preta, que está sério',
#  'Uma entrevista está sendo concedida pelo homem',
#  'A menina está passando lápis de olho em sua pálpebra',
#  'Um grupo de crianças está brincando em um quintal e um homem velho está parado ao fundo',
#  'Uma pessoa está fritando comida em uma frigideira',
#  'Duas crianças estão escalando uma árvore',
#  'Um homem está fazendo exercícios no chão',
#  'Um homem está jogando um jogo com uma bola',
#  'A senhora está quebrando ovos que estão crus dentro de uma tigela',
#  'Um cachorro castanho e branco está atravessando a grama alta',
#  'Um homem de azul está andando em um animal em uma estrada de terra',
#  'Uma menina de vestido branco está correndo',
#  'O menino está borrifando as plantas com água',
#  'As mulheres estão serrando troncos',
#  'Um cachorro está nadando atrás da bola',
#  'Um homem está fazendo uma ligação de um celular',
#  'Três cachorros estão cheirando alguma coisa',
#  'Uma mulher está cortando uma batata',
#  'O ciclista não está andando em uma rua da cidade',
#  'Duas pessoas estão vadeando pela água',
#  'Uma pessoa está fatiando um dente de alho em pedaços',
#  'Um homem de jaqueta vermelha está de pé perto de um caiaque amarelo em algumas pedras próximo ao oceano',
#  'Uma pessoa distante com uma mochila azul está escalando uma área cheia de pedras',
#  'O homem está cortando a fita na caixa',
#  'Um homem está passando manteiga em um pedaço de pão',
#  'Um homem está esvaziando completamente um recipiente feito de plástico',
#  'O homem está tocando o piano de forma divertida com seu nariz',
#  'Um cervo está pulando sobre o recinto',
#  'Um homem está pensando',
#  'Uma pessoa está fatiando algumas cebolas',
#  'A bicicleta está sendo pedalada por uma menina em uma roupa estranha',
#  'Os jóqueis estão montando cavalos no campo, que é completamente verde',
#  'Alguns corredores estão competindo em uma corrida',
#  'Um cachorro pequeno está correndo na praia',
#  'Dois cachorros estão brincando juntos na grama',
#  'Uma pessoa de jaqueta azul está usando um capacete colorido',
#  'Duas pessoas usando capacetes estão dirigindo sobre flores amarelas e brancas',
#  'Não tem nenhuma mulher fatiando carne com uma faca',
#  'Um menino está andando com medo através de uma ponte',
#  'Uma criança jovem está de pé em frente a algumas árvores',
#  'Um pato marrom com uma cabeça verde está batendo suas asas na água',
#  'Duas pessoas estão olhando uma estátua feita de ouro',
#  'Um carro está pulando arriscadamente sobre uma menina',
#  'A máquina não está apontando um lápis',
#  'Um homem está correndo',
#  'Uma mulher está quebrando ovos',
#  'Um adversário está atacando um jogador de futebol de campo',
#  'Alguém está batendo um ovo',
#  'Azulejos estão sendo quebrados com suas mãos por um homem',
#  'O surfista está encostado em uma prancha de surfe',
#  'Um homem mais velho e uma mulher estão andando de bicicleta no calçadão perto da água',
#  'Uma sala de aula está vazia',
#  'Os jóqueis estão correndo a cavalos no campo, que é completamente verde',
#  'Um homem está fatiando um peixe',
#  'Um menino está pulando de uma plataforma e dois outros meninos estão de pé e o encarando',
#  'Uma pessoa está realizando truques em uma motocicleta',
#  'Algumas mulheres estão dançando e cantando',
#  'Uma pessoa está despejando óleo feito com azeitonas em uma panela no fogão',
#  'O homem está picando uma batata',
#  'O homem está colocando frango no recipiente',
#  'O cachorro branco está correndo pela trilha nevada',
#  'Um homem está desenhando uma imagem',
#  'Furões estão escalando prateleira acima',
#  'Três meninos com uniformes de karatê estão brigando',
#  'Um homem está tocando a bateria',
#  'Uma pessoa com equipamento de ciclismo está parada de pé de frente para algumas montanhas',
#  'Um homem está levantando barras',
#  'Um violão está sendo tocado por um bebê',
#  'Uma aeronave está decolando',
#  'Um homem está de pé no meio de uma estrada',
#  'O palestrante gosta de papagaios',
#  'Não tem nenhum grupo de pessoas dançando',
#  'Um grupo de pessoas está equipado com equipamentos de segurança',
#  'Uma jovem mulher está dando um aperto de mão em um homem',
#  'Crianças estão sendo vestidas em fantasias e jogando um jogo',
#  'Uma pessoa está saindo da água',
#  'Um carro e um trem estão atingindo um brinquedo',
#  'Um menino está correndo em direção à linha de pesca',
#  'A pessoa está fatiando um dente de alho em pedaços',
#  'Um homem e uma mulher estão andando agradavelmente',
#  'Um animal está andando de skate',
#  'Uma jovem mulher está dançando',
#  'O pelo de um gato está sendo penteado por uma pessoa',
#  'Um pequeno cachorro castanho e branco está correndo na calçada',
#  'O cachorro, que é preto e branco, está correndo e uma pessoa está parada atrás dele',
#  'Um rio está sendo atravessado por um cachorro em uma ponte feita de uma árvore caída',
#  'As pessoas não estão andando de bote e remando',
#  'Um jogador de hóquei de camisa amarela está protegendo o gol',
#  'Uma banda está tocando no palco',
#  'Cinco crianças estão paradas em frente a uma cabana de madeira',
#  'Vários furões estão escalando para fora da gaiola',
#  'Um homem está descansando em uma cadeira e esfregando seus olhos',
#  'Uma mulher negra está usando óculos sobre a bandana',
#  'Uma mulher está podando algumas plantas',
#  'Uma pessoa está fazendo um truque em um snowboard',
#  'Algumas pessoas estão sentadas em cadeiras no gramado e estão lendo livros',
#  'Um gato está comendo milho na espiga',
#  'Uma batata está sendo fatiada por uma pessoa',
#  'Um cavalo está pulando o obstáculo e tem um cavaleiro nas suas costas',
#  'Uma mulher asiática no meio de muitas pessoas está carregando uma sacola preta',
#  'Uma abelha pequena está pousando em um monte de flores amarelas',
#  'Não há nenhum cachorro rolando de um lado para outro',
#  'Um bebê está tocando um violão',
#  'A mulher está medindo um homem',
#  'O menino sorridente com roupas de inverno está acenando suas mãos enluvadas do lado de fora do prédio na neve',
#  'Um gato é jogado no teto por uma pessoa',
#  'Dois homens estão andando pelo rio',
#  'O panda está comendo bambu',
#  'Um cachorro branco está parado sobre as folhas no chão',
#  'Um pequenino porquinho-da-índia está roendo e comendo um pedaço de cenoura no chão',
#  'Um bebê está sendo colocado em uma lixeira por uma mulher',
#  'O piano está sendo tocado por um homem',
#  'Poucos homens gostam de despejar óleo de tomate',
#  'Uma menina está pulando de uma pedra e outra está em pé sobre a rocha',
#  'Uma menina está pendurada por cordas de ginástica',
#  'Algum homem está liderando a corrida',
#  'O praticante de snowboard está pulando da neve',
#  'Um homem está polvilhando tempero em vários pães fatiados e com manteiga',
#  'Quatro pessoas estão andando através da neve espessa e o sol está se pondo',
#  'Um homem está de pé perto do ônibus',
#  'A mulher está espremendo suco de um limão',
#  'Um homem e uma mulher estão comendo alegremente',
#  'Uma mulher está rachando ovos em uma tigela',
#  'Um cachorro está reunindo um bando de ovelhas brancas em uma fazenda empoeirada',
#  'Um homem está cortando um papel',
#  'Quatro atletas estão com uma pessoa em um estádio lotado',
#  'O homem e a mulher estão andando',
#  'Um homem está dançando no teto de uma sala',
#  'Um músico está tocando dois teclados',
#  'Um homem sem camisa está conduzindo um cavalo que está puxando uma carroça',
#  'Dois homens estão segurando varas de pesca e equipamentos de pesca',
#  'Um gato está escorregando de cabeça para baixo em um sofá',
#  'Um carro está sendo dirigido por um homem',
#  'Um cachorro está se afastando de um bebê',
#  'Um homem está quebrando uma mão de madeira contra uma placa',
#  'Um cachorro preto em uma coleira está andando na água',
#  'Alguém está pregando uma lente de câmera com fortes barulhos',
#  'Um skatista está fazendo truques em uma pista',
#  'O homem e a mulher estão andando através do bosque',
#  'O homem, que tem pele escura, está parado sobre uma mão na frente de um prédio amarelo',
#  'Um homem está rindo',
#  'Um homem de chapéu está andando ansiosamente por uma loja',
#  'Uma multidão perto das pessoas está se beijando dois a dois',
#  'Um grupo de pessoas está perto do mar',
#  'Vários furões estão escalando para dentro da gaiola',
#  'Diversas pessoas estão sentadas em mesas pequenas em um cômodo escuro',
#  'Não tem nenhum homem tocando um violão',
#  'O tempero está sendo adicionado à água pelo homem',
#  'Uma mulher de blusa que é roxa está levando uma bicicleta entre duas colunas de pedra',
#  'O menino está aparando a grama perto da calçada com tesoura',
#  'O jogo de basquete consiste em uma bola sendo enterrada por um homem com uma camisa de time',
#  'A mulher está jogando cebolas fora',
#  'O homem está dançando',
#  'Suco de laranja está sendo bebido por um homem que está andando em um dia ensolarado',
#  'Um homem de camisa roxa está tingindo de preto outra camisa, que tem estampado um homem olhando para um cachorro fazendo uma cara engraçada',
#  'O gol está sendo guardado por um jogador de hóquei de camisa de time amarela',
#  'Alguns jovens ciclistas estão pegando uma mountain bike para cima do morro arenoso',
#  'Um homem está quebrando uma laje de concreto com uma marreta',
#  'Um homem de camisa tingida de roxo está olhando para um homem de camisa preta que está fazendo uma cara que parece engraçada',
#  'Duas crianças pequenas estão vestindo smoking',
#  'Alguns homens estão assistindo críquete',
#  'Uma mulher está cortando uma cenoura',
#  'O homem está de pé na calçada',
#  'Um grupo de pessoas está sentado em ambos os lados de uma estrutura de pedra vermelha',
#  'O homem está despejando líquido em uma panela',
#  'Poucas crianças estão pulando em um trampolim',
#  'Uma mulher de camisa tingida de preto está sentada ao lado de uma sacola verde fluorescente',
#  'Não há nenhum homem apertando os botões de um microondas',
#  'Um roqueiro está sentado com uma camiseta que tem um homem sobre uma cachoeira cinza na frente',
#  'Um grupo de crianças de uniforme está parado no portão e não tem ninguém beijando a mãe',
#  'Uma mulher está pegando uma lata',
#  'Quatro cachorros estão brincando em uma área coberta de grama',
#  'Um homem está subindo em um cavalo numa pista na natureza',
#  'Um trem de brinquedo está golpeando violentamente um carro de brinquedo',
#  'Alguém está verificando o e-mail',
#  'Um homem está exibindo um macaco pequenino',
#  'A onda está sendo surfada pelo surfista',
#  'Alguns homens estão dançando',
#  'A pessoa está montando o animal',
#  'Um homem está montando um touro mecânico',
#  'Um papagaio está falando',
#  'A menina gosta de vermelho e não está usando miçangas para adolescentes',
#  'Um homem está em uma rocha acima de algumas árvores e está parado em uma posição estranha',
#  'Um caminhão está rapidamente subindo um morro',
#  'Um homem está almoçando',
#  'Um menino está dizendo alguma coisa',
#  'Uma pessoa está realizando acrobacias em uma moto',
#  'Duas pessoas estão se beijando apaixonadamente perto de uma multidão',
#  'Uma mulher está tirando sombra',
#  'O praticante de snowboard está pulando de um morro coberto de neve',
#  'Uma criança está vestindo um casaco e carregando um trenó vermelho perto de uma criança de casaco verde e preto',
#  'Dois meninos pequeninos vestidos de smoking estão sentados em um piso vermelho acarpetado',
#  'Uma pessoa está jogando um gato no teto',
#  'Uma mulher está cortando em cubos uma cenoura',
#  'Óculos de sol estão sendo usados \u200b\u200bpor um menino',
#  'A multidão está assistindo um jogo de futebol',
#  'Mímicos estão atuando em um palco',
#  'Um grupo de escoteiros está caminhando pela grama',
#  'Não há nenhum homem montando um cavalo',
#  'Uma senhora está misturando uma mistura de carne em uma tigela',
#  'Um homem está fazendo música com uma flauta',
#  'Uma pessoa está dançando no teto',
#  'Duas mulheres estão usando biquínis na praia que é arenosa',
#  'A menina loira com a blusa rosa está sorrindo e usando óculos engraçados com um grande nariz acoplado',
#  'Um homem está carregando uma árvore',
#  'Uma criança pequenina está enchendo uma xícara com água',
#  'Não tem nenhum homem desenhando uma figura',
#  'Três mulheres estão em pé paradas',
#  'Dois cachorros estão alegremente brincando na praia',
#  'O equipamento de escalada para resgatar um homem está pendurado em uma pedra branca, vertical',
#  'Um cachorro está mordendo uma boneca',
#  'A batata está sendo descascada pela senhora',
#  'Uma mulher está cortando alho',
#  'Um homem está correndo em um campo',
#  'Um homem está perigosamente jogando facas na árvore',
#  'Um cachorro branco está parado em cima de folhas caídas',
#  'Um homem está cortando um cordão com uma espada',
#  'Um grupo de crianças está brincando na casa e não tem nenhum homem parado ao fundo',
#  ...]

# %% [markdown]
# - **Generation Engine**

# %% [markdown]
# Função que vai pegar na frase normal e transformá-la em 3 frases de treino

# %%
# ==========================================
# 3. FUNÇÃO DE GERAÇÃO ROBUSTA
# ==========================================

def gerar_com_codigos(frase):
    # Lista de códigos permitidos (Estilo Polyjuice)
    codigos_validos = ["negation", "substitution", "insertion", "deletion", "quantifier"]
    
    prompt = f"""
    És um gerador de dados para treinar modelos de NLP.
    
    INPUT: "{frase}"
    
    TAREFA:
    Gera 3 variações contrafactuais desta frase.
    Para cada variação, DEVES usar uma estratégia diferente da lista: {codigos_validos}.
    
    REGRAS DOS CÓDIGOS:
    - negation: Adicionar/remover não, nunca, jamais, etc.
    - substitution: Trocar uma entidade (nome, cidade, objeto) por outra do mesmo tipo.
    - insertion: Adicionar um adjetivo ou advérbio que mude o sentido.
    - deletion: Remover uma palavra importante.
    - quantifier: Mudar números ou quantidades (ex: 'muitos' -> 'poucos', '10' -> '50').
    
    OUTPUT:
    Um JSON estrito (lista de objetos). Exemplo de estrutura:
    [
      {{ "frase_base": "{frase}", "codigo": "negation", "frase_gerada": "A frase na negativa..." }},
      {{ "frase_base": "{frase}", "codigo": "substitution", "frase_gerada": "A frase com troca de nome..." }}
    ]
    """

    for tentativa in range(3):
        try:
            response = model_teacher.generate_content(prompt)
            texto = response.text.strip()
            
            # Limpeza de segurança para Markdown
            if "```" in texto:
                # Para remover texto que possa vir em Markdown '''  
                texto = texto.replace("```json", "").replace("```", "")
            
            dados = json.loads(texto)
            
            # Validação: Verifica se é lista e se tem as chaves certas
            if isinstance(dados, list) and len(dados) > 0:
                # Verifica se o primeiro item tem as chaves necessárias
                if 'codigo' in dados[0] and 'frase_gerada' in dados[0]:
                    return dados
            
        except Exception as e:
            # Erro de "To many requests"
            if "429" in str(e):
                time.sleep(1.5) # Pausa curta para o Flash
            continue
            
    return []

# %% [markdown]
# Pega nas frases do ASSIN 2, usa a função do Gemini e gera o ficheiro final.

# %%
import json
import os
import time
from pathlib import Path
from tqdm import tqdm

# ==========================================
# 4. EXECUÇÃO PRINCIPAL 
# ==========================================
caminho_base = Path("/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/notebooks")
arquivo_saida = caminho_base / "teacher_final_dataset_2.json"

print(f"Caminho configurado: {arquivo_saida}")

if caminho_base.exists():
    print("✅ A pasta foi encontrada com sucesso!")
else:
    # Se a pasta não existir, este comando tenta criá-la
    caminho_base.mkdir(parents=True, exist_ok=True)
    print("📁 Pasta criada agora!")

dados_finais = []

# 1. Recuperação de falhas (Lê o que já existe)
if arquivo_saida.exists() and arquivo_saida.stat().st_size > 0:
    try:
        with arquivo_saida.open("r", encoding="utf-8") as f:
            dados_finais = json.load(f)
        print(f"✅ Recuperados {len(dados_finais)} exemplos anteriores.")
    except Exception as e:
        print(f"⚠️ Erro ao ler arquivo: {e}")
        dados_finais = []

# 2. Lógica de retoma
# Dividimos por 3 porque cada frase original gera 3 variações - 300 linhas = 100 frasesd
indice_inicio = len(dados_finais) // 3
limite = 2000
frases_para_processar = frases_input[indice_inicio:limite]

print(f"🚀 A iniciar geração para {len(frases_para_processar)} frases (começando da frase {indice_inicio})...")

# 3. Loop de processamento
try:
    for i, frase in enumerate(tqdm(frases_para_processar)):
        novos_exemplos = gerar_com_codigos(frase)
        
        if novos_exemplos:
            dados_finais.extend(novos_exemplos)
            
            # 4. SALVAR SEMPRE (ou a cada 5) para garantir persistência no Mac
            # i+1 evita salvar no índice 0. Salvamos a cada 5 frases processadas.
            if (i + 1) % 5 == 0:
                with arquivo_saida.open("w", encoding="utf-8") as f:
                    json.dump(dados_finais, f, indent=2, ensure_ascii=False)
                    f.flush()
                    os.fsync(f.fileno()) # Força a escrita física no disco
        
        # Pausa para evitar bloqueio da API (Rate Limit)
        time.sleep(1.2) 

except KeyboardInterrupt:
    print("\n\nInterrompido manualmente. A guardar progresso...")

# 5. Salvar final (Backup de encerramento)
with arquivo_saida.open("w", encoding="utf-8") as f:
    json.dump(dados_finais, f, indent=2, ensure_ascii=False)

print(f"🏁 Concluído! Dataset salvo com {len(dados_finais)} exemplos em: {arquivo_saida}")
# Out:
# Caminho configurado: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/notebooks/teacher_final_dataset_2.json
# ✅ A pasta foi encontrada com sucesso!
# ✅ Recuperados 0 exemplos anteriores.
# 🚀 A iniciar geração para 2000 frases (começando da frase 0)...
#   0%|          | 0/2000 [00:06<?, ?it/s]
# Interrompido manualmente. A guardar progresso...
# 🏁 Concluído! Dataset salvo com 0 exemplos em: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/notebooks/teacher_final_dataset_2.json

# %%
ARQUIVO_DATASET = "teacher_final_dataset.json"

try:
    with open(ARQUIVO_DATASET, 'r', encoding='utf-8') as f:
        dados = json.load(f)
        
    print(f"Total de itens no JSON: {len(dados)}")
    
    if len(dados) > 0:
        print("\n--- EXEMPLO DO PRIMEIRO ITEM ---")
        print(json.dumps(dados[0], indent=2, ensure_ascii=False))
        print("\n--- AS CHAVES SÃO ---")
        print(list(dados[0].keys()))
    else:
        print("O ficheiro JSON está vazio! Verifica se a etapa de geração guardou algo.")

except Exception as e:
    print(f"Erro ao ler o ficheiro: {e}")
# Out:
# Total de itens no JSON: 48
#
# --- EXEMPLO DO PRIMEIRO ITEM ---
# {
#   "frase_base": "Não tem nenhum homem executando um truque em uma bicicleta verde",
#   "codigo": "negation",
#   "frase_gerada": "Tem um homem executando um truque em uma bicicleta verde"
# }
#
# --- AS CHAVES SÃO ---
# ['frase_base', 'codigo', 'frase_gerada']

# %% [markdown]
# ### With Llama 3

# %%
import sys
# !{sys.executable} -m pip install ollama tqdm datasets
# Out:
# Collecting ollama
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tqdm in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: datasets in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (4.4.2)
# Requirement already satisfied: httpx>=0.27 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: filelock in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (3.20.2)
# Requirement already satisfied: numpy>=1.17 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (2.4.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1

# %%
import json
import os
import time
from pathlib import Path
from tqdm import tqdm
import ollama
from datasets import load_dataset

# %%
# ==========================================
# 1. CONFIGURAÇÃO E CAMINHOS
# ==========================================
MODELO_LOCAL = "llama3"
CAMINHO_BASE = Path("/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/notebooks")
ARQUIVO_SAIDA = CAMINHO_BASE / "teacher_final_dataset_local.json"

# Garante que a pasta existe
CAMINHO_BASE.mkdir(parents=True, exist_ok=True)

# %%
# ==========================================
# 2. CARREGAR ASSIN 2 (HUGGING FACE)
# ==========================================
print("📦 A carregar dataset ASSIN 2...")
try:
    dataset_assin = load_dataset("assin2", split="train")
    # Extrair premissas e hipóteses, remover duplicados
    lista_frases = list(dataset_assin['premise']) + list(dataset_assin['hypothesis'])
    frases_input = list(set(lista_frases))
    print(f"✅ Dataset carregado: {len(frases_input)} frases únicas disponíveis.")
except Exception as e:
    print(f"❌ Erro ao carregar dataset: {e}")
    frases_input = ["O governo anunciou novas medidas.", "A equipa venceu o jogo."]
# Out:
# 📦 A carregar dataset ASSIN 2...
# ✅ Dataset carregado: 4140 frases únicas disponíveis.

# %%
# ==========================================
# 3. FUNÇÃO DE GERAÇÃO (OLLAMA)
# ==========================================
def gerar_com_codigos(frase):
    codigos_validos = ["negation", "substitution", "insertion", "deletion", "quantifier"]
    
    prompt = f"""
    És um gerador de dados para treinar modelos de NLP.
    
    INPUT: "{frase}"
    
    TAREFA:
    Gera 3 variações contrafactuais desta frase.
    Para cada variação, DEVES usar uma estratégia diferente da lista: {codigos_validos}.
    
    REGRAS DOS CÓDIGOS:
    - negation: Adicionar/remover não, nunca, jamais, etc.
    - substitution: Trocar uma entidade (nome, cidade, objeto) por outra do mesmo tipo.
    - insertion: Adicionar um adjetivo ou advérbio que mude o sentido.
    - deletion: Remover uma palavra importante.
    - quantifier: Mudar números ou quantidades (ex: 'muitos' -> 'poucos', '10' -> '50').
    
    OUTPUT:
    Um JSON estrito (lista de objetos). Exemplo de estrutura:
    [
      {{ "frase_base": "{frase}", "codigo": "negation", "frase_gerada": "A frase na negativa..." }},
      {{ "frase_base": "{frase}", "codigo": "substitution", "frase_gerada": "A frase com troca de nome..." }}
    ]
    """

    try:
        response = ollama.chat(
            model=MODELO_LOCAL,
            messages=[{'role': 'user', 'content': prompt}],
            format='json' # Força o Llama 3 a responder em JSON puro
        )
        
        conteudo = response['message']['content']
        dados = json.loads(conteudo)
        
        # Se o Ollama devolver um dicionário com uma lista lá dentro, extraímos
        if isinstance(dados, dict):
            for key in dados:
                if isinstance(dados[key], list):
                    return dados[key]
        
        return dados if isinstance(dados, list) else []
        
    except Exception as e:
        print(f"\n⚠️ Erro no Ollama para a frase: {frase[:30]} | Erro: {e}")
        return []

# %%
# ==========================================
# 4. EXECUÇÃO PRINCIPAL COM CHECKPOINT
# ==========================================
dados_finais = []

# Recuperar progresso anterior
if ARQUIVO_SAIDA.exists() and ARQUIVO_SAIDA.stat().st_size > 0:
    try:
        with ARQUIVO_SAIDA.open("r", encoding="utf-8") as f:
            dados_finais = json.load(f)
        print(f"💾 Progresso recuperado: {len(dados_finais)} exemplos encontrados.")
    except Exception as e:
        print(f"⚠️ Erro ao ler backup: {e}")

# Lógica de retoma
indice_inicio = len(dados_finais) // 3
limite = 2000
frases_para_processar = frases_input[indice_inicio:limite]

print(f"🚀 A iniciar geração local (Frase {indice_inicio} até {limite})...")



try:
    for i, frase in enumerate(tqdm(frases_para_processar, desc="Gerando Dataset")):
        novos = gerar_com_codigos(frase)
        
        if novos:
            dados_finais.extend(novos)
            
            # Guardar a cada 5 frases para não perder progresso
            if (i + 1) % 5 == 0:
                with ARQUIVO_SAIDA.open("w", encoding="utf-8") as f:
                    json.dump(dados_finais, f, indent=2, ensure_ascii=False)
                    f.flush()
                    os.fsync(f.fileno()) # Força escrita física no Mac

        # Como é local, não precisamos de sleeps longos
        time.sleep(0.05)

except KeyboardInterrupt:
    print("\n\n🛑 Interrompido pelo utilizador. A guardar progresso...")

# Salvamento Final
with ARQUIVO_SAIDA.open("w", encoding="utf-8") as f:
    json.dump(dados_finais, f, indent=2, ensure_ascii=False)

print(f"🏁 Concluído! O teu dataset local está pronto em: {ARQUIVO_SAIDA}")
print(f"Total de exemplos: {len(dados_finais)}")
# Out:
# 💾 Progresso recuperado: 0 exemplos encontrados.
# 🚀 A iniciar geração local (Frase 0 até 2000)...
# Gerando Dataset:   6%|▌         | 122/2000 [45:48<11:45:05, 22.53s/it]
# 🛑 Interrompido pelo utilizador. A guardar progresso...
# 🏁 Concluído! O teu dataset local está pronto em: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/notebooks/teacher_final_dataset_local.json
# Total de exemplos: 325

# %% [markdown]
# ## Setup the PTT5 Model

# %% [markdown]
# - **Import libraries for T5 Model fine-tuning**

# %% [markdown]
# In this section, we import the essential libraries for data manipulation (pandas, numpy) and for building the Deep Learning pipeline (torch, transformers). We highlight the use of T5ForConditionalGeneration for sequence-by-sequence tasks.

# %%
import json
import gc
import itertools

import numpy as np
import pandas as pd
import torch

from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict

from transformers import (
    T5Tokenizer,
    T5ForConditionalGeneration,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq
)

# %% [markdown]
# - **Environment Configurations & Hyperparameters**

# %%
# ==========================================
# 1. CONFIGURAÇÕES
# ==========================================
MODEL_NAME = "unicamp-dl/ptt5-base-portuguese-vocab" 
ARQUIVO_DATASET = "teacher_final_dataset_local.json"   
OUTPUT_DIR = "./ptt5-polyjuice-pt-student"

# Hiperparâmetros
BATCH_SIZE = 8         
EPOCHS = 3
LEARNING_RATE = 2e-4    
MAX_INPUT_LEN = 128
MAX_TARGET_LEN = 128

# %% [markdown]
# O T5 original usa um tokenizador treinado maioritariamente em inglês. Quando tentas processar português, ele "parte" as palavras em pedaços muito pequenos (sub-tokens), o que torna a frase mais longa e o processamento menos eficiente. O PTT5 foi retreinado com vocabulário português.
# Isto faz com que o modelo entenda melhor a sintaxe PT-PT/PT-BR e converge mais rápido.

# %% [markdown]
# - **Data Sanity Check: Verification of Existence and Format**

# %%
import os
import json

# Verifica se o arquivo existe
if not os.path.exists(ARQUIVO_DATASET):
    print(f"❌ ERRO CRÍTICO: O arquivo '{ARQUIVO_DATASET}' não foi encontrado no diretório atual.")
    print(f"Diretório atual: {os.getcwd()}")
    print("Verifique se fez o upload do arquivo JSON para a pasta correta no Colab/Jupyter.")
else:
    print(f"✅ Arquivo '{ARQUIVO_DATASET}' encontrado!")
    
    # Tenta ler e mostrar o primeiro exemplo para conferir as chaves
    try:
        with open(ARQUIVO_DATASET, 'r', encoding='utf-8') as f:
            data = json.load(f)
            
        if isinstance(data, list) and len(data) > 0:
            print(f"O arquivo contém {len(data)} exemplos.")
            print("\n--- ESTRUTURA DO PRIMEIRO EXEMPLO ---")
            print(json.dumps(data[1], indent=2, ensure_ascii=False))
            print("-------------------------------------")
            print("Compare as chaves acima (ex: 'input', 'target') com as que você usa na função 'carregar_e_formatar_dados'.")
        else:
            print("⚠️ O arquivo JSON foi lido, mas parece estar vazio ou não é uma lista.")
            
    except Exception as e:
        print(f"❌ O arquivo existe, mas o JSON está corrompido ou inválido. Erro: {e}")
# Out:
# ✅ Arquivo 'teacher_final_dataset_local.json' encontrado!
# O arquivo contém 325 exemplos.
#
# --- ESTRUTURA DO PRIMEIRO EXEMPLO ---
# {
#   "frase_base": "Uma mulher está passando batom",
#   "codigo": "substitution",
#   "frase_gerada": "Um homem está passando batom"
# }
# -------------------------------------
# Compare as chaves acima (ex: 'input', 'target') com as que você usa na função 'carregar_e_formatar_dados'.

# %% [markdown]
# - **Ingestion Pipeline: Formatting T5 Inputs and Creating the DatasetDict**

# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict

# ==========================================
# 2. PREPARAÇÃO DOS DADOS (VERSÃO ROBUSTA)
# ==========================================

def carregar_e_formatar_dados(caminho_arquivo):
    print(f"--> A ler o arquivo: {caminho_arquivo}")
    
    with open(caminho_arquivo, 'r', encoding='utf-8') as f:
        dados_raw = json.load(f)

    # CORREÇÃO AUTOMÁTICA DE ESTRUTURA - Evita que crash com KeyError ou TypeError
    # Exceção tratada e entrada normalizada
    # Se o JSON for um dicionário (ex: {"data": [...]}), tentamos encontrar a lista lá dentro.
    if isinstance(dados_raw, dict): 
        print("⚠️ Aviso: O JSON raiz é um dicionário, não uma lista. A procurar a lista de dados...")
        encontrou_lista = False
        for chave, valor in dados_raw.items():
            if isinstance(valor, list):
                print(f"✅ Lista de dados encontrada na chave: '{chave}'")
                dados_raw = valor
                encontrou_lista = True
                break
        if not encontrou_lista:
            raise ValueError("O arquivo é um dicionário, mas não encontrei nenhuma lista dentro dele.")

    inputs = []
    targets = []

    print(f"--> A processar {len(dados_raw)} itens...")

    for i, item in enumerate(dados_raw):
        # Verificação de segurança: se o item for string, algo está errado
        if isinstance(item, str):
            print(f"❌ Erro no item {i}: O item é uma string ('{item}'), esperava-se um objeto {{...}}")
            continue 

        frase_base = item.get('frase_base')
        codigo = item.get('codigo')
        frase_alvo = item.get('frase_gerada')

        if frase_base and frase_alvo:
            if codigo:
                # O codigo é passado para que o modelo altere a frase
                input_text = f"gerar contrafactual {codigo}: {frase_base}"
            else:
                input_text = f"gerar contrafactual: {frase_base}"
            
            inputs.append(input_text)
            targets.append(frase_alvo)

    return inputs, targets

# --- Execução Principal ---

try:
    # 1. Carregar dados
    src_text, tgt_text = carregar_e_formatar_dados(ARQUIVO_DATASET)
    
    if len(src_text) == 0:
        raise ValueError("Nenhum dado válido foi encontrado. Verifique as chaves do JSON.")

    print(f"✅ Sucesso! {len(src_text)} exemplos válidos carregados.")

    # 2. Divisão Treino/Validação
    train_texts, val_texts, train_labels, val_labels = train_test_split(
        src_text, tgt_text, test_size=0.1, random_state=42
    )

    # 3. Criar Datasets Hugging Face
    train_dataset = Dataset.from_dict({"input_text": train_texts, "target_text": train_labels})
    val_dataset = Dataset.from_dict({"input_text": val_texts, "target_text": val_labels})
    dataset = DatasetDict({"train": train_dataset, "validation": val_dataset})
    
    print("\n✅ Dataset pronto:")
    print(dataset)

except Exception as e:
    print("\n❌ ERRO FATAL:")
    print(e)
    # Define variáveis como None para evitar NameError confuso se tentar rodar a próxima célula
    dataset = None
    src_text = None
# Out:
# --> A ler o arquivo: teacher_final_dataset_local.json
# --> A processar 325 itens...
# ❌ Erro no item 102: O item é uma string ('A frase não está mais fatiando batatas'), esperava-se um objeto {...}
# ❌ Erro no item 103: O item é uma string ('Ela não está fatiando batatas nunca'), esperava-se um objeto {...}
# ❌ Erro no item 104: O item é uma string ('Ele não está mais fazendo isso, jamais fatia batatas'), esperava-se um objeto {...}
# ✅ Sucesso! 304 exemplos válidos carregados.
#
# ✅ Dataset pronto:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'target_text'],
#         num_rows: 273
#     })
#     validation: Dataset({
#         features: ['input_text', 'target_text'],
#         num_rows: 31
#     })
# })

# %% [markdown]
# - **Tokenization and Preprocessing with Label Masking (Padding Ignored)**

# %%
# ==========================================
# 3. TOKENIZAÇÃO
# ==========================================
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)

def preprocess_function(examples):
    inputs = examples["input_text"]
    targets = examples["target_text"]
    
    # Tokenizar inputs
    model_inputs = tokenizer(
        inputs, 
        max_length=MAX_INPUT_LEN, 
        padding="max_length", 
        truncation=True
    )

    # Tokenizar targets (labels)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            targets, 
            max_length=MAX_TARGET_LEN, 
            padding="max_length", 
            truncation=True
        )

    # Substituir token de padding por -100 para o cálculo da loss ignorar padding
    # Como as frases têm tamanhos diferentes na matriz retangular enchemos as frases curtas com <pad>
    # Ao calcular a loss, vai incluir o <pad> e para que isso não aconteça utiliza-se o "-100" para
    # que ignore os espaços vazios 
    labels["input_ids"] = [
        [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
    ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_datasets = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/273 [00:00<?, ? examples/s]
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:4169: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/31 [00:00<?, ? examples/s]

# %%
import sys
import os

print(f"Python Executable: {sys.executable}")
print(f"Library Search Paths: {sys.path}")

try:
    import accelerate
    print("Success: Accelerate is visible to this script!")
except ImportError:
    print("Error: Accelerate is STILL NOT visible to this script.")
# Out:
# Python Executable: /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/bin/python
# Library Search Paths: ['/Library/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages', '/var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/tmpn9xxyd7s', '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/src', '/Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/src']
# Success: Accelerate is visible to this script!

# %% [markdown]
# - **Pipeline de Otimização (Grid Search): Experimentação e Seleção de Modelo**

# %%
# ==========================================
# 4. GRID SEARCH CONFIGURATION
# ==========================================

CONFIG_PATH = 'grid_search_config.json'
OUTPUT_DIR = './outputs' # Ensure this variable is defined

with open(CONFIG_PATH, 'r') as f:
    grid_params = json.load(f)

# Fix: Access the nested 'hyperparameters' dictionary
MODEL_NAME = grid_params['model_name']
search_space = grid_params['hyperparameters'] 

keys = search_space.keys()
combinations = list(itertools.product(*search_space.values()))

# Detect Device (Mac MPS support)
if torch.backends.mps.is_available():
    device_type = "mps"
elif torch.cuda.is_available():
    device_type = "cuda"
else:
    device_type = "cpu"

print(f"Device detected: {device_type.upper()}")
print(f"Total Experiences to Realize: {len(combinations)}")

results_log = []
best_loss = float('inf')
best_params = None

# ==========================================
# 5. LOOP DE EXPERIMENTAÇÃO (GRID SEARCH)
# ==========================================
for i, values in enumerate(combinations):
    current_params = dict(zip(keys, values))
    
    # Generate experiment name
    exp_name = (f"exp_lr{current_params['learning_rate']}_"
                f"bs{current_params['batch_size']}_"
                f"ep{current_params['num_train_epochs']}")
    
    print(f"\n>>> EXPERIENCE {i+1}/{len(combinations)} | Parameters: {current_params}")
    
    # 1. Recarregar o modelo limpo
    # Permite que o modelo não faça "weight carry-over"
    model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
    # Move model to detected device
    model.to(device_type)
    
    # 2. Configurar Argumentos
    training_args = Seq2SeqTrainingArguments(
        output_dir=f"./results/{exp_name}",
        eval_strategy="epoch",
        save_strategy="no", 
        learning_rate=current_params['learning_rate'],
        per_device_train_batch_size=current_params['batch_size'],
        per_device_eval_batch_size=current_params['batch_size'],
        weight_decay=current_params['weight_decay'],
        num_train_epochs=current_params['num_train_epochs'],
        predict_with_generate=True,
        # Optimization for Mac vs NVIDIA
        use_mps_device=(device_type == "mps"),
        fp16=torch.cuda.is_available(),
        report_to="none",
        logging_steps=50
    )

    # 3. Inicializar Trainer
    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_datasets["train"], # Assumes this exists in your scope
        eval_dataset=tokenized_datasets["validation"],
        data_collator=DataCollatorForSeq2Seq(tokenizer, model=model),
        tokenizer=tokenizer,
    )

    # 4. Treinar e Avaliar
    trainer.train()
    eval_metrics = trainer.evaluate()
    
    # 5. Log de Resultados
    current_loss = eval_metrics['eval_loss']
    result_entry = {**current_params, **eval_metrics, "exp_name": exp_name}
    results_log.append(result_entry)
    
    # 6. Salvar o melhor modelo se a loss atual for a menor
    # Apenas o melhor modelo é guardado no disco
    if current_loss < best_loss:
        best_loss = current_loss
        best_params = current_params
        print(f" NEW BEST MODEL (Loss: {best_loss:.4f})")
        model.save_pretrained(f"{OUTPUT_DIR}/final_model")
        tokenizer.save_pretrained(f"{OUTPUT_DIR}/final_model")

    # 7. Limpeza agressiva de memória
    del model
    del trainer
    # Para forçar garbage collector e limpar a cache do VRAM no final de cada ciclo é obrigatório para estabilidade
    gc.collect()    
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    elif torch.backends.mps.is_available():
        torch.mps.empty_cache()

# Salvar resumo final
df_results = pd.DataFrame(results_log)
df_results.to_csv("grid_search_results.csv", index=False)

print("\n" + "="*40)
print("GRID SEARCH CONCLUDED!")
print(f"Best Parameters: {best_params}")
print(f"Best Eval Loss: {best_loss:.4f}")
print("Results saved on 'grid_search_results.csv'")
print(f"Best model was saved on: {OUTPUT_DIR}/final_model")
print("="*40)
# Out:
# Device detected: MPS
# Total Experiences to Realize: 36
#
# >>> EXPERIENCE 1/36 | Parameters: {'learning_rate': 0.0001, 'batch_size': 8, 'num_train_epochs': 3, 'weight_decay': 0.01}
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/transformers/training_args.py:2301: UserWarning: `use_mps_device` is deprecated and will be removed in version 5.0 of 🤗 Transformers. `mps` device will be used by default if available similar to the way `cuda` device is used.Therefore, no action from user is required.
#   warnings.warn(
# /var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/ipykernel_2292/3909041487.py:70: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='105' max='105' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [105/105 01:13, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.508456</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.849300</td>
#       <td>1.342185</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.477700</td>
#       <td>1.290410</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='4' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4/4 00:00]
#     </div>
#  NEW BEST MODEL (Loss: 1.2904)
#
# >>> EXPERIENCE 2/36 | Parameters: {'learning_rate': 0.0001, 'batch_size': 8, 'num_train_epochs': 3, 'weight_decay': 0.1}
#     <div>
#
#       <progress value='26' max='105' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 26/105 00:16 < 00:55, 1.43 it/s, Epoch 0.71/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 80
#      70 trainer = Seq2SeqTrainer(
#      71     model=model,
#      72     args=training_args,
#    (...)     76     tokenizer=tokenizer,
#      77 )
#      79 # 4. Treinar e Avaliar
# ---> 80 trainer.train()
#      81 eval_metrics = trainer.evaluate()
#      83 # 5. Log de Resultados
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/transformers/trainer.py:2325, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323         hf_hub_utils.enable_progress_bars()
#    2324 else:
# -> 2325     return inner_training_loop(
#    2326         args=args,
#    2327         resume_from_checkpoint=resume_from_checkpoint,
#    2328         trial=trial,
#    2329         ignore_keys_for_eval=ignore_keys_for_eval,
#    2330     )
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/transformers/trainer.py:2674, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2667 context = (
#    2668     functools.partial(self.accelerator.no_sync, model=model)
#    2669     if i != len(batch_samples) - 1
#    2670     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2671     else contextlib.nullcontext
#    2672 )
#    2673 with context():
# -> 2674     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2676 if (
#    2677     args.logging_nan_inf_filter
#    2678     and not is_torch_xla_available()
#    2679     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2680 ):
#    2681     # if loss is nan or inf simply add the average of previous logged losses
#    2682     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/transformers/trainer.py:4071, in Trainer.training_step(***failed resolving arguments***)
#    4068     if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    4069         kwargs["scale_wrt_gas"] = False
# -> 4071     self.accelerator.backward(loss, **kwargs)
#    4073 return loss.detach()
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/accelerate/accelerator.py:2852, in Accelerator.backward(self, loss, **kwargs)
#    2850     self.lomo_backward(loss, learning_rate)
#    2851 else:
# -> 2852     loss.backward(**kwargs)
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# - **Single-Run Training Execution and Model Evaluation**

# %% [markdown]
# Guarda um snapshot do modelo num momento específico do treino (no passo 35 e 70 como exemplo).
#
# O Trainer do Hugging Face guarda tudo o que é necessário para usar o modelo (fazer as inferências) e continuar o treino de onde parou.

# %% [markdown]
# **Pesos e Arquitetura**

# %% [markdown]
# - model.safetensors (contém os pesos aprendidos pela rede neuronal)
#
# - config.json (tem a planta do modelo e diz como construir a estrtura do modelo antes de carregar os pesos)
#
# - generation_config.json (guardas as regras de geração de texto porque é um modelo T5 - temperatura, tamanho máximo de resposta)

# %% [markdown]
# **Tokenizer** - serve como tradutor de texto para números para que o modelo posso receber os dados.
#
# Utiliza o SentencePiece porque é o PTT5

# %% [markdown]
# - spiece.model (é o modelo do SentencePiece e é o dicionário binário que parte as palavras em pedaços - sub-tokens)
#
# - tokenizer.json (configurações gerais do tokenizer)
#
# - special_tokens_map.json (mapeia tokens especiais)
#
# - added_tokens.json (para palavras novas que não existam no vocabulário)

# %% [markdown]
# **Estado do Treino** - serve para se quiser treinar no ponto que parei

# %% [markdown]
# - optimizer.pt (guarda o estado do otimizador AdamW e recorda-se do momento de cada peso para saber como ajustar a descida do gradiente no próximo passo)
#
# - scheduler.pt (guarda o estado do Learning Rate Scheduler)
#
# - training_arbs.bin (binário de serialização de dados - guarda todos os argumentos definidos no Seq2SeqTrainingArguments - batch size, weight decay, etc). O pyhton pega no objeto Seq2SeqTrainingArguments que estava na memória RAM durante o treino e congela-o numa sequência de bytes para guardar no disco.
#
# | OFFSET | BYTES (HEXADECIMAL)              | DECODIFICAÇÃO ASCII (TEXTO) mentebinaria.gitbook+1​ |
# | ------ | -------------------------------- | --------------------------------------------------- |
# | 000000 | 80 04 95 3A 01 00 00 00 00 00 00 | ...:.......                                         |
# | 000010 | 8C 15 74 72 61 6E 73 66 6F 72 6D | ..transform                                         |
# | 000020 | 65 72 73 2E 74 72 61 69 6E 69 6E | ers.trainin                                         |
# | 000030 | 67 5F 61 72 67 73 94 8C 11 54 72 | g_args..Tr                                          |
# | 000040 | 61 69 6E 69 6E 67 41 72 67 75 6D | ainingArgum                                         |
# | 000050 | 65 6E 74 73 94 93 94 29 81 94 7D | ents...)..}                                         |
# | 000060 | 94 28 8C 0D 6F 75 74 70 75 74 5F | .(.output_                                          |
# | 000070 | 64 69 72 94 8C 17 2E 2F 6F 75 74 | dir.../out                                          |
# | 000080 | 70 75 74 73 2F 74 72 61 69 6E 69 | puts/traini                                         |
# | 0001A0 | 8C 0D 6C 65 61 72 6E 69 6E 67 5F | ..learning_                                         |
# | 0001B0 | 72 61 74 65 94 47 3F D3 A9 2A 30 | rate.G?..*0                                         |
# | 0001C0 | 55 38 1E 8C 0F 6E 75 6D 5F 74 72 | U8...num_tr                                         |
#
# - rng_state.pth (guarda o estado do gerador de números aleatórios  - garante que ao retomar o treino o shuffle dos dados, o dropout acontecem exatamente como se o treino nunca tivesse parado)

# %% [markdown]
# - Com este script já não preciso de treinar o modelo mais nenhuma vez (só se quiser alterar alguns parâmetros)

# %%
import torch
import gc
from transformers import (
    T5ForConditionalGeneration,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    DataCollatorForSeq2Seq
)

# ==========================================
# CONFIGURAÇÃO SIMPLIFICADA (SEM GRID SEARCH)
# ==========================================

MODEL_NAME = "unicamp-dl/ptt5-base-portuguese-vocab" 
OUTPUT_DIR = './outputs'

# Parâmetros fixos (escolha valores razoáveis para teste rápido)
LEARNING_RATE = 3e-4
BATCH_SIZE = 8
NUM_EPOCHS = 2  # Reduzido para teste rápido
WEIGHT_DECAY = 0.01

# Detectar dispositivo
if torch.backends.mps.is_available():
    device_type = "mps"
elif torch.cuda.is_available():
    device_type = "cuda"
else:
    device_type = "cpu"

print(f"Device detected: {device_type.upper()}")
print(f"Training with: LR={LEARNING_RATE}, BS={BATCH_SIZE}, Epochs={NUM_EPOCHS}")

# ==========================================
# CARREGAR MODELO
# ==========================================
print("\nLoading model...")
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
model.to(device_type)

# ==========================================
# CONFIGURAR TREINO
# ==========================================
training_args = Seq2SeqTrainingArguments(
    output_dir=f"{OUTPUT_DIR}/training_output",
    eval_strategy="epoch",
    save_strategy="epoch",  # Salvar a cada época
    save_total_limit=2,     # Guarda sempre o melhor modelo e o mias recente apagando os antigos e nunca mantém mais de duas páginas de checkpoint
    learning_rate=LEARNING_RATE,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    weight_decay=WEIGHT_DECAY,
    num_train_epochs=NUM_EPOCHS,
    predict_with_generate=True,
    use_mps_device=(device_type == "mps"),
    fp16=torch.cuda.is_available(),
    report_to="none",
    logging_steps=50,
    load_best_model_at_end=True,  # Carregar melhor modelo no final
    metric_for_best_model="eval_loss"
)

# o Trainer monitoriza a validação. Mesmo que treines por 10 épocas e o melhor resultado tenha sido na época 3,
#  no final do processo, a variável model (e o que é salvo no disco) conterá os pesos da época 3.

# ==========================================
# INICIALIZAR TRAINER
# ==========================================
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=DataCollatorForSeq2Seq(tokenizer, model=model),
    tokenizer=tokenizer,
)

# ==========================================
# TREINAR
# ==========================================
print("\nStarting training...")
trainer.train()

# ==========================================
# AVALIAR
# ==========================================
print("\nEvaluating model...")
eval_metrics = trainer.evaluate()

print("\n" + "="*50)
print("TRAINING COMPLETED!")
print(f"Final Eval Loss: {eval_metrics['eval_loss']:.4f}")
print("="*50)

# ==========================================
# SALVAR MODELO FINAL
# ==========================================
print(f"\nSaving model to {OUTPUT_DIR}/final_model...")
model.save_pretrained(f"{OUTPUT_DIR}/final_model")
tokenizer.save_pretrained(f"{OUTPUT_DIR}/final_model")

# ==========================================
# LIMPEZA DE MEMÓRIA
# ==========================================
del model
del trainer
gc.collect()

if torch.cuda.is_available():
    torch.cuda.empty_cache()
elif torch.backends.mps.is_available():
    torch.mps.empty_cache()

print("\nAll done! Model saved successfully.")
# Out:
# Device detected: MPS
# Training with: LR=0.0003, BS=8, Epochs=2
#
# Loading model...
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/transformers/training_args.py:2301: UserWarning: `use_mps_device` is deprecated and will be removed in version 5.0 of 🤗 Transformers. `mps` device will be used by default if available similar to the way `cuda` device is used.Therefore, no action from user is required.
#   warnings.warn(
# /var/folders/jc/ggdhgrys23xgcrxc0fly4jjc0000gn/T/ipykernel_1195/1724431252.py:66: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Starting training...
#     <div>
#
#       <progress value='70' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [70/70 00:16, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>3.256629</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.091000</td>
#       <td>3.140272</td>
#     </tr>
#   </tbody>
# </table><p>
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# Evaluating model...
# /Users/miguelmauricioantonio/Documents/NLP-XAI/XAI_LIME/experiments/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='8' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4/4 00:08]
#     </div>
# ==================================================
# TRAINING COMPLETED!
# Final Eval Loss: 3.1403
# ==================================================
#
# Saving model to ./outputs/final_model...
#
# All done! Model saved successfully.

# %% [markdown]
# - **Execution of the Training Pipeline (Knowledge Distillation) and Export**

# %%
# ==========================================
# 5. EXECUÇÃO DO TREINO 
# ==========================================
print("Initializing Training (Distillation)...")
trainer.train()

print("Saving final model...")
model.save_pretrained(f"{OUTPUT_DIR}/final_model")
tokenizer.save_pretrained(f"{OUTPUT_DIR}/final_model")

print("Train ended with success!")
# Out:
# Initializing Training (Distillation)...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # ==========================================
#       2 # 5. EXECUÇÃO DO TREINO
#       3 # ==========================================
#       4 print("Initializing Training (Distillation)...")
# ----> 5 trainer.train()
#       7 print("Saving final model...")
#       8 model.save_pretrained(f"{OUTPUT_DIR}/final_model")
#
# NameError: name 'trainer' is not defined

# %% [markdown]
# - Dataset with sentences that have the words with higher score

# %%
# 1. Extrair palavras do LIME (Baseado no teu script anterior)
raw_list = top_3_fake_compact['Top_3_Words'].tolist()
words_to_audit = []
for item in raw_list:
    cleaned = str(item).replace('[', '').replace(']', '').replace("'", "").replace('"', "")
    for part in cleaned.split(','):
        if part.strip(): words_to_audit.append(part.strip().lower())
words_to_audit = sorted(list(set(words_to_audit)))

# 2. Selecionar frases do X_test que contêm estas palavras
lista_para_xai = []
for word in words_to_audit:
    if word in vectorizer.vocabulary_:
        idx = vectorizer.vocabulary_[word]
        doc_indices = np.where(X_test[:, idx].toarray().flatten() > 0)[0]
        
        for d_idx in doc_indices[:3]: # Pegamos 3 frases por palavra
            txt = texts_test.iloc[d_idx] if hasattr(texts_test, 'iloc') else texts_test[d_idx]
            lista_para_xai.append({'original_text': txt, 'target_code': 'negation', 'word': word})

df_teste_xai = pd.DataFrame(lista_para_xai).drop_duplicates(subset=['original_text'])
print(f"Total de frases para auditoria: {len(df_teste_xai)}")

# %% [markdown]
# ## Inference and Testing of Counterfactual Generation

# %%
import os
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration

# ==========================================
# 1. AJUSTE DO CAMINHO (BASEADO NA TUA IMAGEM)
# ==========================================
# Na imagem, a pasta é "outputs" e dentro tem "final_model"
CAMINHO_CORRETO = "./outputs/final_model" 

print(f"📂 A carregar modelo de: {CAMINHO_CORRETO}")

# Verificação física antes de carregar
if not os.path.exists(CAMINHO_CORRETO):
    print(f"❌ ERRO CRÍTICO: O Python não encontra a pasta '{CAMINHO_CORRETO}'.")
    print(f"   Diretório atual de trabalho: {os.getcwd()}")
    print("   Verifique se a pasta 'outputs' está no mesmo nível deste notebook.")
else:
    print("✅ Diretório encontrado!")

# ==========================================
# 2. CARREGAMENTO (COM SUPORTE A SAFETENSORS)
# ==========================================
# Para que seja Device Agnostic
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")

try:
    # Carregar Tokenizer
    tokenizer = T5Tokenizer.from_pretrained(CAMINHO_CORRETO)
    
    # Carregar Modelo (O 'use_safetensors=True' ajuda se a lib for antiga, 
    # mas o huggingface geralmente deteta sozinho o arquivo .safetensors)
    model = T5ForConditionalGeneration.from_pretrained(
        CAMINHO_CORRETO, 
        use_safetensors=True 
    )
    
    model.to(device)
    model.eval()
    print(f"✅ SUCESSO! Modelo e Tokenizer carregados no device: {device}")

except Exception as e:
    print(f"\n❌ Erro no carregamento: {e}")
    raise e

# ==========================================
# 3. TESTE DE GERAÇÃO
# ==========================================
def gerar_teste(frase, codigo=""):
    # Prompt Engineering - Formato deve ser mantido na inferência                               
    input_text = f"gerar contrafactual {codigo}: {frase}" if codigo else f"gerar contrafactual: {frase}"
    
    inputs = tokenizer(
        input_text, 
        return_tensors="pt", 
        max_length=128, 
        truncation=True, 
        padding="max_length"
    ).to(device)

    with torch.no_grad():
        outputs = model.generate(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            max_length=128,
            # Simulate 5 different paths and choose the one that have the highest probability of being right
            num_beams=5,
            repetition_penalty=1.5, # Penalidade um pouco maior para evitar repetições
            early_stopping=True
        )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Teste Rápido
frase = "O dia está bonito."
print("\n--- TESTE REAL ---")
print(f"Input: {frase}")
print(f"Output: {gerar_teste(frase, 'negation')}")
# Out:
# 📂 A carregar modelo de: ./outputs/final_model
# ✅ Diretório encontrado!
# ✅ SUCESSO! Modelo e Tokenizer carregados no device: mps
#
# --- TESTE REAL ---
# Input: O dia está bonito.
# Output: O dia está bonito.

# %% [markdown]
# ### Fine-tuning Inference: Sampling and Temperature (Creativity Power)

# %%
# ==========================================
# TESTE DE CRIATIVIDADE (SAMPLING VS BEAM)
# ==========================================

def gerar_criativo(frase, codigo="", temperatura=0.9):
    input_text = f"gerar contrafactual {codigo}: {frase}" if codigo else f"gerar contrafactual: {frase}"
    
    inputs = tokenizer(
        input_text, 
        return_tensors="pt", 
        max_length=128, 
        truncation=True, 
        padding="max_length"
    ).to(device)

    # Para não guardar cálculos do backpropagation - poupa memória RAM/VRAM e a geração é mais rápida
    with torch.no_grad():
        outputs = model.generate(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            max_length=128,
            # --- PARÂMETROS DE "CRIATIVIDADE" ---
            # Em vez de escolher sempre o caminho mais óbvio, ele escolhe outras opções com base na temperatura - bom para ver se o modelo aprendeu
            # a estrutura da língua e não apenas decorou frases
            do_sample=True,          # Habilita aleatoriedade controlada
            temperature=temperatura, # Tenta 0.7 (conservador) a 1.2 (caótico)
            top_k=50,                # Considera apenas as 50 melhores palavras
            top_p=0.95,              # Nucleus Sampling (corta cauda longa de probabilidade)
            repetition_penalty=2.0,  # Penaliza fortemente repetição de palavras
            early_stopping=True
        )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# ==========================================
# BATERIA DE TESTES (VERSÃO AVANÇADA)
# ==========================================

# Lista de Tuplos: (Frase, Código que queres testar)
testes = [
    ("O dia está bonito.", "negation"),
    ("O serviço foi rápido.", "negation"),
]

print("\n--- TESTE DE COMANDOS ---")

for frase, codigo_teste in testes:
    print(f"\n📝 Frase Original: {frase}")
    print(f"   Comando: {codigo_teste}")
    
    # Aqui passamos o 'codigo_teste' dinamicamente
    resultado = gerar_criativo(frase, codigo=codigo_teste, temperatura=0.7)
    
    print(f"   🤖 Modelo: {resultado}")
# Out:
# The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# --- TESTE DE COMANDOS ---
#
# 📝 Frase Original: O dia está bonito.
#    Comando: negation
#    🤖 Modelo: O dia está bonito.
#
# 📝 Frase Original: O serviço foi rápido.
#    Comando: negation
#    🤖 Modelo: O serviço foi rápido.
